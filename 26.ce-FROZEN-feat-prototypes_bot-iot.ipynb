# %% [markdown]
# # CE-only VQC with FROZEN Features: BoT-IoT
# ## Capped Sample (3000) | ~11800 Train | Batch Size 64
# ## 50 Epochs (Early Stopping with Patience = 5) | LR 0.05
# ## Target (y) = "label_multiclass" | Data Reupload = 2

# %% [markdown]
# ## Setup

# %%
import pennylane as qp
from pennylane import numpy as np
import torch

import matplotlib.pyplot as plt
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import json
from pathlib import Path
import time

# %%
from scripts.constants import (
    DEFAULT_EPOCHS, DEFAULT_LR, DEFAULT_BATCH_SIZE,
    DEFAULT_NOISE_RATE,
    BARREN_PLATEAU_VAR_THRESHOLD, DEFAULT_N_TRIALS, DEFAULT_PATIENCE,
)
from scripts.data import (
    class_balance_table,
    capped_sample,
    stratified_head,
    plot_class_balance_bars,
    plot_class_balance_pie,
    greedy_kcenter_sample,
    greedy_dpp_sample,
    plot_dataset_and_sampling_analysis,
    load_split,
    to_angles,
)
from scripts.circuit import build_forward_circuit, create_quantum_device
from scripts.train import train_plain_vqc
from scripts.utils import get_torch_device, to_np_y
from scripts.logging import write_history_log
from scripts.memory import is_oom_error, run_batched_safely, safe_empty_cache
from scripts.prototypes import PrototypeBank, prototype_summary
from scripts.gradient import gradient_variance_probe
from scripts.theory import verify_fidelity_convention

# %%
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available?: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA device name: {torch.cuda.get_device_name(0)}")
    print(f"Current CUDA device index: {torch.cuda.current_device()}")
# Out:
# PyTorch version: 2.12.1+cu126
# CUDA available?: True
# CUDA device name: NVIDIA GeForce GTX 1060
# Current CUDA device index: 0

# %% [markdown]
# ## Config

# %%
NOTEBOOK_NAME = "26.ce-FROZEN-feat-prototypes_bot-iot"

dataset = "BoT-IoT"
target_col = "label_multiclass"
data_path = f"data/FROZEN/{dataset}"
frozen_feat_path = "team-artifacts/teamC_week3_FROZEN_handoff.json"

SEED = 42

# %%
check = verify_fidelity_convention(dim=4, n_trials=30, seed=SEED)
print("Fidelity-convention self-check PASSED:", check)
# Out:
# Fidelity-convention self-check PASSED: {'max_pairwise_disagreement': 0.0, 'max_fvg_violation': 0.0}

# %% [markdown]
# ## Load Team C's FROZEN Features

# %%
handoff = json.loads(Path(frozen_feat_path).read_text())
FEATURE_COLS = list(handoff["frozen_subsets"][dataset]["features"])
print(f"Team C selector: {handoff['frozen_subsets'][dataset]['selector']}")
print(f"k={len(FEATURE_COLS)} features: {FEATURE_COLS}")
# Out:
# Team C selector: QIGPSO
# k=10 features: ['n_pkts_total', 'n_bytes_total', 'src_bytes', 'rate', 'pkt_size_min', 'pkt_size_max', 'pkt_size_mean', 'pkt_size_std', 'protocol', 'conn_state']

# %% [markdown]
# ## Load Team A's FROZEN Dataset

# %%
# load all data
X_train_full, y_train_full, class_names, df_train = load_split(
    data_path, f"train", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_cal_full, y_cal_full, _, df_cal = load_split(
    data_path, f"calibration", target_col, categories=class_names, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_test_full, y_test_full, _, df_test = load_split(
    data_path, f"test", target_col, categories=class_names, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_zero_full, y_zero_full, _, df_zero = load_split(
    data_path, f"zeroday", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)

# check shape
print(f"train   : {X_train_full.shape, y_train_full.shape}\n\
cal     : {X_cal_full.shape, y_cal_full.shape}\n\
test    : {X_test_full.shape, y_test_full.shape}\n\
zero    : {X_zero_full.shape, y_zero_full.shape}\n\
classes : {class_names}\n"
)

df_train.head(3)
# Out:
# train   : ((148729, 10), (148729,))
# cal     : ((18591, 10), (18591,))
# test    : ((18591, 10), (18591,))
# zero    : ((683, 10), (683,))
# classes : ['DDoS', 'DoS', 'Normal', 'Reconnaissance']
#    n_pkts_total  n_bytes_total  src_bytes      rate  pkt_size_min  \
# 0     -0.262256      -0.798644  -0.774964 -0.356930      0.000000
# 1      0.427561      -0.121016   0.000000 -0.123704      0.000000
# 2      0.768961       0.200956   0.368220  1.725276      0.761987
#
#    pkt_size_max  pkt_size_mean  pkt_size_std  protocol  conn_state  \
# 0      0.123458      -0.266091      0.827772       0.0         0.0
# 1      0.120431       0.030826      0.766490       0.0         0.0
# 2      0.244690       0.422755      0.618673       0.0         0.0
#
#   label_multiclass
# 0              DoS
# 1              DoS
# 2             DDoS

# %% [markdown]
# ## EDA (Before Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train_full, class_names,
    title=f"train (n={len(to_np_y(y_train_full))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 4

# %% [markdown]
# ## Scaling

# %%
# fit scaler on full train (raw); transform elsewhere via to_angles()
scaler = StandardScaler()
X_train_full_scaled = scaler.fit_transform(X_train_full)
print(f"scaled full train: {X_train_full_scaled.shape}")
# Out:
# scaled full train: (148729, 10)

# %% [markdown]
# ## PCA (Optional)

# %%
USE_PCA = True   # set to False to skip PCA
TARGET_VARIANCE = 0.95

# %%
if USE_PCA:
    pca_full = PCA(random_state=SEED).fit(X_train_full_scaled)
    ratios = pca_full.explained_variance_ratio_
    cum = np.cumsum(ratios)
    n_feat = len(ratios)

    print(f"features (raw dim): {n_feat}")
    print("explained_variance_ratio_:", np.round(ratios, 4))
    print("cumulative:               ", np.round(cum, 4))
    for k in range(1, n_feat + 1):
        print(f"first {k} PCs keep {cum[k - 1]*100:.2f}% variance")

    # smallest k with >= target variance
    k95 = int(np.searchsorted(cum, TARGET_VARIANCE) + 1)
    k95 = min(k95, len(cum))  # safety
    print(f"components needed for >={TARGET_VARIANCE*100}% variance: {k95}")

    fig, ax = plt.subplots(1, 1, figsize=(8, 5))
    ax.bar(range(1, n_feat + 1), ratios, color="slateblue", alpha=0.7, label="per-PC")
    ax.plot(range(1, n_feat + 1), cum, marker="o", color="darkblue", label="cumulative")
    ax.axhline(TARGET_VARIANCE, color="red", linestyle="--", label=f"Target({TARGET_VARIANCE*100}%)")
    ax.axvline(k95, color="green", linestyle=":", label=f"k={k95}")
    ax.set_xlabel("PCA component")
    ax.set_ylabel("explained variance ratio")
    ax.set_title("PCA explained feature variance")
    ax.legend()
    plt.tight_layout()
    plt.show()

    pca = PCA(n_components=k95, random_state=SEED)
    X_train_full_feat = pca.fit_transform(X_train_full_scaled)
else:
    pca = None
    k95 = X_train_full_scaled.shape[1]
    X_train_full_feat = X_train_full_scaled

# angle bounds from full train feature space (pca or scaled)
x_min, x_max = X_train_full_feat.min(0), X_train_full_feat.max(0)
print(f"feature dim for angles: {X_train_full_feat.shape[1]} | USE_PCA={USE_PCA}")
# Out:
# features (raw dim): 10
# explained_variance_ratio_: [0.3698 0.2823 0.1538 0.0927 0.0827 0.0085 0.0052 0.0034 0.0008 0.0007]
# cumulative:                [0.3698 0.6521 0.8059 0.8986 0.9813 0.9898 0.995  0.9985 0.9993 1.    ]
# first 1 PCs keep 36.98% variance
# first 2 PCs keep 65.21% variance
# first 3 PCs keep 80.59% variance
# first 4 PCs keep 89.86% variance
# first 5 PCs keep 98.13% variance
# first 6 PCs keep 98.98% variance
# first 7 PCs keep 99.50% variance
# first 8 PCs keep 99.85% variance
# first 9 PCs keep 99.93% variance
# first 10 PCs keep 100.00% variance
# components needed for >=95.0% variance: 5
# feature dim for angles: 5 | USE_PCA=True

# %% [markdown]
# ## Data Subset (Optional)

# %%
SUBSET = True   # set to False for the full dataset
PER_CLASS_CAP = 3000

# %%
# compare sampling strategies on RAW full train, then apply DPP coreset
if SUBSET:
    plot_dataset_and_sampling_analysis(
        X_train_full,
        y_train_full,
        per_class_cap=PER_CLASS_CAP,
        class_names=class_names,
        seed=SEED,
    )

    print(f"\nRunning representative DPP coreset sampling (cap={PER_CLASS_CAP})...")
    X_train, y_train = greedy_dpp_sample(
        X_train_full, y_train_full, per_class_cap=PER_CLASS_CAP, seed=SEED
    )
    print(f"Coreset selected: {X_train.shape[0]} samples.")
else:
    X_train, y_train = X_train_full, y_train_full
    print(f"using full train (no subset): {X_train.shape[0]} samples")

print(f"train raw: {X_train.shape, y_train.shape} | SUBSET={SUBSET} | cap={PER_CLASS_CAP if SUBSET else 'all'}")
# Out:
# Running representative DPP coreset sampling (cap=3000)...
# Coreset selected: 11832 samples.
# train raw: ((11832, 10), (11832,)) | SUBSET=True | cap=3000

# %% [markdown]
# ## EDA (After Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train, class_names,
    title=f"train subset (n={len(to_np_y(y_train))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 4

# %% [markdown]
# ## Mapping Features $\rightarrow$ [0, $\pi$]

# %%
# raw -> scale -> optional pca -> [0, pi] using bounds from full train
X_train_angles = to_angles(
    X_train, scaler, x_min, x_max, pca=pca if USE_PCA else None, angle_max=np.pi
)

print(f"angles: {X_train_angles.shape} | USE_PCA={USE_PCA} | SUBSET={SUBSET}")

fig, ax1 = plt.subplots(1, 1, figsize=(7, 4))
ax1.hist(X_train_angles.flatten(), bins=50, color="teal", alpha=0.8)
ax1.set_xlabel("angle (radians)")
ax1.set_title("Angle-encoded train feature distribution")
plt.tight_layout()
plt.show()
# Out:
# angles: (11832, 5) | USE_PCA=True | SUBSET=True

# %% [markdown]
# ## Quantum Circuit: Angle Encoding, Data Reuploading, and Adding Noise
#
# $x\xrightarrow[\text{encode}]{\phi(x)}\ket{\psi(x)}\xrightarrow[\text{variational}]{U(\theta)}\ket{\Phi(x)}\xrightarrow{\Lambda_p}\rho(x)$
# - $x$: classical data
# - $\phi(x)$: `qp.AngleEmbedding()`
# - $\ket{\psi(x)}$: quantum state after encoding
# - $U(\theta)$: `qp.StronglyEntanglingLayers()`
# - $\ket{\Phi(x)}$: quantum state after variational transform
# - $\rho(x)=\Lambda_p(\ket{\Phi(x)}\bra{\Phi(x)})$: standard depolarization channel to model NISQ noise

# %%
num_qubits = int(k95)           # pca comps if USE_PCA; else scaled feature dim
num_layers = 2                  # reupload same classical data
noise_rate = DEFAULT_NOISE_RATE
print(f"num_qubits={num_qubits} (USE_PCA={USE_PCA})")
# Out:
# num_qubits=5 (USE_PCA=True)

# %%
# initialize devices
device = get_torch_device()
dev = create_quantum_device(num_qubits) # or dev = qp.device("default.mixed", wires=num_qubits)

# define circuit
forward_circuit = build_forward_circuit(dev, num_qubits, num_layers, noise_rate=noise_rate)

# %% [markdown]
# ## Gradient Variance Probe

# %%
barren_plateau_var = BARREN_PLATEAU_VAR_THRESHOLD
n_trials = 5

safe_empty_cache()

# probe on CPU (recommended)
x_probe = X_train_angles[:1]

try:
    grad_var, grad_samples = gradient_variance_probe(
        forward_circuit, x_probe, num_qubits, num_layers,
        n_trials=n_trials,
        device=torch.device("cpu"),
    )

    print(f"pre-train grad var = {grad_var:.2e} (thr={barren_plateau_var:.0e})")
    if grad_var < barren_plateau_var:
        print("warning: possible barren plateau architecture")

    plt.figure(figsize=(6, 4)); plt.hist(grad_samples, bins=15, color="darkcyan", alpha=0.8)
    plt.title(f"Gradient-variance probe (var={grad_var:.2e})"); plt.tight_layout(); plt.show()

except RuntimeError as e:
    if is_oom_error(e):
        print("\t[OOM] barren-plateau probe skipped (non-critical diagnostic).")
        safe_empty_cache()
    else:
        raise
# Out:
# pre-train grad var = 3.54e-14 (thr=1e-06)
# warning: possible barren plateau architecture

# %% [markdown]
# ## Training
#
# $$
# L = L_{CE}
# $$
#
# CE-only baseline: same quantum circuit + classical head as MAQT, no prototype losses.
#
# Minimizing $L_{CE}$ adjusts $\theta$ for better class predictions.

# %%
epochs = 50
batch_size = 64
lr = DEFAULT_LR
early_stopping = True
patience = 5
min_delta = 0.001

out_dir = Path("models/prototypes") / dataset
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_dir = out_dir / f"{NOTEBOOK_NAME}_seed{SEED}"
latest_ckpt = ckpt_dir / "plain-latest.pt"
resume_from = latest_ckpt if latest_ckpt.exists() else None

print(f"checkpoint_dir: {ckpt_dir}")
print(f"resume_from: {resume_from}")
# Out:
# checkpoint_dir: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42
# resume_from: None

# %%
torch.manual_seed(SEED)

result = run_batched_safely(
    train_plain_vqc,
    X_train_angles,
    y_train,
    n_classes=num_classes,
    n_qubits=num_qubits,
    n_layers=num_layers,
    forward_circuit=forward_circuit,
    device=device,
    epochs=epochs,
    lr=lr,
    batch_size=batch_size,
    min_batch=2,
    label="train_plain_vqc",
    use_weighted_sampler=True,
    seed=SEED,
    early_stopping=early_stopping,
    patience=patience,
    min_delta=min_delta,
    checkpoint_dir=ckpt_dir,
    save_every_epoch=True,
    resume_from=resume_from,
    reset_early_stopping_on_resume=True,
    heartbeat_every_steps=50,  # pass None to less verbose
    notebook_name=NOTEBOOK_NAME,
    log_dir=ckpt_dir,
)

if result is None:
    raise RuntimeError("train_plain_vqc failed even at min_batch (OOM)")

theta, head, history = result
theta_star = theta
classifier_head = head
safe_empty_cache()
print(
    "\n"
    f"epochs_ran={history.get('epochs_ran')} | "
    f"best_epoch={history.get('best_epoch')} | "
    f"stopped_early={history.get('stopped_early')} | "
    f"stop_reason={history.get('stop_reason')}"
)
# Out:
# 	epoch 1 step 50 (27%) loss=0.8465 elapsed=5s eta=15s
# 	epoch 1 step 100 (54%) loss=0.7152 elapsed=11s eta=9s
# 	epoch 1 step 150 (81%) loss=0.7321 elapsed=17s eta=4s
# epoch  1/50 | time 20.6s | loss 0.7696 | L_CE 0.7696 | grad_var 1.72e-03 | peak_mem=49MB | best=0.7696@ep1 | bad=0/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch001.pt
# 	epoch 2 step 50 (27%) loss=0.5417 elapsed=6s eta=15s
# 	epoch 2 step 100 (54%) loss=0.6460 elapsed=11s eta=9s
# 	epoch 2 step 150 (81%) loss=0.5447 elapsed=16s eta=4s
# epoch  2/50 | time 19.9s | loss 0.5752 | L_CE 0.5752 | grad_var 3.45e-03 | peak_mem=49MB | best=0.5752@ep2 | bad=0/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch002.pt
# 	epoch 3 step 50 (27%) loss=0.4354 elapsed=5s eta=14s
# 	epoch 3 step 100 (54%) loss=0.5328 elapsed=11s eta=9s
# 	epoch 3 step 150 (81%) loss=0.5207 elapsed=16s eta=4s
# epoch  3/50 | time 19.5s | loss 0.5322 | L_CE 0.5322 | grad_var 5.08e-03 | peak_mem=49MB | best=0.5322@ep3 | bad=0/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch003.pt
# 	epoch 4 step 50 (27%) loss=0.4925 elapsed=5s eta=14s
# 	epoch 4 step 100 (54%) loss=0.5092 elapsed=10s eta=9s
# 	epoch 4 step 150 (81%) loss=0.5207 elapsed=16s eta=4s
# epoch  4/50 | time 19.3s | loss 0.5190 | L_CE 0.5190 | grad_var 6.84e-03 | peak_mem=49MB | best=0.5190@ep4 | bad=0/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch004.pt
# 	epoch 5 step 50 (27%) loss=0.5746 elapsed=5s eta=14s
# 	epoch 5 step 100 (54%) loss=0.4475 elapsed=10s eta=9s
# 	epoch 5 step 150 (81%) loss=0.3872 elapsed=16s eta=4s
# epoch  5/50 | time 19.4s | loss 0.5081 | L_CE 0.5081 | grad_var 6.43e-03 | peak_mem=49MB | best=0.5081@ep5 | bad=0/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch005.pt
# 	epoch 6 step 50 (27%) loss=0.5301 elapsed=5s eta=14s
# 	epoch 6 step 100 (54%) loss=0.5712 elapsed=10s eta=9s
# 	epoch 6 step 150 (81%) loss=0.4874 elapsed=16s eta=4s
# epoch  6/50 | time 19.4s | loss 0.4901 | L_CE 0.4901 | grad_var 6.49e-03 | peak_mem=49MB | best=0.4901@ep6 | bad=0/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch006.pt
# 	epoch 7 step 50 (27%) loss=0.4492 elapsed=5s eta=14s
# 	epoch 7 step 100 (54%) loss=0.4717 elapsed=11s eta=9s
# 	epoch 7 step 150 (81%) loss=0.4463 elapsed=16s eta=4s
# epoch  7/50 | time 19.8s | loss 0.4962 | L_CE 0.4962 | grad_var 8.09e-03 | peak_mem=49MB | best=0.4901@ep6 | bad=1/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch007.pt
# 	epoch 8 step 50 (27%) loss=0.4727 elapsed=5s eta=14s
# 	epoch 8 step 100 (54%) loss=0.4641 elapsed=11s eta=9s
# 	epoch 8 step 150 (81%) loss=0.4180 elapsed=16s eta=4s
# epoch  8/50 | time 19.3s | loss 0.4945 | L_CE 0.4945 | grad_var 8.14e-03 | peak_mem=49MB | best=0.4901@ep6 | bad=2/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch008.pt
# 	epoch 9 step 50 (27%) loss=0.4094 elapsed=5s eta=14s
# 	epoch 9 step 100 (54%) loss=0.5335 elapsed=10s eta=9s
# 	epoch 9 step 150 (81%) loss=0.6090 elapsed=16s eta=4s
# epoch  9/50 | time 19.3s | loss 0.4972 | L_CE 0.4972 | grad_var 8.55e-03 | peak_mem=49MB | best=0.4901@ep6 | bad=3/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch009.pt
# 	epoch 10 step 50 (27%) loss=0.6103 elapsed=5s eta=14s
# 	epoch 10 step 100 (54%) loss=0.4107 elapsed=10s eta=9s
# 	epoch 10 step 150 (81%) loss=0.5788 elapsed=16s eta=4s
# epoch 10/50 | time 19.8s | loss 0.4939 | L_CE 0.4939 | grad_var 1.04e-02 | peak_mem=49MB | best=0.4901@ep6 | bad=4/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch010.pt
# 	epoch 11 step 50 (27%) loss=0.4946 elapsed=5s eta=14s
# 	epoch 11 step 100 (54%) loss=0.3662 elapsed=10s eta=9s
# 	epoch 11 step 150 (81%) loss=0.5252 elapsed=16s eta=4s
# epoch 11/50 | time 19.2s | loss 0.4793 | L_CE 0.4793 | grad_var 7.78e-03 | peak_mem=49MB | best=0.4793@ep11 | bad=0/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch011.pt
# 	epoch 12 step 50 (27%) loss=0.3855 elapsed=5s eta=14s
# 	epoch 12 step 100 (54%) loss=0.4844 elapsed=10s eta=9s
# 	epoch 12 step 150 (81%) loss=0.5154 elapsed=16s eta=4s
# epoch 12/50 | time 19.4s | loss 0.4912 | L_CE 0.4912 | grad_var 9.99e-03 | peak_mem=49MB | best=0.4793@ep11 | bad=1/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch012.pt
# 	epoch 13 step 50 (27%) loss=0.4576 elapsed=5s eta=14s
# 	epoch 13 step 100 (54%) loss=0.5030 elapsed=10s eta=9s
# 	epoch 13 step 150 (81%) loss=0.5356 elapsed=16s eta=4s
# epoch 13/50 | time 19.4s | loss 0.4893 | L_CE 0.4893 | grad_var 9.72e-03 | peak_mem=49MB | best=0.4793@ep11 | bad=2/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch013.pt
# 	epoch 14 step 50 (27%) loss=0.4972 elapsed=5s eta=14s
# 	epoch 14 step 100 (54%) loss=0.4918 elapsed=10s eta=9s
# 	epoch 14 step 150 (81%) loss=0.3942 elapsed=16s eta=4s
# epoch 14/50 | time 19.5s | loss 0.4938 | L_CE 0.4938 | grad_var 1.04e-02 | peak_mem=49MB | best=0.4793@ep11 | bad=3/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch014.pt
# 	epoch 15 step 50 (27%) loss=0.3835 elapsed=5s eta=15s
# 	epoch 15 step 100 (54%) loss=0.5860 elapsed=11s eta=9s
# 	epoch 15 step 150 (81%) loss=0.3121 elapsed=16s eta=4s
# epoch 15/50 | time 19.8s | loss 0.4877 | L_CE 0.4877 | grad_var 9.90e-03 | peak_mem=49MB | best=0.4793@ep11 | bad=4/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch015.pt
# 	epoch 16 step 50 (27%) loss=0.5090 elapsed=5s eta=14s
# 	epoch 16 step 100 (54%) loss=0.5368 elapsed=11s eta=9s
# 	epoch 16 step 150 (81%) loss=0.5227 elapsed=16s eta=4s
# epoch 16/50 | time 19.5s | loss 0.4728 | L_CE 0.4728 | grad_var 8.95e-03 | peak_mem=49MB | best=0.4728@ep16 | bad=0/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch016.pt
# 	epoch 17 step 50 (27%) loss=0.4392 elapsed=5s eta=14s
# 	epoch 17 step 100 (54%) loss=0.9270 elapsed=11s eta=9s
# 	epoch 17 step 150 (81%) loss=0.4413 elapsed=16s eta=4s
# epoch 17/50 | time 19.8s | loss 0.4832 | L_CE 0.4832 | grad_var 8.64e-03 | peak_mem=49MB | best=0.4728@ep16 | bad=1/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch017.pt
# 	epoch 18 step 50 (27%) loss=0.5645 elapsed=5s eta=14s
# 	epoch 18 step 100 (54%) loss=0.5190 elapsed=11s eta=9s
# 	epoch 18 step 150 (81%) loss=0.5124 elapsed=16s eta=4s
# epoch 18/50 | time 19.4s | loss 0.4820 | L_CE 0.4820 | grad_var 1.05e-02 | peak_mem=49MB | best=0.4728@ep16 | bad=2/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch018.pt
# 	epoch 19 step 50 (27%) loss=0.4625 elapsed=5s eta=14s
# 	epoch 19 step 100 (54%) loss=0.4944 elapsed=10s eta=9s
# 	epoch 19 step 150 (81%) loss=0.3640 elapsed=16s eta=4s
# epoch 19/50 | time 19.4s | loss 0.4836 | L_CE 0.4836 | grad_var 1.12e-02 | peak_mem=49MB | best=0.4728@ep16 | bad=3/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch019.pt
# 	epoch 20 step 50 (27%) loss=0.5017 elapsed=5s eta=14s
# 	epoch 20 step 100 (54%) loss=0.5795 elapsed=11s eta=9s
# 	epoch 20 step 150 (81%) loss=0.6261 elapsed=16s eta=4s
# epoch 20/50 | time 19.8s | loss 0.4973 | L_CE 0.4973 | grad_var 1.08e-02 | peak_mem=49MB | best=0.4728@ep16 | bad=4/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch020.pt
# 	epoch 21 step 50 (27%) loss=0.4753 elapsed=5s eta=14s
# 	epoch 21 step 100 (54%) loss=0.5019 elapsed=11s eta=9s
# 	epoch 21 step 150 (81%) loss=0.5473 elapsed=16s eta=4s
# epoch 21/50 | time 19.7s | loss 0.4816 | L_CE 0.4816 | grad_var 1.11e-02 | peak_mem=49MB | best=0.4728@ep16 | bad=5/5
#   saved checkpoint: models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot_seed42/plain-epoch021.pt
# early stopping at epoch 21: no train-loss improvement for 5 epochs (best=0.4728 @ epoch 16)
# restored best plain-VQC weights from epoch 16 (train loss=0.4728)
#
# epochs_ran=21 | best_epoch=16 | stopped_early=True | stop_reason=early_stopping

# %% [markdown]
# ## Prototypes
#
# Class-mean prototypes are computed post-hoc after CE training for later Algo-3 / geometry compare.

# %%
# post-hoc class-mean prototypes under frozen CE theta
proto_bank = PrototypeBank(classes=range(num_classes))
prototypes = proto_bank.compute(
    theta_star, X_train_angles, y_train, forward_circuit,
    device=device, batch_size=batch_size,
)

# %%
proto_df = pd.DataFrame(prototype_summary(prototypes, class_names))
proto_df
# Out:
#             class  dim     trace
# 0            DDoS   32  1.000001
# 1             DoS   32  1.000001
# 2          Normal   32  1.000001
# 3  Reconnaissance   32  1.000001

# %%
# save prototypes (all-in-one checkpoint)
out_dir = Path("models/prototypes") / dataset
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_path = out_dir / f"{NOTEBOOK_NAME}-checkpoint.pt"
torch.save(
    {
        "theta": theta_star.detach().cpu(),
        "head_state_dict": head.state_dict(),
        "prototypes": {k: v.detach().cpu() for k, v in prototypes.items()},
        "train_mode": "CE-only",

        # rebuild / inference meta
        "class_names": list(class_names),
        "num_classes": num_classes,
        "num_qubits": num_qubits,
        "num_layers": num_layers,
        "noise_rate": noise_rate,

        # FROZEN feature + angle pipeline (must match train)
        "feature_cols": list(FEATURE_COLS),
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "target_col": target_col,
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "scaler": scaler,                    # StandardScaler fitted on full train
        "pca": pca,                          # PCA fitted on scaled full train (or None)
        "k95": int(k95),
        "angle_x_min": np.asarray(x_min),    # on pca space if USE_PCA else scaled space
        "angle_x_max": np.asarray(x_max),
        "angle_min": 0.0,
        "angle_max": float(np.pi),
    },
    ckpt_path,
)
print("published:", ckpt_path.resolve())
# Out:
# published: /home/lawun330/Desktop/quantum-sentinel/models/prototypes/BoT-IoT/26.ce-FROZEN-feat-prototypes_bot-iot-checkpoint.pt

# %% [markdown]
# ## Visualization

# %%
# plots
epochs_x = range(1, len(history["loss"]) + 1)

fig, axes = plt.subplots(1, 3, figsize=(14, 4))

# total loss (= CE for this baseline)
axes[0].plot(epochs_x, history["loss"], marker="o")
axes[0].set_title("Total loss ($L_{CE}$)")
axes[0].set_xlabel("Epoch")

# CE curve
axes[1].plot(epochs_x, history["loss"], marker=None, label=r"$L$")
axes[1].plot(epochs_x, history["L_CE"], "--", label=r"$L_{CE}")
axes[1].set_title(r"$L = L_{CE}$ (CE-only)")
axes[1].legend(fontsize=8)

# grad var
axes[2].plot(epochs_x, history["grad_var"], marker="o", color="tab:orange")
axes[2].axhline(1e-6, color="red", linestyle="--", label="plateau thr")  # or BARREN_PLATEAU_VAR_THRESHOLD
axes[2].set_title("Gradient variance")
axes[2].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Logging

# %%
# write log (final)
log_path = write_history_log(
    history,
    NOTEBOOK_NAME,
    extra={
        ## data
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "dataset": dataset,
        "feature_cols": FEATURE_COLS,
        "target_col": target_col,
        "n_train": len(X_train),
        "class_names": list(class_names),
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "num_qubits": num_qubits,
        "k95": int(k95),

        # algo: CE-only train
        "train_mode": "CE-only",
        "epochs": epochs,
        "batch_size": batch_size,
        "lr": lr,

        ## quantum model
        "noise_rate": noise_rate,
        "num_layers": num_layers,
        "num_classes": num_classes,

        ## training
        "train_total_sec": float(sum(history["epoch_sec"])) if history.get("epoch_sec") else None,
        "loss_last": float(history["loss"][-1]) if history["loss"] else None,
        "barren_plateau_var": barren_plateau_var,
        "barren_plateau_any": bool(
            any(g < barren_plateau_var for g in history["grad_var"])
        ) if history.get("grad_var") else None,
        "seed": SEED,
        "early_stopping": early_stopping,
        "patience": patience,
        "best_epoch": history.get("best_epoch"),
        "best_score": history.get("best_score"),
        "stopped_early": history.get("stopped_early"),
        "epochs_ran": history.get("epochs_ran"),
        "stop_reason": history.get("stop_reason"),
        "interrupted": history.get("interrupted"),
        "checkpoint_dir": str(ckpt_dir),
    },
    log_dir="logs",
)
print(f"wrote {log_path.resolve()}")
# Out:
# wrote /home/lawun330/Desktop/quantum-sentinel/logs/26.ce-FROZEN-feat-prototypes_bot-iot.log
