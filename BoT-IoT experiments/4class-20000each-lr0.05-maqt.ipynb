# %% [markdown]
# # MAQT Prototypes with FROZEN Features: BoT-IoT
# # Experiment: More Samples
# ## Capped Sample (20,000) | ~48,000 Train | Batch Size 64
# ## 50 Epochs (Early Stopping with Patience = 5) | LR 0.05
# ## Target (y) = "label_multiclass" | Data Reupload = 2

# %% [markdown]
# ## Setup

# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import torch
from pennylane import numpy as np
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from scripts.circuit import build_forward_circuit, create_quantum_device
from scripts.constants import (
    BARREN_PLATEAU_VAR_THRESHOLD,
    DEFAULT_LR,
    DEFAULT_NOISE_RATE,
)
from scripts.data import (
    greedy_dpp_sample,
    load_split,
    plot_class_balance_pie,
    plot_dataset_and_sampling_analysis,
    to_angles,
)
from scripts.gradient import gradient_variance_probe
from scripts.logging import write_history_log
from scripts.memory import is_oom_error, run_batched_safely, safe_empty_cache
from scripts.prototypes import prototype_summary
from scripts.theory import verify_fidelity_convention
from scripts.train import train_maqt
from scripts.utils import get_torch_device, to_np_y

# %%
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available?: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA device name: {torch.cuda.get_device_name(0)}")
    print(f"Current CUDA device index: {torch.cuda.current_device()}")
# Out:
# PyTorch version: 2.12.1+cu126
# CUDA available?: True
# CUDA device name: NVIDIA GeForce GTX 1060
# Current CUDA device index: 0

# %% [markdown]
# ## Config

# %%
NOTEBOOK_NAME = "4class-20000each-lr0.05-maqt"

dataset = "BoT-IoT"
target_col = "label_multiclass"
data_path = f"data/FROZEN/{dataset}"
frozen_feat_path = "team-artifacts/teamC_week3_FROZEN_handoff.json"

SEED = 42

# %%
check = verify_fidelity_convention(dim=4, n_trials=30, seed=SEED)
print("Fidelity-convention self-check PASSED:", check)
# Out:
# Fidelity-convention self-check PASSED: {'max_pairwise_disagreement': 0.0, 'max_fvg_violation': 0.0}

# %% [markdown]
# ## Load Team C's FROZEN Features

# %%
handoff = json.loads(Path(frozen_feat_path).read_text())
FEATURE_COLS = list(handoff["frozen_subsets"][dataset]["features"])
print(f"Team C selector: {handoff['frozen_subsets'][dataset]['selector']}")
print(f"k={len(FEATURE_COLS)} features: {FEATURE_COLS}")
# Out:
# Team C selector: QIGPSO
# k=10 features: ['n_pkts_total', 'n_bytes_total', 'src_bytes', 'rate', 'pkt_size_min', 'pkt_size_max', 'pkt_size_mean', 'pkt_size_std', 'protocol', 'conn_state']

# %% [markdown]
# ## Load Team A's FROZEN Dataset

# %%
# load all data
X_train_full, y_train_full, class_names, df_train = load_split(
    data_path, "train", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_cal_full, y_cal_full, _, df_cal = load_split(
    data_path,
    "calibration",
    target_col,
    csv=True,
    selected_cols=FEATURE_COLS,
    return_df=True,
)
X_test_full, y_test_full, _, df_test = load_split(
    data_path, "test", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_zero_full, y_zero_full, _, df_zero = load_split(
    data_path,
    "zeroday",
    target_col,
    csv=True,
    selected_cols=FEATURE_COLS,
    return_df=True,
)

# check shape
print(
    f"train   : {X_train_full.shape, y_train_full.shape}\n\
cal     : {X_cal_full.shape, y_cal_full.shape}\n\
test    : {X_test_full.shape, y_test_full.shape}\n\
zero    : {X_zero_full.shape, y_zero_full.shape}\n\
classes : {class_names}\n"
)

df_train.head(3)
# Out:
# train   : ((148729, 10), (148729,))
# cal     : ((18591, 10), (18591,))
# test    : ((18591, 10), (18591,))
# zero    : ((683, 10), (683,))
# classes : ['DDoS', 'DoS', 'Normal', 'Reconnaissance']
#    n_pkts_total  n_bytes_total  src_bytes      rate  pkt_size_min  \
# 0     -0.262256      -0.798644  -0.774964 -0.356930      0.000000
# 1      0.427561      -0.121016   0.000000 -0.123704      0.000000
# 2      0.768961       0.200956   0.368220  1.725276      0.761987
#
#    pkt_size_max  pkt_size_mean  pkt_size_std  protocol  conn_state  \
# 0      0.123458      -0.266091      0.827772       0.0         0.0
# 1      0.120431       0.030826      0.766490       0.0         0.0
# 2      0.244690       0.422755      0.618673       0.0         0.0
#
#   label_multiclass
# 0              DoS
# 1              DoS
# 2             DDoS

# %% [markdown]
# ## EDA (Before Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train_full,
    class_names,
    title=f"train (n={len(to_np_y(y_train_full))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 4

# %% [markdown]
# ## Scaling

# %%
# fit scaler on full train (raw); transform elsewhere via to_angles()
scaler = StandardScaler()
X_train_full_scaled = scaler.fit_transform(X_train_full)
print(f"scaled full train: {X_train_full_scaled.shape}")
# Out:
# scaled full train: (148729, 10)

# %% [markdown]
# ## PCA (Optional)

# %%
USE_PCA = True  # set to False to skip PCA
TARGET_VARIANCE = 0.95

# %%
if USE_PCA:
    pca_full = PCA(random_state=SEED).fit(X_train_full_scaled)
    ratios = pca_full.explained_variance_ratio_
    cum = np.cumsum(ratios)
    n_feat = len(ratios)

    print(f"features (raw dim): {n_feat}")
    print("explained_variance_ratio_:", np.round(ratios, 4))
    print("cumulative:               ", np.round(cum, 4))
    for k in range(1, n_feat + 1):
        print(f"first {k} PCs keep {cum[k - 1] * 100:.2f}% variance")

    # smallest k with >= target variance
    k95 = int(np.searchsorted(cum, TARGET_VARIANCE) + 1)
    k95 = min(k95, len(cum))  # safety
    print(f"components needed for >={TARGET_VARIANCE * 100}% variance: {k95}")

    fig, ax = plt.subplots(1, 1, figsize=(8, 5))
    ax.bar(range(1, n_feat + 1), ratios, color="slateblue", alpha=0.7, label="per-PC")
    ax.plot(range(1, n_feat + 1), cum, marker="o", color="darkblue", label="cumulative")
    ax.axhline(
        TARGET_VARIANCE,
        color="red",
        linestyle="--",
        label=f"Target({TARGET_VARIANCE * 100}%)",
    )
    ax.axvline(k95, color="green", linestyle=":", label=f"k={k95}")
    ax.set_xlabel("PCA component")
    ax.set_ylabel("explained variance ratio")
    ax.set_title("PCA explained feature variance")
    ax.legend()
    plt.tight_layout()
    plt.show()

    pca = PCA(n_components=k95, random_state=SEED)
    X_train_full_feat = pca.fit_transform(X_train_full_scaled)
else:
    pca = None
    k95 = X_train_full_scaled.shape[1]
    X_train_full_feat = X_train_full_scaled

# angle bounds from full train feature space (pca or scaled)
x_min, x_max = X_train_full_feat.min(0), X_train_full_feat.max(0)
print(f"feature dim for angles: {X_train_full_feat.shape[1]} | USE_PCA={USE_PCA}")
# Out:
# features (raw dim): 10
# explained_variance_ratio_: [0.3698 0.2823 0.1538 0.0927 0.0827 0.0085 0.0052 0.0034 0.0008 0.0007]
# cumulative:                [0.3698 0.6521 0.8059 0.8986 0.9813 0.9898 0.995  0.9985 0.9993 1.    ]
# first 1 PCs keep 36.98% variance
# first 2 PCs keep 65.21% variance
# first 3 PCs keep 80.59% variance
# first 4 PCs keep 89.86% variance
# first 5 PCs keep 98.13% variance
# first 6 PCs keep 98.98% variance
# first 7 PCs keep 99.50% variance
# first 8 PCs keep 99.85% variance
# first 9 PCs keep 99.93% variance
# first 10 PCs keep 100.00% variance
# components needed for >=95.0% variance: 5
# feature dim for angles: 5 | USE_PCA=True

# %% [markdown]
# ## Data Subset (Optional)

# %%
SUBSET = True  # set to False for the full dataset
PER_CLASS_CAP = 20000

# %%
# compare sampling strategies on RAW full train, then apply DPP coreset
if SUBSET:
    plot_dataset_and_sampling_analysis(
        X_train_full,
        y_train_full,
        per_class_cap=PER_CLASS_CAP,
        class_names=class_names,
        seed=SEED,
    )

    print(f"\nRunning representative DPP coreset sampling (cap={PER_CLASS_CAP})...")
    X_train, y_train = greedy_dpp_sample(
        X_train_full, y_train_full, per_class_cap=PER_CLASS_CAP, seed=SEED
    )
    print(f"Coreset selected: {X_train.shape[0]} samples.")
else:
    X_train, y_train = X_train_full, y_train_full
    print(f"using full train (no subset): {X_train.shape[0]} samples")

print(
    f"train raw: {X_train.shape, y_train.shape} | SUBSET={SUBSET} | cap={PER_CLASS_CAP if SUBSET else 'all'}"
)
# Out:
# Running representative DPP coreset sampling (cap=20000)...
# Coreset selected: 48359 samples.
# train raw: ((48359, 10), (48359,)) | SUBSET=True | cap=20000

# %% [markdown]
# ## EDA (After Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train,
    class_names,
    title=f"train (n={len(to_np_y(y_train))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 4

# %% [markdown]
# ## Mapping Features $\rightarrow$ [0, $\pi$]

# %%
# raw -> scale -> optional pca -> [0, pi] using bounds from full train
X_train_angles_all = to_angles(
    X_train, scaler, x_min, x_max, pca=pca if USE_PCA else None, angle_max=np.pi
)

# seeded stratified holdout from train for early stopping (cal/test untouched)
VAL_FRAC = 0.1
_y_all = y_train
idx = np.arange(len(X_train_angles_all))
idx_fit, idx_val = train_test_split(
    idx,
    test_size=VAL_FRAC,
    stratify=_y_all,
    random_state=SEED,
)
X_train_angles, y_train = X_train_angles_all[idx_fit], _y_all[idx_fit]
X_val_angles, y_val = X_train_angles_all[idx_val], _y_all[idx_val]
print(
    f"angles fit: {X_train_angles.shape} | val: {X_val_angles.shape} | "
    f"VAL_FRAC={VAL_FRAC} | USE_PCA={USE_PCA} | SUBSET={SUBSET}"
)

fig, ax1 = plt.subplots(1, 1, figsize=(7, 4))
ax1.hist(X_train_angles.flatten(), bins=50, color="teal", alpha=0.8)
ax1.set_xlabel("angle (radians)")
ax1.set_title("Angle-encoded train (fit) feature distribution")
plt.tight_layout()
plt.show()
# Out:
# angles fit: (43523, 5) | val: (4836, 5) | VAL_FRAC=0.1 | USE_PCA=True | SUBSET=True

# %% [markdown]
# ## Quantum Circuit: Angle Encoding, Data Reuploading, and Adding Noise
#
# $$
# x\xrightarrow[\text{encode}]{\phi(x)}\ket{\psi(x)}\xrightarrow[\text{variational}]{U(\theta)}\ket{\Phi(x)}\xrightarrow{\Lambda_p}\rho(x)
# $$
# - $x$: classical data
# - $\phi(x)$: `qp.AngleEmbedding()`
# - $\ket{\psi(x)}$: quantum state after encoding
# - $U(\theta)$: `qp.StronglyEntanglingLayers()`
# - $\ket{\Phi(x)}$: quantum state after variational transform
# - $\rho(x)=\Lambda_p(\ket{\Phi(x)}\bra{\Phi(x)})$: standard depolarization channel to model NISQ noise

# %%
num_qubits = int(k95)  # pca comps if USE_PCA; else scaled feature dim
num_layers = 2  # reupload same classical data
noise_rate = DEFAULT_NOISE_RATE
print(f"num_qubits={num_qubits} (USE_PCA={USE_PCA})")
# Out:
# num_qubits=5 (USE_PCA=True)

# %%
# initialize devices
device = get_torch_device()
dev = create_quantum_device(
    num_qubits
)  # or dev = qp.device("default.mixed", wires=num_qubits)

# define circuit
forward_circuit = build_forward_circuit(
    dev, num_qubits, num_layers, noise_rate=noise_rate
)

# %% [markdown]
# ## Gradient Variance Probe

# %%
barren_plateau_var = BARREN_PLATEAU_VAR_THRESHOLD
n_trials = 5

safe_empty_cache()

# probe on CPU (recommended)
x_probe = X_train_angles[:1]

try:
    grad_var, grad_samples = gradient_variance_probe(
        forward_circuit,
        x_probe,
        num_qubits,
        num_layers,
        n_trials=n_trials,
        device=torch.device("cpu"),
    )

    print(f"pre-train grad var = {grad_var:.2e} (thr={barren_plateau_var:.0e})")
    if grad_var < barren_plateau_var:
        print("warning: possible barren plateau architecture")

    plt.figure(figsize=(6, 4))
    plt.hist(grad_samples, bins=15, color="darkcyan", alpha=0.8)
    plt.title(f"Gradient-variance probe (var={grad_var:.2e})")
    plt.tight_layout()
    plt.show()

except RuntimeError as e:
    if is_oom_error(e):
        print("\t[OOM] barren-plateau probe skipped (non-critical diagnostic).")
        safe_empty_cache()
    else:
        raise
# Out:
# pre-train grad var = 3.14e-09 (thr=1e-06)
# warning: possible barren plateau architecture

# %% [markdown]
# ## Training
#
# $$
# L = L_{CE} + \lambda_1*L_{intra} + \lambda_2*L_{inter}
# $$
#
# Minimizing:
# - $L_{CE}$ adjusts $\theta$ for better class predictions.
# - $L_{intra}$ pulls each sample toward its class prototype
# - $L_{inter}$ pushs different-class prototypes apart (maximize trace distance)

# %%
epochs = 50
batch_size = 64
lr = DEFAULT_LR
lambda1 = 0.5
lambda2 = 0.02
early_stopping = True
patience = 5
min_delta = 0.001

out_dir = Path("artifacts") / dataset
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_dir = out_dir / f"{NOTEBOOK_NAME}_seed{SEED}"
latest_ckpt = ckpt_dir / "maqt-latest.pt"
resume_from = latest_ckpt if latest_ckpt.exists() else None

print(f"checkpoint_dir: {ckpt_dir}")
print(f"resume_from: {resume_from}")
# Out:
# checkpoint_dir: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42
# resume_from: None

# %%
torch.manual_seed(SEED)

result = run_batched_safely(
    train_maqt,
    X_train_angles,
    y_train,
    n_classes=num_classes,
    n_qubits=num_qubits,
    n_layers=num_layers,
    forward_circuit=forward_circuit,
    device=device,
    epochs=epochs,
    lr=lr,
    batch_size=batch_size,
    min_batch=2,
    label="train_maqt",
    lambda1_max=lambda1,
    lambda2_max=lambda2,
    use_weighted_sampler=True,
    seed=SEED,
    early_stopping=early_stopping,
    patience=patience,
    min_delta=min_delta,
    X_val=X_val_angles,
    y_val=y_val,
    checkpoint_dir=ckpt_dir,
    save_every_epoch=True,
    resume_from=resume_from,
    reset_early_stopping_on_resume=True,
    heartbeat_every_steps=20,  # pass None to less verbose
    notebook_name=NOTEBOOK_NAME,
    log_dir=ckpt_dir,
)

if result is None:
    raise RuntimeError("train_maqt failed even at min_batch (OOM)")

theta, head, prototypes, ema_protos, history = result
theta_star = theta
classifier_head = head
safe_empty_cache()
print(
    "\n"
    f"epochs_ran={history.get('epochs_ran')} | "
    f"best_epoch={history.get('best_epoch')} | "
    f"stopped_early={history.get('stopped_early')} | "
    f"stop_reason={history.get('stop_reason')}"
)
# Out:
# 	epoch 1 step 20 (3%) loss=1.0068 elapsed=11s eta=376s
# 	epoch 1 step 40 (6%) loss=0.8134 elapsed=23s eta=370s
# 	epoch 1 step 60 (9%) loss=0.7825 elapsed=35s eta=361s
# 	epoch 1 step 80 (12%) loss=0.6689 elapsed=46s eta=348s
# 	epoch 1 step 100 (15%) loss=0.6875 elapsed=58s eta=335s
# 	epoch 1 step 120 (18%) loss=0.7022 elapsed=69s eta=322s
# 	epoch 1 step 140 (21%) loss=0.6448 elapsed=81s eta=311s
# 	epoch 1 step 160 (24%) loss=0.5344 elapsed=92s eta=300s
# 	epoch 1 step 180 (26%) loss=0.5415 elapsed=104s eta=288s
# 	epoch 1 step 200 (29%) loss=0.5949 elapsed=115s eta=276s
# 	epoch 1 step 220 (32%) loss=0.6711 elapsed=126s eta=264s
# 	epoch 1 step 240 (35%) loss=0.5962 elapsed=138s eta=253s
# 	epoch 1 step 260 (38%) loss=0.6109 elapsed=149s eta=241s
# 	epoch 1 step 280 (41%) loss=0.5497 elapsed=160s eta=229s
# 	epoch 1 step 300 (44%) loss=0.5463 elapsed=172s eta=217s
# 	epoch 1 step 320 (47%) loss=0.6757 elapsed=183s eta=206s
# 	epoch 1 step 340 (50%) loss=0.6255 elapsed=195s eta=195s
# 	epoch 1 step 360 (53%) loss=0.5142 elapsed=207s eta=184s
# 	epoch 1 step 380 (56%) loss=0.6436 elapsed=219s eta=173s
# 	epoch 1 step 400 (59%) loss=0.4943 elapsed=230s eta=161s
# 	epoch 1 step 420 (62%) loss=0.6577 elapsed=243s eta=150s
# 	epoch 1 step 440 (65%) loss=0.7281 elapsed=255s eta=139s
# 	epoch 1 step 460 (68%) loss=0.5391 elapsed=267s eta=128s
# 	epoch 1 step 480 (71%) loss=0.6688 elapsed=279s eta=116s
# 	epoch 1 step 500 (74%) loss=0.6443 elapsed=291s eta=105s
# 	epoch 1 step 520 (76%) loss=0.5054 elapsed=303s eta=93s
# 	epoch 1 step 540 (79%) loss=0.4793 elapsed=315s eta=82s
# 	epoch 1 step 560 (82%) loss=0.4332 elapsed=327s eta=70s
# 	epoch 1 step 580 (85%) loss=0.3850 elapsed=338s eta=58s
# 	epoch 1 step 600 (88%) loss=0.4346 elapsed=350s eta=47s
# 	epoch 1 step 620 (91%) loss=0.4297 elapsed=361s eta=35s
# 	epoch 1 step 640 (94%) loss=0.4755 elapsed=373s eta=23s
# 	epoch 1 step 660 (97%) loss=0.6476 elapsed=384s eta=12s
# 	epoch 1 step 680 (100%) loss=0.6543 elapsed=395s eta=0s
# epoch  1/50 | time 395.5s | loss 0.6181 | L_CE 0.6181 | L_intra 0.1849 | L_inter -0.4915 | grad_var 4.10e-03 | intra_fid 0.815 | inter_TD 0.480 | val_loss 0.7063 | peak_mem=50MB | best=0.7063@ep1 | bad=0/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch001.pt
# 	epoch 2 step 20 (3%) loss=0.5243 elapsed=12s eta=411s
# 	epoch 2 step 40 (6%) loss=0.5233 elapsed=24s eta=384s
# 	epoch 2 step 60 (9%) loss=0.6285 elapsed=36s eta=368s
# 	epoch 2 step 80 (12%) loss=0.3977 elapsed=47s eta=354s
# 	epoch 2 step 100 (15%) loss=0.4257 elapsed=59s eta=340s
# 	epoch 2 step 120 (18%) loss=0.4681 elapsed=70s eta=327s
# 	epoch 2 step 140 (21%) loss=0.5293 elapsed=82s eta=315s
# 	epoch 2 step 160 (24%) loss=0.5477 elapsed=93s eta=303s
# 	epoch 2 step 180 (26%) loss=0.5061 elapsed=105s eta=291s
# 	epoch 2 step 200 (29%) loss=0.6119 elapsed=116s eta=279s
# 	epoch 2 step 220 (32%) loss=0.5645 elapsed=128s eta=267s
# 	epoch 2 step 240 (35%) loss=0.4314 elapsed=139s eta=255s
# 	epoch 2 step 260 (38%) loss=0.3946 elapsed=150s eta=243s
# 	epoch 2 step 280 (41%) loss=0.4581 elapsed=162s eta=231s
# 	epoch 2 step 300 (44%) loss=0.4523 elapsed=173s eta=220s
# 	epoch 2 step 320 (47%) loss=0.4186 elapsed=185s eta=208s
# 	epoch 2 step 340 (50%) loss=0.4887 elapsed=196s eta=196s
# 	epoch 2 step 360 (53%) loss=0.4796 elapsed=208s eta=185s
# 	epoch 2 step 380 (56%) loss=0.5077 elapsed=219s eta=173s
# 	epoch 2 step 400 (59%) loss=0.4394 elapsed=230s eta=161s
# 	epoch 2 step 420 (62%) loss=0.6061 elapsed=242s eta=150s
# 	epoch 2 step 440 (65%) loss=0.6282 elapsed=253s eta=138s
# 	epoch 2 step 460 (68%) loss=0.4457 elapsed=265s eta=127s
# 	epoch 2 step 480 (71%) loss=0.5414 elapsed=276s eta=115s
# 	epoch 2 step 500 (74%) loss=0.5123 elapsed=288s eta=104s
# 	epoch 2 step 520 (76%) loss=0.7001 elapsed=299s eta=92s
# 	epoch 2 step 540 (79%) loss=0.3540 elapsed=311s eta=81s
# 	epoch 2 step 560 (82%) loss=0.5457 elapsed=322s eta=69s
# 	epoch 2 step 580 (85%) loss=0.5241 elapsed=334s eta=58s
# 	epoch 2 step 600 (88%) loss=0.3893 elapsed=345s eta=46s
# 	epoch 2 step 620 (91%) loss=0.3809 elapsed=357s eta=35s
# 	epoch 2 step 640 (94%) loss=0.5068 elapsed=368s eta=23s
# 	epoch 2 step 660 (97%) loss=0.4083 elapsed=380s eta=12s
# 	epoch 2 step 680 (100%) loss=0.6326 elapsed=391s eta=0s
# epoch  2/50 | time 391.2s | loss 0.5083 | L_CE 0.5012 | L_intra 0.1614 | L_inter -0.4857 | grad_var 8.39e-03 | intra_fid 0.839 | inter_TD 0.489 | val_loss 0.7070 | peak_mem=50MB | best=0.7063@ep1 | bad=1/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch002.pt
# 	epoch 3 step 20 (3%) loss=0.6512 elapsed=11s eta=378s
# 	epoch 3 step 40 (6%) loss=0.5267 elapsed=23s eta=367s
# 	epoch 3 step 60 (9%) loss=0.5532 elapsed=34s eta=355s
# 	epoch 3 step 80 (12%) loss=0.4416 elapsed=46s eta=344s
# 	epoch 3 step 100 (15%) loss=0.4199 elapsed=57s eta=333s
# 	epoch 3 step 120 (18%) loss=0.4468 elapsed=69s eta=321s
# 	epoch 3 step 140 (21%) loss=0.4612 elapsed=80s eta=309s
# 	epoch 3 step 160 (24%) loss=0.5816 elapsed=92s eta=298s
# 	epoch 3 step 180 (26%) loss=0.4567 elapsed=103s eta=287s
# 	epoch 3 step 200 (29%) loss=0.4787 elapsed=115s eta=275s
# 	epoch 3 step 220 (32%) loss=0.4700 elapsed=126s eta=264s
# 	epoch 3 step 240 (35%) loss=0.3815 elapsed=138s eta=253s
# 	epoch 3 step 260 (38%) loss=0.4845 elapsed=149s eta=241s
# 	epoch 3 step 280 (41%) loss=0.4437 elapsed=161s eta=230s
# 	epoch 3 step 300 (44%) loss=0.4426 elapsed=172s eta=218s
# 	epoch 3 step 320 (47%) loss=0.5309 elapsed=184s eta=207s
# 	epoch 3 step 340 (50%) loss=0.3262 elapsed=195s eta=195s
# 	epoch 3 step 360 (53%) loss=0.5543 elapsed=207s eta=184s
# 	epoch 3 step 380 (56%) loss=0.5398 elapsed=218s eta=172s
# 	epoch 3 step 400 (59%) loss=0.6987 elapsed=230s eta=161s
# 	epoch 3 step 420 (62%) loss=0.5415 elapsed=241s eta=149s
# 	epoch 3 step 440 (65%) loss=0.4548 elapsed=253s eta=138s
# 	epoch 3 step 460 (68%) loss=0.5193 elapsed=264s eta=126s
# 	epoch 3 step 480 (71%) loss=0.5334 elapsed=275s eta=115s
# 	epoch 3 step 500 (74%) loss=0.3796 elapsed=287s eta=103s
# 	epoch 3 step 520 (76%) loss=0.4967 elapsed=298s eta=92s
# 	epoch 3 step 540 (79%) loss=0.4624 elapsed=310s eta=80s
# 	epoch 3 step 560 (82%) loss=0.3818 elapsed=321s eta=69s
# 	epoch 3 step 580 (85%) loss=0.4390 elapsed=333s eta=57s
# 	epoch 3 step 600 (88%) loss=0.5081 elapsed=344s eta=46s
# 	epoch 3 step 620 (91%) loss=0.6212 elapsed=356s eta=34s
# 	epoch 3 step 640 (94%) loss=0.5332 elapsed=367s eta=23s
# 	epoch 3 step 660 (97%) loss=0.5578 elapsed=379s eta=12s
# 	epoch 3 step 680 (100%) loss=0.6086 elapsed=390s eta=0s
# epoch  3/50 | time 390.3s | loss 0.5114 | L_CE 0.4980 | L_intra 0.1530 | L_inter -0.4724 | grad_var 1.12e-02 | intra_fid 0.847 | inter_TD 0.481 | val_loss 0.6917 | peak_mem=50MB | best=0.6917@ep3 | bad=0/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch003.pt
# 	epoch 4 step 20 (3%) loss=0.5197 elapsed=11s eta=379s
# 	epoch 4 step 40 (6%) loss=0.3136 elapsed=23s eta=366s
# 	epoch 4 step 60 (9%) loss=0.3740 elapsed=34s eta=355s
# 	epoch 4 step 80 (12%) loss=0.4631 elapsed=46s eta=344s
# 	epoch 4 step 100 (15%) loss=0.4416 elapsed=57s eta=332s
# 	epoch 4 step 120 (18%) loss=0.5059 elapsed=69s eta=321s
# 	epoch 4 step 140 (21%) loss=0.4225 elapsed=80s eta=309s
# 	epoch 4 step 160 (24%) loss=0.5804 elapsed=92s eta=298s
# 	epoch 4 step 180 (26%) loss=0.4630 elapsed=103s eta=286s
# 	epoch 4 step 200 (29%) loss=0.5917 elapsed=115s eta=275s
# 	epoch 4 step 220 (32%) loss=0.5142 elapsed=126s eta=264s
# 	epoch 4 step 240 (35%) loss=0.5295 elapsed=138s eta=252s
# 	epoch 4 step 260 (38%) loss=0.3851 elapsed=149s eta=241s
# 	epoch 4 step 280 (41%) loss=0.5232 elapsed=160s eta=229s
# 	epoch 4 step 300 (44%) loss=0.5325 elapsed=172s eta=218s
# 	epoch 4 step 320 (47%) loss=0.5743 elapsed=183s eta=206s
# 	epoch 4 step 340 (50%) loss=0.5631 elapsed=195s eta=195s
# 	epoch 4 step 360 (53%) loss=0.4461 elapsed=206s eta=183s
# 	epoch 4 step 380 (56%) loss=0.4807 elapsed=218s eta=172s
# 	epoch 4 step 400 (59%) loss=0.5167 elapsed=229s eta=160s
# 	epoch 4 step 420 (62%) loss=0.5876 elapsed=241s eta=149s
# 	epoch 4 step 440 (65%) loss=0.5090 elapsed=252s eta=138s
# 	epoch 4 step 460 (68%) loss=0.5423 elapsed=264s eta=126s
# 	epoch 4 step 480 (71%) loss=0.4753 elapsed=275s eta=115s
# 	epoch 4 step 500 (74%) loss=0.6103 elapsed=287s eta=103s
# 	epoch 4 step 520 (76%) loss=0.5657 elapsed=298s eta=92s
# 	epoch 4 step 540 (79%) loss=0.5731 elapsed=310s eta=80s
# 	epoch 4 step 560 (82%) loss=0.4717 elapsed=321s eta=69s
# 	epoch 4 step 580 (85%) loss=0.4249 elapsed=332s eta=57s
# 	epoch 4 step 600 (88%) loss=0.5314 elapsed=344s eta=46s
# 	epoch 4 step 620 (91%) loss=0.5295 elapsed=355s eta=34s
# 	epoch 4 step 640 (94%) loss=0.4557 elapsed=367s eta=23s
# 	epoch 4 step 660 (97%) loss=0.4885 elapsed=378s eta=11s
# 	epoch 4 step 680 (100%) loss=0.5307 elapsed=390s eta=0s
# epoch  4/50 | time 389.7s | loss 0.5105 | L_CE 0.4904 | L_intra 0.1526 | L_inter -0.4742 | grad_var 1.23e-02 | intra_fid 0.847 | inter_TD 0.449 | val_loss 0.6949 | peak_mem=50MB | best=0.6917@ep3 | bad=1/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch004.pt
# 	epoch 5 step 20 (3%) loss=0.5981 elapsed=12s eta=385s
# 	epoch 5 step 40 (6%) loss=0.4634 elapsed=23s eta=369s
# 	epoch 5 step 60 (9%) loss=0.6267 elapsed=34s eta=356s
# 	epoch 5 step 80 (12%) loss=0.4718 elapsed=46s eta=344s
# 	epoch 5 step 100 (15%) loss=0.4235 elapsed=57s eta=332s
# 	epoch 5 step 120 (18%) loss=0.4862 elapsed=69s eta=321s
# 	epoch 5 step 140 (21%) loss=0.4536 elapsed=80s eta=309s
# 	epoch 5 step 160 (24%) loss=0.5577 elapsed=92s eta=298s
# 	epoch 5 step 180 (26%) loss=0.4619 elapsed=103s eta=286s
# 	epoch 5 step 200 (29%) loss=0.5816 elapsed=114s eta=275s
# 	epoch 5 step 220 (32%) loss=0.4748 elapsed=126s eta=263s
# 	epoch 5 step 240 (35%) loss=0.6136 elapsed=137s eta=252s
# 	epoch 5 step 260 (38%) loss=0.5517 elapsed=149s eta=240s
# 	epoch 5 step 280 (41%) loss=0.4938 elapsed=160s eta=229s
# 	epoch 5 step 300 (44%) loss=0.4385 elapsed=172s eta=217s
# 	epoch 5 step 320 (47%) loss=0.5628 elapsed=183s eta=206s
# 	epoch 5 step 340 (50%) loss=0.4323 elapsed=195s eta=195s
# 	epoch 5 step 360 (53%) loss=0.5694 elapsed=206s eta=183s
# 	epoch 5 step 380 (56%) loss=0.5441 elapsed=217s eta=172s
# 	epoch 5 step 400 (59%) loss=0.4017 elapsed=229s eta=160s
# 	epoch 5 step 420 (62%) loss=0.4147 elapsed=240s eta=149s
# 	epoch 5 step 440 (65%) loss=0.4901 elapsed=252s eta=138s
# 	epoch 5 step 460 (68%) loss=0.5453 elapsed=264s eta=126s
# 	epoch 5 step 480 (71%) loss=0.4906 elapsed=276s eta=115s
# 	epoch 5 step 500 (74%) loss=0.5254 elapsed=287s eta=103s
# 	epoch 5 step 520 (76%) loss=0.4014 elapsed=299s eta=92s
# 	epoch 5 step 540 (79%) loss=0.4457 elapsed=310s eta=80s
# 	epoch 5 step 560 (82%) loss=0.4438 elapsed=321s eta=69s
# 	epoch 5 step 580 (85%) loss=0.4170 elapsed=333s eta=57s
# 	epoch 5 step 600 (88%) loss=0.4521 elapsed=344s eta=46s
# 	epoch 5 step 620 (91%) loss=0.4246 elapsed=356s eta=34s
# 	epoch 5 step 640 (94%) loss=0.6127 elapsed=368s eta=23s
# 	epoch 5 step 660 (97%) loss=0.4233 elapsed=379s eta=12s
# 	epoch 5 step 680 (100%) loss=0.4361 elapsed=391s eta=0s
# epoch  5/50 | time 390.7s | loss 0.5058 | L_CE 0.4800 | L_intra 0.1479 | L_inter -0.4715 | grad_var 1.19e-02 | intra_fid 0.852 | inter_TD 0.480 | val_loss 0.7261 | peak_mem=50MB | best=0.6917@ep3 | bad=2/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch005.pt
# 	epoch 6 step 20 (3%) loss=0.3972 elapsed=11s eta=379s
# 	epoch 6 step 40 (6%) loss=0.3898 elapsed=23s eta=369s
# 	epoch 6 step 60 (9%) loss=0.7048 elapsed=34s eta=356s
# 	epoch 6 step 80 (12%) loss=0.5081 elapsed=46s eta=344s
# 	epoch 6 step 100 (15%) loss=0.4690 elapsed=57s eta=332s
# 	epoch 6 step 120 (18%) loss=0.6538 elapsed=68s eta=320s
# 	epoch 6 step 140 (21%) loss=0.6569 elapsed=80s eta=309s
# 	epoch 6 step 160 (24%) loss=0.4074 elapsed=91s eta=297s
# 	epoch 6 step 180 (26%) loss=0.4876 elapsed=103s eta=285s
# 	epoch 6 step 200 (29%) loss=0.5727 elapsed=114s eta=274s
# 	epoch 6 step 220 (32%) loss=0.5998 elapsed=126s eta=263s
# 	epoch 6 step 240 (35%) loss=0.5417 elapsed=137s eta=252s
# 	epoch 6 step 260 (38%) loss=0.5761 elapsed=149s eta=240s
# 	epoch 6 step 280 (41%) loss=0.5259 elapsed=160s eta=229s
# 	epoch 6 step 300 (44%) loss=0.3548 elapsed=172s eta=217s
# 	epoch 6 step 320 (47%) loss=0.4698 elapsed=184s eta=206s
# 	epoch 6 step 340 (50%) loss=0.4425 elapsed=195s eta=195s
# 	epoch 6 step 360 (53%) loss=0.4121 elapsed=206s eta=183s
# 	epoch 6 step 380 (56%) loss=0.4431 elapsed=218s eta=172s
# 	epoch 6 step 400 (59%) loss=0.4970 elapsed=229s eta=160s
# 	epoch 6 step 420 (62%) loss=0.7446 elapsed=241s eta=149s
# 	epoch 6 step 440 (65%) loss=0.5616 elapsed=252s eta=138s
# 	epoch 6 step 460 (68%) loss=0.4373 elapsed=264s eta=126s
# 	epoch 6 step 480 (71%) loss=0.5142 elapsed=275s eta=115s
# 	epoch 6 step 500 (74%) loss=0.4744 elapsed=286s eta=103s
# 	epoch 6 step 520 (76%) loss=0.4394 elapsed=298s eta=92s
# 	epoch 6 step 540 (79%) loss=0.4832 elapsed=309s eta=80s
# 	epoch 6 step 560 (82%) loss=0.7565 elapsed=321s eta=69s
# 	epoch 6 step 580 (85%) loss=0.5489 elapsed=332s eta=57s
# 	epoch 6 step 600 (88%) loss=0.4613 elapsed=343s eta=46s
# 	epoch 6 step 620 (91%) loss=0.5722 elapsed=355s eta=34s
# 	epoch 6 step 640 (94%) loss=0.4801 elapsed=366s eta=23s
# 	epoch 6 step 660 (97%) loss=0.5333 elapsed=378s eta=11s
# 	epoch 6 step 680 (100%) loss=0.3730 elapsed=389s eta=0s
# epoch  6/50 | time 389.4s | loss 0.5146 | L_CE 0.4820 | L_intra 0.1492 | L_inter -0.4718 | grad_var 1.36e-02 | intra_fid 0.851 | inter_TD 0.471 | val_loss 0.7680 | peak_mem=50MB | best=0.6917@ep3 | bad=3/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch006.pt
# 	epoch 7 step 20 (3%) loss=0.5466 elapsed=11s eta=377s
# 	epoch 7 step 40 (6%) loss=0.5220 elapsed=23s eta=366s
# 	epoch 7 step 60 (9%) loss=0.4906 elapsed=34s eta=355s
# 	epoch 7 step 80 (12%) loss=0.6022 elapsed=46s eta=344s
# 	epoch 7 step 100 (15%) loss=0.6462 elapsed=57s eta=333s
# 	epoch 7 step 120 (18%) loss=0.5821 elapsed=69s eta=323s
# 	epoch 7 step 140 (21%) loss=0.5288 elapsed=82s eta=315s
# 	epoch 7 step 160 (24%) loss=0.5183 elapsed=94s eta=307s
# 	epoch 7 step 180 (26%) loss=0.5607 elapsed=106s eta=295s
# 	epoch 7 step 200 (29%) loss=0.4777 elapsed=118s eta=282s
# 	epoch 7 step 220 (32%) loss=0.4127 elapsed=129s eta=270s
# 	epoch 7 step 240 (35%) loss=0.4327 elapsed=141s eta=258s
# 	epoch 7 step 260 (38%) loss=0.6289 elapsed=152s eta=246s
# 	epoch 7 step 280 (41%) loss=0.5083 elapsed=164s eta=234s
# 	epoch 7 step 300 (44%) loss=0.6233 elapsed=175s eta=222s
# 	epoch 7 step 320 (47%) loss=0.5041 elapsed=187s eta=210s
# 	epoch 7 step 340 (50%) loss=0.5763 elapsed=198s eta=198s
# 	epoch 7 step 360 (53%) loss=0.5094 elapsed=210s eta=186s
# 	epoch 7 step 380 (56%) loss=0.5723 elapsed=221s eta=175s
# 	epoch 7 step 400 (59%) loss=0.5287 elapsed=233s eta=163s
# 	epoch 7 step 420 (62%) loss=0.7138 elapsed=244s eta=151s
# 	epoch 7 step 440 (65%) loss=0.5043 elapsed=256s eta=140s
# 	epoch 7 step 460 (68%) loss=0.4965 elapsed=267s eta=128s
# 	epoch 7 step 480 (71%) loss=0.5490 elapsed=279s eta=116s
# 	epoch 7 step 500 (74%) loss=0.5304 elapsed=290s eta=105s
# 	epoch 7 step 520 (76%) loss=0.5390 elapsed=302s eta=93s
# 	epoch 7 step 540 (79%) loss=0.4191 elapsed=314s eta=81s
# 	epoch 7 step 560 (82%) loss=0.4520 elapsed=325s eta=70s
# 	epoch 7 step 580 (85%) loss=0.4602 elapsed=337s eta=58s
# 	epoch 7 step 600 (88%) loss=0.4413 elapsed=348s eta=46s
# 	epoch 7 step 620 (91%) loss=0.6301 elapsed=360s eta=35s
# 	epoch 7 step 640 (94%) loss=0.5123 elapsed=371s eta=23s
# 	epoch 7 step 660 (97%) loss=0.4993 elapsed=383s eta=12s
# 	epoch 7 step 680 (100%) loss=0.4568 elapsed=395s eta=0s
# epoch  7/50 | time 394.8s | loss 0.5177 | L_CE 0.4790 | L_intra 0.1478 | L_inter -0.4685 | grad_var 1.31e-02 | intra_fid 0.852 | inter_TD 0.469 | val_loss 0.6877 | peak_mem=50MB | best=0.6877@ep7 | bad=0/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch007.pt
# 	epoch 8 step 20 (3%) loss=0.4958 elapsed=12s eta=381s
# 	epoch 8 step 40 (6%) loss=0.5256 elapsed=23s eta=371s
# 	epoch 8 step 60 (9%) loss=0.4000 elapsed=35s eta=358s
# 	epoch 8 step 80 (12%) loss=0.6273 elapsed=46s eta=345s
# 	epoch 8 step 100 (15%) loss=0.6641 elapsed=57s eta=333s
# 	epoch 8 step 120 (18%) loss=0.5317 elapsed=69s eta=321s
# 	epoch 8 step 140 (21%) loss=0.5269 elapsed=80s eta=309s
# 	epoch 8 step 160 (24%) loss=0.4807 elapsed=92s eta=298s
# 	epoch 8 step 180 (26%) loss=0.4556 elapsed=103s eta=286s
# 	epoch 8 step 200 (29%) loss=0.5038 elapsed=114s eta=275s
# 	epoch 8 step 220 (32%) loss=0.6504 elapsed=126s eta=263s
# 	epoch 8 step 240 (35%) loss=0.5186 elapsed=137s eta=252s
# 	epoch 8 step 260 (38%) loss=0.3960 elapsed=149s eta=241s
# 	epoch 8 step 280 (41%) loss=0.6461 elapsed=160s eta=229s
# 	epoch 8 step 300 (44%) loss=0.6446 elapsed=172s eta=218s
# 	epoch 8 step 320 (47%) loss=0.4368 elapsed=183s eta=206s
# 	epoch 8 step 340 (50%) loss=0.4554 elapsed=195s eta=195s
# 	epoch 8 step 360 (53%) loss=0.5444 elapsed=207s eta=184s
# 	epoch 8 step 380 (56%) loss=0.7681 elapsed=218s eta=172s
# 	epoch 8 step 400 (59%) loss=0.4554 elapsed=230s eta=161s
# 	epoch 8 step 420 (62%) loss=0.5280 elapsed=242s eta=150s
# 	epoch 8 step 440 (65%) loss=0.5899 elapsed=254s eta=139s
# 	epoch 8 step 460 (68%) loss=0.4835 elapsed=267s eta=127s
# 	epoch 8 step 480 (71%) loss=0.5715 elapsed=278s eta=116s
# 	epoch 8 step 500 (74%) loss=0.5349 elapsed=290s eta=104s
# 	epoch 8 step 520 (76%) loss=0.5719 elapsed=301s eta=93s
# 	epoch 8 step 540 (79%) loss=0.5340 elapsed=313s eta=81s
# 	epoch 8 step 560 (82%) loss=0.4377 elapsed=324s eta=70s
# 	epoch 8 step 580 (85%) loss=0.5223 elapsed=336s eta=58s
# 	epoch 8 step 600 (88%) loss=0.5187 elapsed=347s eta=46s
# 	epoch 8 step 620 (91%) loss=0.3746 elapsed=359s eta=35s
# 	epoch 8 step 640 (94%) loss=0.6824 elapsed=371s eta=23s
# 	epoch 8 step 660 (97%) loss=0.5455 elapsed=382s eta=12s
# 	epoch 8 step 680 (100%) loss=0.4526 elapsed=394s eta=0s
# epoch  8/50 | time 394.3s | loss 0.5281 | L_CE 0.4829 | L_intra 0.1479 | L_inter -0.4665 | grad_var 1.39e-02 | intra_fid 0.852 | inter_TD 0.472 | val_loss 0.7058 | peak_mem=50MB | best=0.6877@ep7 | bad=1/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch008.pt
# 	epoch 9 step 20 (3%) loss=0.6405 elapsed=12s eta=393s
# 	epoch 9 step 40 (6%) loss=0.7139 elapsed=23s eta=375s
# 	epoch 9 step 60 (9%) loss=0.4353 elapsed=35s eta=361s
# 	epoch 9 step 80 (12%) loss=0.4121 elapsed=47s eta=354s
# 	epoch 9 step 100 (15%) loss=0.6039 elapsed=59s eta=341s
# 	epoch 9 step 120 (18%) loss=0.5366 elapsed=70s eta=327s
# 	epoch 9 step 140 (21%) loss=0.5631 elapsed=82s eta=315s
# 	epoch 9 step 160 (24%) loss=0.5225 elapsed=94s eta=305s
# 	epoch 9 step 180 (26%) loss=0.5291 elapsed=106s eta=294s
# 	epoch 9 step 200 (29%) loss=0.5536 elapsed=118s eta=282s
# 	epoch 9 step 220 (32%) loss=0.4998 elapsed=130s eta=271s
# 	epoch 9 step 240 (35%) loss=0.4870 elapsed=141s eta=259s
# 	epoch 9 step 260 (38%) loss=0.4535 elapsed=153s eta=247s
# 	epoch 9 step 280 (41%) loss=0.4197 elapsed=164s eta=235s
# 	epoch 9 step 300 (44%) loss=0.4694 elapsed=176s eta=223s
# 	epoch 9 step 320 (47%) loss=0.4937 elapsed=187s eta=211s
# 	epoch 9 step 340 (50%) loss=0.4569 elapsed=199s eta=199s
# 	epoch 9 step 360 (53%) loss=0.6020 elapsed=210s eta=187s
# 	epoch 9 step 380 (56%) loss=0.5880 elapsed=222s eta=175s
# 	epoch 9 step 400 (59%) loss=0.4746 elapsed=233s eta=163s
# 	epoch 9 step 420 (62%) loss=0.3927 elapsed=245s eta=151s
# 	epoch 9 step 440 (65%) loss=0.4196 elapsed=256s eta=140s
# 	epoch 9 step 460 (68%) loss=0.4749 elapsed=268s eta=128s
# 	epoch 9 step 480 (71%) loss=0.6549 elapsed=279s eta=116s
# 	epoch 9 step 500 (74%) loss=0.4032 elapsed=290s eta=105s
# 	epoch 9 step 520 (76%) loss=0.5037 elapsed=302s eta=93s
# 	epoch 9 step 540 (79%) loss=0.5725 elapsed=313s eta=81s
# 	epoch 9 step 560 (82%) loss=0.4433 elapsed=325s eta=70s
# 	epoch 9 step 580 (85%) loss=0.6451 elapsed=336s eta=58s
# 	epoch 9 step 600 (88%) loss=0.4560 elapsed=348s eta=46s
# 	epoch 9 step 620 (91%) loss=0.4939 elapsed=359s eta=35s
# 	epoch 9 step 640 (94%) loss=0.4881 elapsed=370s eta=23s
# 	epoch 9 step 660 (97%) loss=0.5582 elapsed=382s eta=12s
# 	epoch 9 step 680 (100%) loss=0.5768 elapsed=394s eta=0s
# epoch  9/50 | time 393.9s | loss 0.5209 | L_CE 0.4702 | L_intra 0.1453 | L_inter -0.4670 | grad_var 1.47e-02 | intra_fid 0.855 | inter_TD 0.458 | val_loss 0.6745 | peak_mem=50MB | best=0.6745@ep9 | bad=0/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch009.pt
# 	epoch 10 step 20 (3%) loss=0.4855 elapsed=11s eta=377s
# 	epoch 10 step 40 (6%) loss=0.5460 elapsed=23s eta=364s
# 	epoch 10 step 60 (9%) loss=0.4976 elapsed=34s eta=353s
# 	epoch 10 step 80 (12%) loss=0.6104 elapsed=46s eta=342s
# 	epoch 10 step 100 (15%) loss=0.5268 elapsed=57s eta=330s
# 	epoch 10 step 120 (18%) loss=0.5037 elapsed=68s eta=319s
# 	epoch 10 step 140 (21%) loss=0.4751 elapsed=80s eta=308s
# 	epoch 10 step 160 (24%) loss=0.5869 elapsed=91s eta=296s
# 	epoch 10 step 180 (26%) loss=0.4192 elapsed=103s eta=285s
# 	epoch 10 step 200 (29%) loss=0.5180 elapsed=114s eta=274s
# 	epoch 10 step 220 (32%) loss=0.7660 elapsed=126s eta=263s
# 	epoch 10 step 240 (35%) loss=0.4898 elapsed=137s eta=252s
# 	epoch 10 step 260 (38%) loss=0.4945 elapsed=149s eta=241s
# 	epoch 10 step 280 (41%) loss=0.6275 elapsed=161s eta=229s
# 	epoch 10 step 300 (44%) loss=0.4510 elapsed=172s eta=218s
# 	epoch 10 step 320 (47%) loss=0.3465 elapsed=184s eta=207s
# 	epoch 10 step 340 (50%) loss=0.4839 elapsed=195s eta=195s
# 	epoch 10 step 360 (53%) loss=0.5634 elapsed=207s eta=184s
# 	epoch 10 step 380 (56%) loss=0.5167 elapsed=218s eta=172s
# 	epoch 10 step 400 (59%) loss=0.5313 elapsed=230s eta=161s
# 	epoch 10 step 420 (62%) loss=0.4790 elapsed=241s eta=149s
# 	epoch 10 step 440 (65%) loss=0.5133 elapsed=253s eta=138s
# 	epoch 10 step 460 (68%) loss=0.5687 elapsed=264s eta=126s
# 	epoch 10 step 480 (71%) loss=0.5202 elapsed=276s eta=115s
# 	epoch 10 step 500 (74%) loss=0.4587 elapsed=287s eta=103s
# 	epoch 10 step 520 (76%) loss=0.4967 elapsed=299s eta=92s
# 	epoch 10 step 540 (79%) loss=0.4505 elapsed=310s eta=81s
# 	epoch 10 step 560 (82%) loss=0.6148 elapsed=322s eta=69s
# 	epoch 10 step 580 (85%) loss=0.5293 elapsed=333s eta=57s
# 	epoch 10 step 600 (88%) loss=0.9068 elapsed=345s eta=46s
# 	epoch 10 step 620 (91%) loss=0.4457 elapsed=356s eta=34s
# 	epoch 10 step 640 (94%) loss=0.5558 elapsed=368s eta=23s
# 	epoch 10 step 660 (97%) loss=0.4416 elapsed=379s eta=12s
# 	epoch 10 step 680 (100%) loss=0.5411 elapsed=390s eta=0s
# epoch 10/50 | time 390.3s | loss 0.5288 | L_CE 0.4734 | L_intra 0.1416 | L_inter -0.4631 | grad_var 1.54e-02 | intra_fid 0.858 | inter_TD 0.484 | val_loss 0.6738 | peak_mem=50MB | best=0.6745@ep9 | bad=1/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch010.pt
# 	epoch 11 step 20 (3%) loss=0.6004 elapsed=11s eta=378s
# 	epoch 11 step 40 (6%) loss=0.5177 elapsed=23s eta=366s
# 	epoch 11 step 60 (9%) loss=0.5547 elapsed=34s eta=355s
# 	epoch 11 step 80 (12%) loss=0.5601 elapsed=46s eta=343s
# 	epoch 11 step 100 (15%) loss=0.4409 elapsed=57s eta=332s
# 	epoch 11 step 120 (18%) loss=0.5115 elapsed=69s eta=321s
# 	epoch 11 step 140 (21%) loss=0.4679 elapsed=80s eta=309s
# 	epoch 11 step 160 (24%) loss=0.4585 elapsed=91s eta=297s
# 	epoch 11 step 180 (26%) loss=0.4310 elapsed=103s eta=286s
# 	epoch 11 step 200 (29%) loss=0.4562 elapsed=114s eta=274s
# 	epoch 11 step 220 (32%) loss=0.5858 elapsed=126s eta=263s
# 	epoch 11 step 240 (35%) loss=0.6023 elapsed=137s eta=252s
# 	epoch 11 step 260 (38%) loss=0.3635 elapsed=149s eta=240s
# 	epoch 11 step 280 (41%) loss=0.5113 elapsed=160s eta=229s
# 	epoch 11 step 300 (44%) loss=0.6105 elapsed=171s eta=217s
# 	epoch 11 step 320 (47%) loss=0.5327 elapsed=183s eta=206s
# 	epoch 11 step 340 (50%) loss=0.4504 elapsed=194s eta=194s
# 	epoch 11 step 360 (53%) loss=0.5419 elapsed=205s eta=183s
# 	epoch 11 step 380 (56%) loss=0.5647 elapsed=217s eta=171s
# 	epoch 11 step 400 (59%) loss=0.5969 elapsed=228s eta=160s
# 	epoch 11 step 420 (62%) loss=0.5111 elapsed=240s eta=148s
# 	epoch 11 step 440 (65%) loss=0.4607 elapsed=251s eta=137s
# 	epoch 11 step 460 (68%) loss=0.5009 elapsed=263s eta=126s
# 	epoch 11 step 480 (71%) loss=0.6061 elapsed=274s eta=114s
# 	epoch 11 step 500 (74%) loss=0.5140 elapsed=286s eta=103s
# 	epoch 11 step 520 (76%) loss=0.4605 elapsed=297s eta=91s
# 	epoch 11 step 540 (79%) loss=0.6563 elapsed=308s eta=80s
# 	epoch 11 step 560 (82%) loss=0.4007 elapsed=320s eta=69s
# 	epoch 11 step 580 (85%) loss=0.4369 elapsed=331s eta=57s
# 	epoch 11 step 600 (88%) loss=0.4946 elapsed=342s eta=46s
# 	epoch 11 step 620 (91%) loss=0.4151 elapsed=354s eta=34s
# 	epoch 11 step 640 (94%) loss=0.4738 elapsed=366s eta=23s
# 	epoch 11 step 660 (97%) loss=0.6326 elapsed=377s eta=11s
# 	epoch 11 step 680 (100%) loss=0.6933 elapsed=389s eta=0s
# epoch 11/50 | time 389.1s | loss 0.5277 | L_CE 0.4663 | L_intra 0.1411 | L_inter -0.4617 | grad_var 1.51e-02 | intra_fid 0.859 | inter_TD 0.453 | val_loss 0.7090 | peak_mem=50MB | best=0.6745@ep9 | bad=2/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch011.pt
# 	epoch 12 step 20 (3%) loss=0.4275 elapsed=12s eta=386s
# 	epoch 12 step 40 (6%) loss=0.6344 elapsed=23s eta=371s
# 	epoch 12 step 60 (9%) loss=0.4517 elapsed=35s eta=358s
# 	epoch 12 step 80 (12%) loss=0.5651 elapsed=46s eta=346s
# 	epoch 12 step 100 (15%) loss=0.5274 elapsed=58s eta=335s
# 	epoch 12 step 120 (18%) loss=0.4821 elapsed=69s eta=324s
# 	epoch 12 step 140 (21%) loss=0.6535 elapsed=81s eta=312s
# 	epoch 12 step 160 (24%) loss=0.6453 elapsed=93s eta=301s
# 	epoch 12 step 180 (26%) loss=0.5886 elapsed=104s eta=289s
# 	epoch 12 step 200 (29%) loss=0.6440 elapsed=116s eta=277s
# 	epoch 12 step 220 (32%) loss=0.4809 elapsed=127s eta=266s
# 	epoch 12 step 240 (35%) loss=0.5849 elapsed=139s eta=255s
# 	epoch 12 step 260 (38%) loss=0.5610 elapsed=151s eta=243s
# 	epoch 12 step 280 (41%) loss=0.5743 elapsed=162s eta=231s
# 	epoch 12 step 300 (44%) loss=0.5275 elapsed=174s eta=220s
# 	epoch 12 step 320 (47%) loss=0.4870 elapsed=185s eta=208s
# 	epoch 12 step 340 (50%) loss=0.5366 elapsed=197s eta=197s
# 	epoch 12 step 360 (53%) loss=0.5559 elapsed=208s eta=185s
# 	epoch 12 step 380 (56%) loss=0.4418 elapsed=219s eta=173s
# 	epoch 12 step 400 (59%) loss=0.4669 elapsed=231s eta=162s
# 	epoch 12 step 420 (62%) loss=0.4869 elapsed=243s eta=150s
# 	epoch 12 step 440 (65%) loss=0.4199 elapsed=255s eta=139s
# 	epoch 12 step 460 (68%) loss=0.5206 elapsed=266s eta=127s
# 	epoch 12 step 480 (71%) loss=0.6372 elapsed=279s eta=116s
# 	epoch 12 step 500 (74%) loss=0.5482 elapsed=292s eta=105s
# 	epoch 12 step 520 (76%) loss=0.6577 elapsed=304s eta=94s
# 	epoch 12 step 540 (79%) loss=0.5347 elapsed=316s eta=82s
# 	epoch 12 step 560 (82%) loss=0.5072 elapsed=328s eta=70s
# 	epoch 12 step 580 (85%) loss=0.5760 elapsed=340s eta=59s
# 	epoch 12 step 600 (88%) loss=0.5263 elapsed=351s eta=47s
# 	epoch 12 step 620 (91%) loss=0.4169 elapsed=363s eta=35s
# 	epoch 12 step 640 (94%) loss=0.6307 elapsed=375s eta=23s
# 	epoch 12 step 660 (97%) loss=0.5561 elapsed=387s eta=12s
# 	epoch 12 step 680 (100%) loss=0.4735 elapsed=399s eta=0s
# epoch 12/50 | time 398.6s | loss 0.5293 | L_CE 0.4687 | L_intra 0.1395 | L_inter -0.4592 | grad_var 1.58e-02 | intra_fid 0.861 | inter_TD 0.466 | val_loss 0.8056 | peak_mem=50MB | best=0.6745@ep9 | bad=3/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch012.pt
# 	epoch 13 step 20 (3%) loss=0.5957 elapsed=12s eta=398s
# 	epoch 13 step 40 (6%) loss=0.5635 elapsed=24s eta=388s
# 	epoch 13 step 60 (9%) loss=0.3841 elapsed=36s eta=370s
# 	epoch 13 step 80 (12%) loss=0.5514 elapsed=47s eta=355s
# 	epoch 13 step 100 (15%) loss=0.5884 elapsed=59s eta=345s
# 	epoch 13 step 120 (18%) loss=0.4287 elapsed=71s eta=332s
# 	epoch 13 step 140 (21%) loss=0.4832 elapsed=83s eta=319s
# 	epoch 13 step 160 (24%) loss=0.4137 elapsed=94s eta=307s
# 	epoch 13 step 180 (26%) loss=0.4990 elapsed=106s eta=295s
# 	epoch 13 step 200 (29%) loss=0.4546 elapsed=120s eta=287s
# 	epoch 13 step 220 (32%) loss=0.5627 elapsed=132s eta=276s
# 	epoch 13 step 240 (35%) loss=0.5190 elapsed=144s eta=264s
# 	epoch 13 step 260 (38%) loss=0.5555 elapsed=156s eta=253s
# 	epoch 13 step 280 (41%) loss=0.6315 elapsed=169s eta=241s
# 	epoch 13 step 300 (44%) loss=0.6241 elapsed=181s eta=229s
# 	epoch 13 step 320 (47%) loss=0.4209 elapsed=192s eta=216s
# 	epoch 13 step 340 (50%) loss=0.5552 elapsed=204s eta=204s
# 	epoch 13 step 360 (53%) loss=0.5169 elapsed=216s eta=192s
# 	epoch 13 step 380 (56%) loss=0.6769 elapsed=228s eta=180s
# 	epoch 13 step 400 (59%) loss=0.5237 elapsed=240s eta=168s
# 	epoch 13 step 420 (62%) loss=0.5546 elapsed=252s eta=156s
# 	epoch 13 step 440 (65%) loss=0.5487 elapsed=264s eta=144s
# 	epoch 13 step 460 (68%) loss=0.3905 elapsed=275s eta=132s
# 	epoch 13 step 480 (71%) loss=0.5823 elapsed=287s eta=120s
# 	epoch 13 step 500 (74%) loss=0.6056 elapsed=299s eta=108s
# 	epoch 13 step 520 (76%) loss=0.4357 elapsed=311s eta=96s
# 	epoch 13 step 540 (79%) loss=0.3946 elapsed=323s eta=84s
# 	epoch 13 step 560 (82%) loss=0.7548 elapsed=334s eta=72s
# 	epoch 13 step 580 (85%) loss=0.5540 elapsed=346s eta=60s
# 	epoch 13 step 600 (88%) loss=0.5648 elapsed=358s eta=48s
# 	epoch 13 step 620 (91%) loss=0.8514 elapsed=370s eta=36s
# 	epoch 13 step 640 (94%) loss=0.5782 elapsed=381s eta=24s
# 	epoch 13 step 660 (97%) loss=0.4792 elapsed=393s eta=12s
# 	epoch 13 step 680 (100%) loss=0.5679 elapsed=404s eta=0s
# epoch 13/50 | time 404.5s | loss 0.5317 | L_CE 0.4705 | L_intra 0.1410 | L_inter -0.4632 | grad_var 1.63e-02 | intra_fid 0.859 | inter_TD 0.483 | val_loss 0.7075 | peak_mem=50MB | best=0.6745@ep9 | bad=4/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch013.pt
# 	epoch 14 step 20 (3%) loss=0.6033 elapsed=12s eta=386s
# 	epoch 14 step 40 (6%) loss=0.4964 elapsed=23s eta=373s
# 	epoch 14 step 60 (9%) loss=0.5492 elapsed=35s eta=360s
# 	epoch 14 step 80 (12%) loss=0.4442 elapsed=47s eta=349s
# 	epoch 14 step 100 (15%) loss=0.5157 elapsed=58s eta=337s
# 	epoch 14 step 120 (18%) loss=0.3977 elapsed=70s eta=325s
# 	epoch 14 step 140 (21%) loss=0.4574 elapsed=81s eta=314s
# 	epoch 14 step 160 (24%) loss=0.4990 elapsed=93s eta=302s
# 	epoch 14 step 180 (26%) loss=0.4678 elapsed=104s eta=290s
# 	epoch 14 step 200 (29%) loss=0.5971 elapsed=116s eta=278s
# 	epoch 14 step 220 (32%) loss=0.5902 elapsed=127s eta=266s
# 	epoch 14 step 240 (35%) loss=0.8258 elapsed=139s eta=254s
# 	epoch 14 step 260 (38%) loss=0.4042 elapsed=150s eta=243s
# 	epoch 14 step 280 (41%) loss=0.5007 elapsed=162s eta=231s
# 	epoch 14 step 300 (44%) loss=0.5417 elapsed=173s eta=219s
# 	epoch 14 step 320 (47%) loss=0.5022 elapsed=185s eta=208s
# 	epoch 14 step 340 (50%) loss=0.5424 elapsed=196s eta=196s
# 	epoch 14 step 360 (53%) loss=0.5029 elapsed=208s eta=185s
# 	epoch 14 step 380 (56%) loss=0.4687 elapsed=219s eta=173s
# 	epoch 14 step 400 (59%) loss=0.5814 elapsed=230s eta=161s
# 	epoch 14 step 420 (62%) loss=0.5554 elapsed=242s eta=150s
# 	epoch 14 step 440 (65%) loss=0.5363 elapsed=253s eta=138s
# 	epoch 14 step 460 (68%) loss=0.5380 elapsed=265s eta=127s
# 	epoch 14 step 480 (71%) loss=0.4335 elapsed=276s eta=115s
# 	epoch 14 step 500 (74%) loss=0.6540 elapsed=288s eta=104s
# 	epoch 14 step 520 (76%) loss=0.5045 elapsed=299s eta=92s
# 	epoch 14 step 540 (79%) loss=0.6258 elapsed=310s eta=81s
# 	epoch 14 step 560 (82%) loss=0.5083 elapsed=322s eta=69s
# 	epoch 14 step 580 (85%) loss=0.5140 elapsed=333s eta=58s
# 	epoch 14 step 600 (88%) loss=0.3942 elapsed=345s eta=46s
# 	epoch 14 step 620 (91%) loss=0.4748 elapsed=356s eta=35s
# 	epoch 14 step 640 (94%) loss=0.5344 elapsed=368s eta=23s
# 	epoch 14 step 660 (97%) loss=0.5787 elapsed=379s eta=12s
# 	epoch 14 step 680 (100%) loss=0.4739 elapsed=391s eta=0s
# epoch 14/50 | time 390.9s | loss 0.5242 | L_CE 0.4636 | L_intra 0.1398 | L_inter -0.4613 | grad_var 1.63e-02 | intra_fid 0.860 | inter_TD 0.465 | val_loss 0.7544 | peak_mem=50MB | best=0.6745@ep9 | bad=5/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.05-maqt_seed42/maqt-epoch014.pt
# early stopping at epoch 14: no val_loss improvement for 5 epochs (best=0.6745 @ epoch 9)
# restored best MAQT weights from epoch 9 (val_loss=0.6745)
#
# epochs_ran=14 | best_epoch=9 | stopped_early=True | stop_reason=early_stopping

# %% [markdown]
# ## Prototypes

# %%
proto_df = pd.DataFrame(prototype_summary(prototypes, class_names))
proto_df
# Out:
#             class  dim     trace
# 0            DDoS   32  1.000000
# 1             DoS   32  1.000000
# 2          Normal   32  1.000001
# 3  Reconnaissance   32  1.000001

# %%
# save prototypes (all-in-one checkpoint)
out_dir = Path("artifacts") / dataset
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_path = out_dir / f"{NOTEBOOK_NAME}-checkpoint.pt"
torch.save(
    {
        "theta": theta_star.detach().cpu(),
        "head_state_dict": head.state_dict(),
        "prototypes": {k: v.detach().cpu() for k, v in prototypes.items()},
        # rebuild / inference meta
        "class_names": list(class_names),
        "num_classes": num_classes,
        "num_qubits": num_qubits,
        "num_layers": num_layers,
        "noise_rate": noise_rate,
        # FROZEN feature + angle pipeline (must match train)
        "feature_cols": list(FEATURE_COLS),
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "target_col": target_col,
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "scaler": scaler,  # StandardScaler fitted on full train
        "pca": pca,  # PCA fitted on scaled full train (or None)
        "k95": int(k95),
        "angle_x_min": np.asarray(x_min),  # on pca space if USE_PCA else scaled space
        "angle_x_max": np.asarray(x_max),
        "angle_min": 0.0,
        "angle_max": float(np.pi),
    },
    ckpt_path,
)
print("published:", ckpt_path.resolve())
# Out:
# published: /home/lawun330/Desktop/quantum-sentinel/artifacts/BoT-IoT/4class-20000each-lr0.05-maqt-checkpoint.pt

# %% [markdown]
# ## Visualization

# %%
# plots
epochs_x = range(1, len(history["loss"]) + 1)

fig, axes = plt.subplots(1, 3, figsize=(14, 4))

# total loss
axes[0].plot(epochs_x, history["loss"], marker="o")
axes[0].set_title("Total loss")
axes[0].set_xlabel("Epoch")

# decomposed (weighted like the objective)
axes[1].plot(epochs_x, history["loss"], marker=None, label=r"$L$")
axes[1].plot(epochs_x, history["L_CE"], "--", label=r"$L_{CE}$")
axes[1].plot(
    epochs_x,
    [lambda1 * v for v in history["L_intra"]],
    "--",
    label=r"$\lambda_1 L_{intra}$",
)
axes[1].plot(
    epochs_x,
    [lambda2 * v for v in history["L_inter"]],
    "--",
    label=r"$\lambda_2 L_{inter}$",
)
axes[1].set_title(r"$Decomposed L = L_{CE}+\lambda_1 L_{intra}+\lambda_2 L_{inter}$")
axes[1].legend(fontsize=8)

# grad var
axes[2].plot(epochs_x, history["grad_var"], marker="o", color="tab:orange")
axes[2].axhline(
    1e-6, color="red", linestyle="--", label="plateau thr"
)  # or BARREN_PLATEAU_VAR_THRESHOLD
axes[2].set_title("Gradient variance")
axes[2].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Logging

# %%
# write log (final)
log_path = write_history_log(
    history,
    NOTEBOOK_NAME,
    extra={
        ## data
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "dataset": dataset,
        "feature_cols": FEATURE_COLS,
        "target_col": target_col,
        "n_train": len(X_train),
        "class_names": list(class_names),
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "num_qubits": num_qubits,
        "k95": int(k95),
        # algo 1: MAQT train
        "epochs": epochs,
        "batch_size": batch_size,
        "lr": lr,
        "lambda1": lambda1,
        "lambda2": lambda2,
        ## quantum model
        "noise_rate": noise_rate,
        "num_layers": num_layers,
        "num_classes": num_classes,
        ## training
        "train_total_sec": float(sum(history["epoch_sec"]))
        if history.get("epoch_sec")
        else None,
        "loss_last": float(history["loss"][-1]) if history["loss"] else None,
        "barren_plateau_var": barren_plateau_var,
        "barren_plateau_any": bool(
            any(g < barren_plateau_var for g in history["grad_var"])
        )
        if history.get("grad_var")
        else None,
        "seed": SEED,
        "early_stopping": early_stopping,
        "patience": patience,
        "best_epoch": history.get("best_epoch"),
        "best_score": history.get("best_score"),
        "stopped_early": history.get("stopped_early"),
        "epochs_ran": history.get("epochs_ran"),
        "stop_reason": history.get("stop_reason"),
        "interrupted": history.get("interrupted"),
        "checkpoint_dir": str(ckpt_dir),
    },
    log_dir="logs",
)
print(f"wrote {log_path.resolve()}")
# Out:
# wrote /home/lawun330/Desktop/quantum-sentinel/logs/4class-20000each-lr0.05-maqt.log
