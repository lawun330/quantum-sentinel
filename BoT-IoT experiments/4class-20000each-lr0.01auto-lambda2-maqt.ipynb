# %% [markdown]
# # MAQT Prototypes with FROZEN Features: BoT-IoT
# # Experiment: More Samples | Auto LR | $\lambda_2$ 0.1 from 0.02
# ## Capped Sample (20,000) | ~1,1800 Train | Batch Size 64
# ## 50 Epochs (Early Stopping with Patience = 5) | LR Decay (Start at 0.01)
# ## Target (y) = "label_multiclass" | Data Reupload = 2

# %% [markdown]
# ## Setup

# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import torch
from pennylane import numpy as np
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from scripts.circuit import build_forward_circuit, create_quantum_device
from scripts.constants import (
    BARREN_PLATEAU_VAR_THRESHOLD,
    DEFAULT_NOISE_RATE,
)
from scripts.data import (
    greedy_dpp_sample,
    load_split,
    plot_class_balance_pie,
    plot_dataset_and_sampling_analysis,
    to_angles,
)
from scripts.gradient import gradient_variance_probe
from scripts.logging import write_history_log
from scripts.memory import is_oom_error, run_batched_safely, safe_empty_cache
from scripts.prototypes import prototype_summary
from scripts.theory import verify_fidelity_convention
from scripts.train import train_maqt
from scripts.utils import get_torch_device, to_np_y

# %%
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available?: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA device name: {torch.cuda.get_device_name(0)}")
    print(f"Current CUDA device index: {torch.cuda.current_device()}")
# Out:
# PyTorch version: 2.12.1+cu126
# CUDA available?: True
# CUDA device name: NVIDIA GeForce GTX 1060
# Current CUDA device index: 0

# %% [markdown]
# ## Config

# %%
NOTEBOOK_NAME = "4class-20000each-lr0.01auto-lambda2-maqt"

dataset = "BoT-IoT"
target_col = "label_multiclass"
data_path = f"data/FROZEN/{dataset}"
frozen_feat_path = "team-artifacts/teamC_week3_FROZEN_handoff.json"

SEED = 42

# %%
check = verify_fidelity_convention(dim=4, n_trials=30, seed=SEED)
print("Fidelity-convention self-check PASSED:", check)
# Out:
# Fidelity-convention self-check PASSED: {'max_pairwise_disagreement': 0.0, 'max_fvg_violation': 0.0}

# %% [markdown]
# ## Load Team C's FROZEN Features

# %%
handoff = json.loads(Path(frozen_feat_path).read_text())
FEATURE_COLS = list(handoff["frozen_subsets"][dataset]["features"])
print(f"Team C selector: {handoff['frozen_subsets'][dataset]['selector']}")
print(f"k={len(FEATURE_COLS)} features: {FEATURE_COLS}")
# Out:
# Team C selector: QIGPSO
# k=10 features: ['n_pkts_total', 'n_bytes_total', 'src_bytes', 'rate', 'pkt_size_min', 'pkt_size_max', 'pkt_size_mean', 'pkt_size_std', 'protocol', 'conn_state']

# %% [markdown]
# ## Load Team A's FROZEN Dataset

# %%
# load all data
X_train_full, y_train_full, class_names, df_train = load_split(
    data_path, "train", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_cal_full, y_cal_full, _, df_cal = load_split(
    data_path, "calibration", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_test_full, y_test_full, _, df_test = load_split(
    data_path, "test", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_zero_full, y_zero_full, _, df_zero = load_split(
    data_path, "zeroday", target_col, csv=True, selected_cols=FEATURE_COLS, return_df = True
)

# check shape
print(f"train   : {X_train_full.shape, y_train_full.shape}\n\
cal     : {X_cal_full.shape, y_cal_full.shape}\n\
test    : {X_test_full.shape, y_test_full.shape}\n\
zero    : {X_zero_full.shape, y_zero_full.shape}\n\
classes : {class_names}\n"
)

df_train.head(3)
# Out:
# train   : ((148729, 10), (148729,))
# cal     : ((18591, 10), (18591,))
# test    : ((18591, 10), (18591,))
# zero    : ((683, 10), (683,))
# classes : ['DDoS', 'DoS', 'Normal', 'Reconnaissance']
#    n_pkts_total  n_bytes_total  src_bytes      rate  pkt_size_min  \
# 0     -0.262256      -0.798644  -0.774964 -0.356930      0.000000
# 1      0.427561      -0.121016   0.000000 -0.123704      0.000000
# 2      0.768961       0.200956   0.368220  1.725276      0.761987
#
#    pkt_size_max  pkt_size_mean  pkt_size_std  protocol  conn_state  \
# 0      0.123458      -0.266091      0.827772       0.0         0.0
# 1      0.120431       0.030826      0.766490       0.0         0.0
# 2      0.244690       0.422755      0.618673       0.0         0.0
#
#   label_multiclass
# 0              DoS
# 1              DoS
# 2             DDoS

# %% [markdown]
# ## EDA (Before Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train_full, class_names,
    title=f"train (n={len(to_np_y(y_train_full))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 4

# %% [markdown]
# ## Scaling

# %%
# fit scaler on full train (raw); transform elsewhere via to_angles()
scaler = StandardScaler()
X_train_full_scaled = scaler.fit_transform(X_train_full)
print(f"scaled full train: {X_train_full_scaled.shape}")
# Out:
# scaled full train: (148729, 10)

# %% [markdown]
# ## PCA (Optional)

# %%
USE_PCA = True   # set to False to skip PCA
TARGET_VARIANCE = 0.95

# %%
if USE_PCA:
    pca_full = PCA(random_state=SEED).fit(X_train_full_scaled)
    ratios = pca_full.explained_variance_ratio_
    cum = np.cumsum(ratios)
    n_feat = len(ratios)

    print(f"features (raw dim): {n_feat}")
    print("explained_variance_ratio_:", np.round(ratios, 4))
    print("cumulative:               ", np.round(cum, 4))
    for k in range(1, n_feat + 1):
        print(f"first {k} PCs keep {cum[k - 1]*100:.2f}% variance")

    # smallest k with >= target variance
    k95 = int(np.searchsorted(cum, TARGET_VARIANCE) + 1)
    k95 = min(k95, len(cum))  # safety
    print(f"components needed for >={TARGET_VARIANCE*100}% variance: {k95}")

    fig, ax = plt.subplots(1, 1, figsize=(8, 5))
    ax.bar(range(1, n_feat + 1), ratios, color="slateblue", alpha=0.7, label="per-PC")
    ax.plot(range(1, n_feat + 1), cum, marker="o", color="darkblue", label="cumulative")
    ax.axhline(TARGET_VARIANCE, color="red", linestyle="--", label=f"Target({TARGET_VARIANCE*100}%)")
    ax.axvline(k95, color="green", linestyle=":", label=f"k={k95}")
    ax.set_xlabel("PCA component")
    ax.set_ylabel("explained variance ratio")
    ax.set_title("PCA explained feature variance")
    ax.legend()
    plt.tight_layout()
    plt.show()

    pca = PCA(n_components=k95, random_state=SEED)
    X_train_full_feat = pca.fit_transform(X_train_full_scaled)
else:
    pca = None
    k95 = X_train_full_scaled.shape[1]
    X_train_full_feat = X_train_full_scaled

# angle bounds from full train feature space (pca or scaled)
x_min, x_max = X_train_full_feat.min(0), X_train_full_feat.max(0)
print(f"feature dim for angles: {X_train_full_feat.shape[1]} | USE_PCA={USE_PCA}")
# Out:
# features (raw dim): 10
# explained_variance_ratio_: [0.3698 0.2823 0.1538 0.0927 0.0827 0.0085 0.0052 0.0034 0.0008 0.0007]
# cumulative:                [0.3698 0.6521 0.8059 0.8986 0.9813 0.9898 0.995  0.9985 0.9993 1.    ]
# first 1 PCs keep 36.98% variance
# first 2 PCs keep 65.21% variance
# first 3 PCs keep 80.59% variance
# first 4 PCs keep 89.86% variance
# first 5 PCs keep 98.13% variance
# first 6 PCs keep 98.98% variance
# first 7 PCs keep 99.50% variance
# first 8 PCs keep 99.85% variance
# first 9 PCs keep 99.93% variance
# first 10 PCs keep 100.00% variance
# components needed for >=95.0% variance: 5
# feature dim for angles: 5 | USE_PCA=True

# %% [markdown]
# ## Data Subset (Optional)

# %%
SUBSET = True   # set to False for the full dataset
PER_CLASS_CAP = 20000

# %%
# compare sampling strategies on RAW full train, then apply DPP coreset
if SUBSET:
    plot_dataset_and_sampling_analysis(
        X_train_full,
        y_train_full,
        per_class_cap=PER_CLASS_CAP,
        class_names=class_names,
        seed=SEED,
    )

    print(f"\nRunning representative DPP coreset sampling (cap={PER_CLASS_CAP})...")
    X_train, y_train = greedy_dpp_sample(
        X_train_full, y_train_full, per_class_cap=PER_CLASS_CAP, seed=SEED
    )
    print(f"Coreset selected: {X_train.shape[0]} samples.")
else:
    X_train, y_train = X_train_full, y_train_full
    print(f"using full train (no subset): {X_train.shape[0]} samples")

print(f"train raw: {X_train.shape, y_train.shape} | SUBSET={SUBSET} | cap={PER_CLASS_CAP if SUBSET else 'all'}")
# Out:
# Running representative DPP coreset sampling (cap=20000)...
# Coreset selected: 48359 samples.
# train raw: ((48359, 10), (48359,)) | SUBSET=True | cap=20000

# %% [markdown]
# ## EDA (After Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train, class_names,
    title=f"train (n={len(to_np_y(y_train))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 4

# %% [markdown]
# ## Mapping Features $\rightarrow$ [0, $\pi$]

# %%
# raw -> scale -> optional pca -> [0, pi] using bounds from full train
X_train_angles_all = to_angles(
    X_train, scaler, x_min, x_max, pca=pca if USE_PCA else None, angle_max=np.pi
)

# seeded stratified holdout from train for early stopping (cal/test untouched)
VAL_FRAC = 0.1
_y_all = y_train
idx = np.arange(len(X_train_angles_all))
idx_fit, idx_val = train_test_split(
    idx, test_size=VAL_FRAC, stratify=_y_all, random_state=SEED,
)
X_train_angles, y_train = X_train_angles_all[idx_fit], _y_all[idx_fit]
X_val_angles, y_val = X_train_angles_all[idx_val], _y_all[idx_val]
print(
    f"angles fit: {X_train_angles.shape} | val: {X_val_angles.shape} | "
    f"VAL_FRAC={VAL_FRAC} | USE_PCA={USE_PCA} | SUBSET={SUBSET}"
)

fig, ax1 = plt.subplots(1, 1, figsize=(7, 4))
ax1.hist(X_train_angles.flatten(), bins=50, color="teal", alpha=0.8)
ax1.set_xlabel("angle (radians)")
ax1.set_title("Angle-encoded train (fit) feature distribution")
plt.tight_layout()
plt.show()
# Out:
# angles fit: (43523, 5) | val: (4836, 5) | VAL_FRAC=0.1 | USE_PCA=True | SUBSET=True

# %% [markdown]
# ## Quantum Circuit: Angle Encoding, Data Reuploading, and Adding Noise
#
# $$
# x\xrightarrow[\text{encode}]{\phi(x)}\ket{\psi(x)}\xrightarrow[\text{variational}]{U(\theta)}\ket{\Phi(x)}\xrightarrow{\Lambda_p}\rho(x)
# $$
# - $x$: classical data
# - $\phi(x)$: `qp.AngleEmbedding()`
# - $\ket{\psi(x)}$: quantum state after encoding
# - $U(\theta)$: `qp.StronglyEntanglingLayers()`
# - $\ket{\Phi(x)}$: quantum state after variational transform
# - $\rho(x)=\Lambda_p(\ket{\Phi(x)}\bra{\Phi(x)})$: standard depolarization channel to model NISQ noise

# %%
num_qubits = int(k95)           # pca comps if USE_PCA; else scaled feature dim
num_layers = 2                  # reupload same classical data
noise_rate = DEFAULT_NOISE_RATE
print(f"num_qubits={num_qubits} (USE_PCA={USE_PCA})")
# Out:
# num_qubits=5 (USE_PCA=True)

# %%
# initialize devices
device = get_torch_device()
dev = create_quantum_device(num_qubits) # or dev = qp.device("default.mixed", wires=num_qubits)

# define circuit
forward_circuit = build_forward_circuit(dev, num_qubits, num_layers, noise_rate=noise_rate)

# %% [markdown]
# ## Gradient Variance Probe

# %%
barren_plateau_var = BARREN_PLATEAU_VAR_THRESHOLD
n_trials = 5

safe_empty_cache()

# probe on CPU (recommended)
x_probe = X_train_angles[:1]

try:
    grad_var, grad_samples = gradient_variance_probe(
        forward_circuit, x_probe, num_qubits, num_layers,
        n_trials=n_trials,
        device=torch.device("cpu"),
    )

    print(f"pre-train grad var = {grad_var:.2e} (thr={barren_plateau_var:.0e})")
    if grad_var < barren_plateau_var:
        print("warning: possible barren plateau architecture")

    plt.figure(figsize=(6, 4)); plt.hist(grad_samples, bins=15, color="darkcyan", alpha=0.8)
    plt.title(f"Gradient-variance probe (var={grad_var:.2e})"); plt.tight_layout(); plt.show()

except RuntimeError as e:
    if is_oom_error(e):
        print("\t[OOM] barren-plateau probe skipped (non-critical diagnostic).")
        safe_empty_cache()
    else:
        raise
# Out:
# pre-train grad var = 3.14e-09 (thr=1e-06)
# warning: possible barren plateau architecture

# %% [markdown]
# ## Training
#
# $$
# L = L_{CE} + \lambda_1*L_{intra} + \lambda_2*L_{inter}
# $$
#
# Minimizing:
# - $L_{CE}$ adjusts $\theta$ for better class predictions.
# - $L_{intra}$ pulls each sample toward its class prototype
# - $L_{inter}$ pushs different-class prototypes apart (maximize trace distance)

# %%
epochs = 50
batch_size = 64
lr = 0.01
lambda1 = 0.5
lambda2 = 0.1
early_stopping = True
patience = 5
min_delta = 0.001

out_dir = Path("artifacts") / dataset
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_dir = out_dir / f"{NOTEBOOK_NAME}_seed{SEED}"
latest_ckpt = ckpt_dir / "maqt-latest.pt"
resume_from = latest_ckpt if latest_ckpt.exists() else None

print(f"checkpoint_dir: {ckpt_dir}")
print(f"resume_from: {resume_from}")
# Out:
# checkpoint_dir: artifacts/BoT-IoT/4class-20000each-lr0.01auto-lambda2-maqt_seed42
# resume_from: None

# %%
torch.manual_seed(SEED)

result = run_batched_safely(
    train_maqt,
    X_train_angles,
    y_train,
    n_classes=num_classes,
    n_qubits=num_qubits,
    n_layers=num_layers,
    forward_circuit=forward_circuit,
    device=device,
    epochs=epochs,
    lr=lr,
    use_lr_schedule=True,  # auto LR
    batch_size=batch_size,
    min_batch=2,
    label="train_maqt",
    lambda1_max=lambda1,
    lambda2_max=lambda2,
    use_weighted_sampler=True,
    seed=SEED,
    early_stopping=early_stopping,
    patience=patience,
    min_delta=min_delta,
    X_val=X_val_angles,
    y_val=y_val,
    checkpoint_dir=ckpt_dir,
    save_every_epoch=True,
    resume_from=resume_from,
    reset_early_stopping_on_resume=True,
    heartbeat_every_steps=20,  # pass None to less verbose
    notebook_name=NOTEBOOK_NAME,
    log_dir=ckpt_dir,
)

if result is None:
    raise RuntimeError("train_maqt failed even at min_batch (OOM)")

theta, head, prototypes, ema_protos, history = result
theta_star = theta
classifier_head = head
safe_empty_cache()
print(
    "\n"
    f"epochs_ran={history.get('epochs_ran')} | "
    f"best_epoch={history.get('best_epoch')} | "
    f"stopped_early={history.get('stopped_early')} | "
    f"stop_reason={history.get('stop_reason')}"
)
# Out:
# 	epoch 1 step 20 (3%) loss=1.3009 elapsed=21s eta=680s
# 	epoch 1 step 40 (6%) loss=1.2276 elapsed=38s eta=609s
# 	epoch 3 step 160 (24%) loss=0.5809 elapsed=99s eta=321s
# 	epoch 3 step 180 (26%) loss=0.4904 elapsed=111s eta=308s
# 	epoch 3 step 200 (29%) loss=0.5030 elapsed=123s eta=296s
# 	epoch 3 step 220 (32%) loss=0.5239 elapsed=136s eta=284s
# 	epoch 3 step 240 (35%) loss=0.4154 elapsed=148s eta=271s
# 	epoch 3 step 260 (38%) loss=0.4471 elapsed=160s eta=259s
# 	epoch 3 step 280 (41%) loss=0.4810 elapsed=173s eta=246s
# 	epoch 3 step 300 (44%) loss=0.5022 elapsed=185s eta=234s
# 	epoch 3 step 320 (47%) loss=0.5665 elapsed=197s eta=222s
# 	epoch 3 step 340 (50%) loss=0.3613 elapsed=209s eta=209s
# 	epoch 3 step 360 (53%) loss=0.5756 elapsed=222s eta=197s
# 	epoch 3 step 380 (56%) loss=0.5555 elapsed=234s eta=185s
# 	epoch 3 step 400 (59%) loss=0.7279 elapsed=246s eta=172s
# 	epoch 3 step 420 (62%) loss=0.6065 elapsed=259s eta=160s
# 	epoch 3 step 440 (65%) loss=0.4782 elapsed=271s eta=148s
# 	epoch 3 step 460 (68%) loss=0.5901 elapsed=283s eta=136s
# 	epoch 3 step 480 (71%) loss=0.5142 elapsed=296s eta=123s
# 	epoch 3 step 500 (74%) loss=0.3992 elapsed=308s eta=111s
# 	epoch 3 step 520 (76%) loss=0.4876 elapsed=320s eta=99s
# 	epoch 3 step 540 (79%) loss=0.5068 elapsed=333s eta=86s
# 	epoch 3 step 560 (82%) loss=0.4411 elapsed=345s eta=74s
# 	epoch 3 step 580 (85%) loss=0.4806 elapsed=357s eta=62s
# 	epoch 3 step 600 (88%) loss=0.5810 elapsed=370s eta=49s
# 	epoch 3 step 620 (91%) loss=0.7035 elapsed=382s eta=37s
# 	epoch 3 step 640 (94%) loss=0.5477 elapsed=394s eta=25s
# 	epoch 3 step 660 (97%) loss=0.5322 elapsed=407s eta=12s
# 	epoch 3 step 680 (100%) loss=0.5666 elapsed=419s eta=0s
# epoch  3/50 | time 419.2s | loss 0.5375 | L_CE 0.5295 | L_intra 0.1813 | L_inter -0.5054 | grad_var 4.71e-03 | intra_fid 0.819 | inter_TD 0.515 | val_loss 0.6889 | lr 9.96e-03 | peak_mem=50MB | best=0.6889@ep3 | bad=0/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.01auto-lambda2-maqt_seed42/maqt-epoch003.pt
# 	epoch 4 step 20 (3%) loss=0.4783 elapsed=12s eta=407s
# 	epoch 4 step 40 (6%) loss=0.3454 elapsed=25s eta=395s
# 	epoch 4 step 60 (9%) loss=0.4411 elapsed=37s eta=382s
# 	epoch 4 step 80 (12%) loss=0.4438 elapsed=49s eta=371s
# 	epoch 4 step 100 (15%) loss=0.4984 elapsed=62s eta=358s
# 	epoch 4 step 120 (18%) loss=0.4971 elapsed=74s eta=346s
# 	epoch 4 step 140 (21%) loss=0.4368 elapsed=86s eta=333s
# 	epoch 4 step 160 (24%) loss=0.5597 elapsed=99s eta=321s
# 	epoch 4 step 180 (26%) loss=0.5305 elapsed=111s eta=308s
# 	epoch 4 step 200 (29%) loss=0.5821 elapsed=123s eta=296s
# 	epoch 13 step 660 (97%) loss=0.4636 elapsed=409s eta=12s
# 	epoch 13 step 680 (100%) loss=0.5741 elapsed=421s eta=0s
# epoch 13/50 | time 421.5s | loss 0.4798 | L_CE 0.4454 | L_intra 0.1708 | L_inter -0.5096 | grad_var 1.53e-02 | intra_fid 0.829 | inter_TD 0.520 | val_loss 0.6629 | lr 8.66e-03 | peak_mem=50MB | best=0.6629@ep13 | bad=0/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.01auto-lambda2-maqt_seed42/maqt-epoch013.pt
# 	epoch 14 step 20 (3%) loss=0.4634 elapsed=12s eta=411s
# 	epoch 14 step 40 (6%) loss=0.4285 elapsed=25s eta=397s
# 	epoch 14 step 60 (9%) loss=0.4787 elapsed=37s eta=385s
# 	epoch 14 step 80 (12%) loss=0.4140 elapsed=50s eta=373s
# 	epoch 14 step 100 (15%) loss=0.4394 elapsed=62s eta=360s
# 	epoch 14 step 120 (18%) loss=0.3369 elapsed=74s eta=347s
# 	epoch 14 step 140 (21%) loss=0.3986 elapsed=87s eta=334s
# 	epoch 14 step 160 (24%) loss=0.4445 elapsed=99s eta=322s
# 	epoch 14 step 180 (26%) loss=0.4295 elapsed=112s eta=310s
# 	epoch 14 step 200 (29%) loss=0.5408 elapsed=124s eta=298s
# 	epoch 14 step 220 (32%) loss=0.5683 elapsed=137s eta=286s
# 	epoch 14 step 240 (35%) loss=0.6729 elapsed=149s eta=274s
# 	epoch 14 step 260 (38%) loss=0.3856 elapsed=162s eta=261s
# 	epoch 14 step 280 (41%) loss=0.4828 elapsed=174s eta=249s
# 	epoch 14 step 300 (44%) loss=0.4843 elapsed=187s eta=236s
# 	epoch 14 step 320 (47%) loss=0.4696 elapsed=199s eta=224s
# 	epoch 14 step 340 (50%) loss=0.5258 elapsed=211s eta=211s
# 	epoch 14 step 360 (53%) loss=0.4521 elapsed=224s eta=200s
# 	epoch 14 step 380 (56%) loss=0.4209 elapsed=237s eta=187s
# 	epoch 14 step 400 (59%) loss=0.5429 elapsed=250s eta=175s
# 	epoch 14 step 420 (62%) loss=0.5449 elapsed=262s eta=162s
# 	epoch 14 step 440 (65%) loss=0.4638 elapsed=275s eta=150s
# 	epoch 14 step 460 (68%) loss=0.4455 elapsed=287s eta=137s
# 	epoch 14 step 480 (71%) loss=0.4377 elapsed=301s eta=125s
# 	epoch 14 step 500 (74%) loss=0.6324 elapsed=314s eta=113s
# 	epoch 14 step 520 (76%) loss=0.4459 elapsed=327s eta=101s
# 	epoch 14 step 540 (79%) loss=0.6446 elapsed=341s eta=88s
# 	epoch 14 step 560 (82%) loss=0.4896 elapsed=354s eta=76s
# 	epoch 14 step 580 (85%) loss=0.4869 elapsed=366s eta=63s
# 	epoch 14 step 600 (88%) loss=0.4009 elapsed=379s eta=51s
# 	epoch 14 step 620 (91%) loss=0.4446 elapsed=392s eta=38s
# 	epoch 14 step 640 (94%) loss=0.4696 elapsed=405s eta=25s
# 	epoch 14 step 660 (97%) loss=0.5040 elapsed=418s eta=13s
# 	epoch 14 step 680 (100%) loss=0.4444 elapsed=431s eta=0s
# epoch 14/50 | time 431.5s | loss 0.4734 | L_CE 0.4394 | L_intra 0.1692 | L_inter -0.5067 | grad_var 1.54e-02 | intra_fid 0.831 | inter_TD 0.509 | val_loss 0.6589 | lr 8.44e-03 | peak_mem=50MB | best=0.6589@ep14 | bad=0/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.01auto-lambda2-maqt_seed42/maqt-epo
| bad=1/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.01auto-lambda2-maqt_seed42/maqt-epoch016.pt
# 	epoch 17 step 20 (3%) loss=0.4593 elapsed=14s eta=459s
# 	epoch 17 step 40 (6%) loss=0.4779 elapsed=28s eta=446s
# 	epoch 17 step 60 (9%) loss=0.3348 elapsed=42s eta=433s
# 	epoch 17 step 80 (12%) loss=0.4601 elapsed=56s eta=420s
# 	epoch 17 step 100 (15%) loss=0.3800 elapsed=70s eta=407s
# 	epoch 17 step 120 (18%) loss=0.4710 elapsed=83s eta=387s
# 	epoch 17 step 140 (21%) loss=0.3954 elapsed=95s eta=368s
# 	epoch 17 step 160 (24%) loss=0.3840 elapsed=108s eta=351s
# 	epoch 17 step 180 (26%) loss=0.5163 elapsed=121s eta=336s
# 	epoch 17 step 200 (29%) loss=0.3697 elapsed=134s eta=321s
# 	epoch 17 step 220 (32%) loss=0.6145 elapsed=146s eta=306s
# 	epoch 17 step 240 (35%) loss=0.3901 elapsed=159s eta=291s
# 	epoch 17 step 260 (38%) loss=0.4380 elapsed=171s eta=277s
# 	epoch 17 step 280 (41%) loss=0.5002 elapsed=184s eta=262s
# 	epoch 17 step 300 (44%) loss=0.5158 elapsed=196s eta=248s
# 	epoch 17 step 320 (47%) loss=0.4793 elapsed=208s eta=234s
# 	epoch 17 step 340 (50%) loss=0.4466 elapsed=221s eta=221s
# 	epoch 17 step 360 (53%) loss=0.4435 elapsed=233s eta=207s
# 	epoch 17 step 380 (56%) loss=0.5267 elapsed=245s eta=194s
# 	epoch 17 step 400 (59%) loss=0.5356 elapsed=258s eta=180s
# 	epoch 17 step 420 (62%) loss=0.3606 elapsed=270s eta=167s
# 	epoch 17 step 440 (65%) loss=0.4818 elapsed=282s eta=154s
# 	epoch 17 step 460 (68%) loss=0.6213 elapsed=295s eta=141s
# 	epoch 17 step 480 (71%) loss=0.4287 elapsed=307s eta=128s
# 	epoch 17 step 500 (74%) loss=0.5308 elapsed=319s eta=115s
# 	epoch 17 step 520 (76%) loss=0.5491 elapsed=331s eta=102s
# 	epoch 17 step 540 (79%) loss=0.5199 elapsed=344s eta=89s
# 	epoch 17 step 560 (82%) loss=0.4100 elapsed=356s eta=76s
# 	epoch 17 step 580 (85%) loss=0.4719 elapsed=368s eta=64s
# 	epoch 17 step 600 (88%) loss=0.4367 elapsed=381s eta=51s
# 	epoch 17 step 620 (91%) loss=0.5561 elapsed=393s eta=38s
# 	epoch 17 step 640 (94%) loss=0.4863 elapsed=405s eta=25s
# 	epoch 17 step 660 (97%) loss=0.5722 elapsed=417s eta=13s
# 	epoch 17 step 680 (100%) loss=0.5533 elapsed=430s eta=0s
# epoch 17/50 | time 429.8s | loss 0.4675 | L_CE 0.4348 | L_intra 0.1663 | L_inter -0.5044 | grad_var 1.67e-02 | intra_fid 0.834 | inter_TD 0.500 | val_loss 0.6425 | lr 7.70e-03 | peak_mem=50MB | best=0.6360@ep15 | bad=2/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.01auto-lambda2-maqt_seed42/maqt-epo
# 	epoch 20 step 200 (29%) loss=0.5049 elapsed=123s eta=296s
# 	epoch 20 step 220 (32%) loss=0.4660 elapsed=136s eta=284s
# 	epoch 20 step 240 (35%) loss=0.4099 elapsed=148s eta=272s
# 	epoch 20 step 260 (38%) loss=0.3326 elapsed=160s eta=259s
# 	epoch 20 step 280 (41%) loss=0.5058 elapsed=173s eta=247s
# 	epoch 20 step 300 (44%) loss=0.3814 elapsed=185s eta=235s
# 	epoch 20 step 320 (47%) loss=0.3670 elapsed=198s eta=222s
# 	epoch 20 step 340 (50%) loss=0.4209 elapsed=210s eta=210s
# 	epoch 20 step 360 (53%) loss=0.5269 elapsed=222s eta=198s
# 	epoch 20 step 380 (56%) loss=0.4093 elapsed=235s eta=185s
# 	epoch 20 step 400 (59%) loss=0.3149 elapsed=247s eta=173s
# 	epoch 20 step 420 (62%) loss=0.5120 elapsed=260s eta=161s
# 	epoch 20 step 440 (65%) loss=0.2837 elapsed=272s eta=148s
# 	epoch 20 step 460 (68%) loss=0.4691 elapsed=284s eta=136s
# 	epoch 20 step 480 (71%) loss=0.5633 elapsed=297s eta=124s
# 	epoch 20 step 500 (74%) loss=0.3394 elapsed=309s eta=111s
# 	epoch 20 step 520 (76%) loss=0.4279 elapsed=321s eta=99s
# 	epoch 20 step 540 (79%) loss=0.4179 elapsed=333s eta=86s
# 	epoch 20 step 560 (82%) loss=0.4767 elapsed=346s eta=74s
# 	epoch 20 step 580 (85%) loss=0.4019 elapsed=358s eta=62s
# 	epoch 20 step 600 (88%) loss=0.3747 elapsed=370s eta=49s
# 	epoch 20 step 620 (91%) loss=0.3591 elapsed=383s eta=37s
# 	epoch 20 step 640 (94%) loss=0.4814 elapsed=395s eta=25s
# 	epoch 20 step 660 (97%) loss=0.5447 elapsed=407s eta=12s
# 	epoch 20 step 680 (100%) loss=0.5371 elapsed=419s eta=0s
# epoch 20/50 | time 419.5s | loss 0.4566 | L_CE 0.4250 | L_intra 0.1638 | L_inter -0.5027 | grad_var 1.78e-02 | intra_fid 0.836 | inter_TD 0.511 | val_loss 0.6466 | lr 6.87e-03 | peak_mem=50MB | best=0.6360@ep15 | bad=5/5
#   saved checkpoint: artifacts/BoT-IoT/4class-20000each-lr0.01auto-lambda2-maqt_seed42/maqt-epoch020.pt
# early stopping at epoch 20: no val_loss improvement for 5 epochs (best=0.6360 @ epoch 15)
# restored best MAQT weights from epoch 15 (val_loss=0.6360)
#
# epochs_ran=20 | best_epoch=15 | stopped_early=True | stop_reason=early_stopping

# %% [markdown]
# ## Prototypes

# %%
proto_df = pd.DataFrame(prototype_summary(prototypes, class_names))
proto_df
# Out:
#             class  dim     trace
# 0            DDoS   32  1.000001
# 1             DoS   32  1.000001
# 2          Normal   32  1.000001
# 3  Reconnaissance   32  1.000001

# %%
# save prototypes (all-in-one checkpoint)
out_dir = Path("artifacts") / dataset
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_path = out_dir / f"{NOTEBOOK_NAME}-checkpoint.pt"
torch.save(
    {
        "theta": theta_star.detach().cpu(),
        "head_state_dict": head.state_dict(),
        "prototypes": {k: v.detach().cpu() for k, v in prototypes.items()},

        # rebuild / inference meta
        "class_names": list(class_names),
        "num_classes": num_classes,
        "num_qubits": num_qubits,
        "num_layers": num_layers,
        "noise_rate": noise_rate,

        # FROZEN feature + angle pipeline (must match train)
        "feature_cols": list(FEATURE_COLS),
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "target_col": target_col,
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "scaler": scaler,                    # StandardScaler fitted on full train
        "pca": pca,                          # PCA fitted on scaled full train (or None)
        "k95": int(k95),
        "angle_x_min": np.asarray(x_min),    # on pca space if USE_PCA else scaled space
        "angle_x_max": np.asarray(x_max),
        "angle_min": 0.0,
        "angle_max": float(np.pi),
    },
    ckpt_path,
)
print("published:", ckpt_path.resolve())
# Out:
# published: /home/lawun330/Desktop/quantum-sentinel/artifacts/BoT-IoT/4class-20000each-lr0.01auto-lambda2-maqt-checkpoint.pt

# %% [markdown]
# ## Visualization

# %%
# plots
epochs_x = range(1, len(history["loss"]) + 1)

fig, axes = plt.subplots(1, 3, figsize=(14, 4))

# total loss
axes[0].plot(epochs_x, history["loss"], marker="o")
axes[0].set_title("Total loss")
axes[0].set_xlabel("Epoch")

# decomposed (weighted like the objective)
axes[1].plot(epochs_x, history["loss"], marker=None, label=r"$L$")
axes[1].plot(epochs_x, history["L_CE"], "--", label=r"$L_{CE}$")
axes[1].plot(epochs_x, [lambda1 * v for v in history["L_intra"]], "--", label=r"$\lambda_1 L_{intra}$")
axes[1].plot(epochs_x, [lambda2 * v for v in history["L_inter"]], "--", label=r"$\lambda_2 L_{inter}$")
axes[1].set_title(r"$Decomposed L = L_{CE}+\lambda_1 L_{intra}+\lambda_2 L_{inter}$")
axes[1].legend(fontsize=8)

# grad var
axes[2].plot(epochs_x, history["grad_var"], marker="o", color="tab:orange")
axes[2].axhline(1e-6, color="red", linestyle="--", label="plateau thr")  # or BARREN_PLATEAU_VAR_THRESHOLD
axes[2].set_title("Gradient variance")
axes[2].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Logging

# %%
# write log (final)
log_path = write_history_log(
    history,
    NOTEBOOK_NAME,
    extra={
        ## data
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "dataset": dataset,
        "feature_cols": FEATURE_COLS,
        "target_col": target_col,
        "n_train": len(X_train),
        "class_names": list(class_names),
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "num_qubits": num_qubits,
        "k95": int(k95),

        # algo 1: MAQT train
        "epochs": epochs,
        "batch_size": batch_size,
        "lr": lr,
        "lambda1": lambda1,
        "lambda2": lambda2,

        ## quantum model
        "noise_rate": noise_rate,
        "num_layers": num_layers,
        "num_classes": num_classes,

        ## training
        "train_total_sec": float(sum(history["epoch_sec"])) if history.get("epoch_sec") else None,
        "loss_last": float(history["loss"][-1]) if history["loss"] else None,
        "barren_plateau_var": barren_plateau_var,
        "barren_plateau_any": bool(
            any(g < barren_plateau_var for g in history["grad_var"])
        ) if history.get("grad_var") else None,
        "seed": SEED,
        "early_stopping": early_stopping,
        "patience": patience,
        "best_epoch": history.get("best_epoch"),
        "best_score": history.get("best_score"),
        "stopped_early": history.get("stopped_early"),
        "epochs_ran": history.get("epochs_ran"),
        "stop_reason": history.get("stop_reason"),
        "interrupted": history.get("interrupted"),
        "checkpoint_dir": str(ckpt_dir),
    },
    log_dir="logs",
)
print(f"wrote {log_path.resolve()}")
# Out:
# wrote /home/lawun330/Desktop/quantum-sentinel/logs/4class-20000each-lr0.01auto-lambda2-maqt.log
