# %% [markdown]
# # QS-Net (PyTorch Version): Tune $\lambda_1$, $\lambda_2$ Sensitivity
# ## BoT_IoT | 0.5% Training (Weighted) | Batch Size 64 | 10 Epochs | LR 0.05
# ## Target (y) = "label_multiclass" | Data Reupload = 2

# %% [markdown]
# ## Setup

# %%
import pennylane as qp
from pennylane import numpy as np
import torch
import torch.nn as nn

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import f1_score, confusion_matrix, classification_report

import json
from pathlib import Path
from itertools import product
import time
from collections import Counter

# %%
from scripts.constants import DEFAULT_NOISE_RATE
from scripts.data import load_split, stratified_head
from scripts.circuit import build_forward_circuit, create_quantum_device, initialize_weights
from scripts.prototypes import PrototypeBank
from scripts.loss import maqt_loss, gradient_variance
from scripts.logging import write_history_log
from scripts.inference import predict_labels
from scripts.utils import to_np_x, to_torch_x

# %%
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available?: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA device name: {torch.cuda.get_device_name(0)}")
    print(f"Current CUDA device index: {torch.cuda.current_device()}")
# Out:
# PyTorch version: 2.12.1+cu126
# CUDA available?: True
# CUDA device name: NVIDIA GeForce GTX 1060
# Current CUDA device index: 0

# %% [markdown]
# ## Load Dataset: BoT_IoT

# %%
NOTEBOOK_NAME = "tune-lambdas-bot-iot"
dataset = "BoT_IoT"
data_path = f"data/{dataset}/quantum"
target_col = "label_multiclass"
split_prefix = "q8"

# %%
df = pd.read_parquet(f"{data_path}/{split_prefix}_train.parquet")
df
# Out:
#             rate  n_bytes_total  rate_src  dst_pkts  n_pkts_total  dst_bytes  \
# 0       0.030780       0.332164  0.032406    0.0000      0.295669   0.000000
# 1       0.040153       0.429708  0.042274    0.0000      0.404791   0.000000
# 2       0.114465       0.476056  0.120511    0.0000      0.458797   0.000000
# 3       0.051103       0.527890  0.053802    0.0000      0.295669   0.000000
# 4       0.018999       0.421771  0.020003    0.0000      0.186546   0.000000
# ...          ...            ...       ...       ...           ...        ...
# 130133  0.051554       0.337622  0.054277    0.0000      0.109122   0.000000
# 130134  0.077777       0.495858  0.081885    0.0000      0.482215   0.000000
# 130135  0.085139       0.332164  0.089636    0.0000      0.295669   0.000000
# 130136  0.034507       0.527890  0.036329    0.0000      0.295669   0.000000
# 130137  0.059124       0.571553  0.046360    0.2968      0.404791   0.813308
#
#         src_bytes  src_pkts label_multiclass  label_binary label_family
# 0        0.395761  0.295669              DoS             1          dos
# 1        0.491098  0.404791              DoS             1          dos
# 2        0.536396  0.458797             DDoS             1         ddos
# 3        0.587057  0.295669             DDoS             1         ddos
# 4        0.483341  0.186546              DoS             1          dos
# ...           ...       ...              ...           ...          ...
# 130133   0.401096  0.109122             DDoS             1         ddos
# 130134   0.555750  0.482215             DDoS             1         ddos
# 130135   0.395761  0.295669             DDoS             1         ddos
# 130136   0.587057  0.295669             DDoS             1         ddos
# 130137   0.602299  0.337155             DDoS             1         ddos
#
# [130138 rows x 11 columns]

# %%
print(df["label_multiclass"].unique())
print()
print(df["label_family"].unique())
# Out:
# <ArrowStringArray>
# ['DoS', 'DDoS', 'Reconnaissance', 'Normal']
# Length: 4, dtype: str
#
# <ArrowStringArray>
# ['dos', 'ddos', 'recon', 'benign']
# Length: 4, dtype: str

# %%
# check rows if NaN dropped
df[df[target_col].notna()].copy()
# Out:
#             rate  n_bytes_total  rate_src  dst_pkts  n_pkts_total  dst_bytes  \
# 0       0.030780       0.332164  0.032406    0.0000      0.295669   0.000000
# 1       0.040153       0.429708  0.042274    0.0000      0.404791   0.000000
# 2       0.114465       0.476056  0.120511    0.0000      0.458797   0.000000
# 3       0.051103       0.527890  0.053802    0.0000      0.295669   0.000000
# 4       0.018999       0.421771  0.020003    0.0000      0.186546   0.000000
# ...          ...            ...       ...       ...           ...        ...
# 130133  0.051554       0.337622  0.054277    0.0000      0.109122   0.000000
# 130134  0.077777       0.495858  0.081885    0.0000      0.482215   0.000000
# 130135  0.085139       0.332164  0.089636    0.0000      0.295669   0.000000
# 130136  0.034507       0.527890  0.036329    0.0000      0.295669   0.000000
# 130137  0.059124       0.571553  0.046360    0.2968      0.404791   0.813308
#
#         src_bytes  src_pkts label_multiclass  label_binary label_family
# 0        0.395761  0.295669              DoS             1          dos
# 1        0.491098  0.404791              DoS             1          dos
# 2        0.536396  0.458797             DDoS             1         ddos
# 3        0.587057  0.295669             DDoS             1         ddos
# 4        0.483341  0.186546              DoS             1          dos
# ...           ...       ...              ...           ...          ...
# 130133   0.401096  0.109122             DDoS             1         ddos
# 130134   0.555750  0.482215             DDoS             1         ddos
# 130135   0.395761  0.295669             DDoS             1         ddos
# 130136   0.587057  0.295669             DDoS             1         ddos
# 130137   0.602299  0.337155             DDoS             1         ddos
#
# [130138 rows x 11 columns]

# %%
# get labels
class_names = sorted(df[target_col].dropna().unique())
class_names
# Out:
# ['DDoS', 'DoS', 'Normal', 'Reconnaissance']

# %%
# load all data
X_train_full, y_train_full = load_split(data_path, f"{split_prefix}_train", target_col, class_names)
X_val_full, y_val_full = load_split(data_path, f"{split_prefix}_val", target_col, class_names)

# %%
# check shape
[X_train_full.shape, y_train_full.shape], [X_val_full.shape, y_val_full.shape]
# Out:
# ([(130138, 8), (130138,)], [(18591, 8), (18591,)])

# %% [markdown]
# ## Class Weighting, Data Subset
#
# - Rebalance **training only** (tempered class-weighted CE).
# - Keep **val / calibration / test** unchanged (natural distribution).
# - Do **not** use hard equal-count undersampling of every class.
# - Do **not** use SMOTE after quantum encoding.
# - Never train/tune on zero-day.

# %%
percentage = 0.5 / 100 # 0.5% of original data

# %%
# take subset
X_train, y_train = stratified_head(X_train_full, y_train_full, round(percentage * X_train_full.shape[0]), seed=42)
X_val, y_val = stratified_head(X_val_full, y_val_full, round(percentage * X_val_full.shape[0]), seed=42)

# %%
# recompute tempered weights on the actual training y
y_np = to_np_x(y_train).astype(int)
counts = Counter(y_np.tolist())
raw = {c: 1.0 / (counts[c] ** 0.5) for c in counts}

# normalize to mean 1, then clip
mean_w = sum(raw.values()) / len(raw)
class_weight = {c: min(max(raw[c] / mean_w, 0.25), 4.0) for c in raw}

weight_tensor = torch.tensor(
    [class_weight.get(i, 1.0) for i in range(len(class_names))],
    dtype=torch.float32,
)

print("train class counts:", dict(sorted(counts.items())))
print()
print("tempered class weights:", {class_names[c]: round(class_weight[c], 3) for c in sorted(class_weight)})
# Out:
# train class counts: {0: 330, 1: 285, 2: 24, 3: 12}
#
# tempered class weights: {'DDoS': 0.363, 'DoS': 0.39, 'Normal': 1.345, 'Reconnaissance': 1.902}

# %%
# check shape
[X_train.shape, y_train.shape], [X_val.shape, y_val.shape]
# Out:
# ([(651, 8), (651,)], [(93, 8), (93,)])

# %% [markdown]
# ## EDA (After Class-Weighting)

# %%
num_classes = len(class_names)
num_qubits = X_train.shape[1]

print(f"classes: {class_names}")
print(f"\nnumber of classes: {num_classes}")
print(f"\nnumber of qubits: {num_qubits}")
# Out:
# classes: ['DDoS', 'DoS', 'Normal', 'Reconnaissance']
#
# number of classes: 4
#
# number of qubits: 8

# %%
# initialize devices
dev = qp.device("default.mixed", wires=num_qubits)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# convert data type and move to device
X_train = to_torch_x(X_train, device)
y_train = to_torch_x(y_train, device).long()

# move weight tensor to device
weight_tensor = weight_tensor.to(device)

# verify
X_train[:5], y_train[:5], weight_tensor
# Out:
# (tensor([[0.0717, 0.5460, 0.0755, 0.0000, 0.5423, 0.0000, 0.6047, 0.5423],
#          [0.0191, 0.5279, 0.0201, 0.0000, 0.2957, 0.0000, 0.5871, 0.2957],
#          [0.0748, 0.1425, 0.0787, 0.0000, 0.1091, 0.0000, 0.2104, 0.1091],
#          [0.1527, 0.3700, 0.1608, 0.0000, 0.3372, 0.0000, 0.4327, 0.3372],
#          [0.0513, 0.3700, 0.0540, 0.0000, 0.3372, 0.0000, 0.4327, 0.3372]],
#         device='cuda:0'),
#  tensor([1, 1, 0, 1, 1], device='cuda:0'),
#  tensor([0.3627, 0.3903, 1.3450, 1.9020], device='cuda:0'))

# %% [markdown]
# ## Quantum Circuit: Angle Encoding, Data Reuploading, and Adding Noise

# %%
num_layers = 2                  # reupload same classical data
noise_rate = DEFAULT_NOISE_RATE

# %%
# initialize deviceSize
dev = create_quantum_device(num_qubits)

# define circuit
forward_circuit = build_forward_circuit(dev, num_qubits, num_layers, noise_rate=noise_rate)

# no global theta and classifier head initalization
## each lambdas pair has its own theta and classifier head

# %% [markdown]
# ## Training
#
# Minimizing:
# - $L_{CE}$ adjusts $\theta$ for better class predictions.
# - $L_{intra}$ pulls each sample toward its class prototype
# - $L_{inter}$ pushs different-class prototypes apart (maximize trace distance)

# %%
# # smoke test
# lambda1_grid = [0.0, 0.1]
# lambda2_grid = [0.0, 0.1]

# real test
lambda1_grid = [0.0, 0.33, 0.66, 1.0]
lambda2_grid = [0.0, 0.33, 0.66, 1.0]

lambda_grid = list(product(lambda1_grid, lambda2_grid))
print(f"grid size: {len(lambda_grid)} runs")
for a, b in lambda_grid:
    print(f"  λ1={a}, λ2={b}")
# Out:
# grid size: 16 runs
#   λ1=0.0, λ2=0.0
#   λ1=0.0, λ2=0.33
#   λ1=0.0, λ2=0.66
#   λ1=0.0, λ2=1.0
#   λ1=0.33, λ2=0.0
#   λ1=0.33, λ2=0.33
#   λ1=0.33, λ2=0.66
#   λ1=0.33, λ2=1.0
#   λ1=0.66, λ2=0.0
#   λ1=0.66, λ2=0.33
#   λ1=0.66, λ2=0.66
#   λ1=0.66, λ2=1.0
#   λ1=1.0, λ2=0.0
#   λ1=1.0, λ2=0.33
#   λ1=1.0, λ2=0.66
#   λ1=1.0, λ2=1.0

# %%
seed = 42
epochs = 10
batch_size = 64
lr = 0.05
barren_plateau_var = 1e-6
COMPUTE_GRAD_VAR = False
IMBALANCE_MODE = "class_weighted_ce"

# %%
def train_one_lambda(lambda1, lambda2):
    """
    Fixed-epoch MAQT run returning history and summary metrics.
    """
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

    # initialize weights
    theta = initialize_weights(num_layers, num_qubits, device)

    # define classifier head
    classifier_head = nn.Linear(num_qubits, num_classes).to(device)

    # define loss function
    if IMBALANCE_MODE == "class_weighted_ce":
        ce_loss_fn = nn.CrossEntropyLoss(weight=weight_tensor)
    else:
        ce_loss_fn = nn.CrossEntropyLoss()

    # define optimizer
    optimizer = torch.optim.Adam(list([theta]) + list(classifier_head.parameters()), lr=lr)

    # define prototype bank
    prototype_bank = PrototypeBank(range(num_classes))

    history = {
        "loss": [], "l_ce": [], "l_intra": [], "l_inter": [],
        "grad_var": [], "barren_plateau": [],
        "val_macro_f1": [], "epoch_sec": [],
    }

    num_batches = (len(X_train) + batch_size - 1) // batch_size
    t0 = time.perf_counter()

    for epoch in range(epochs):
        epoch_t0 = time.perf_counter()
        prototype_bank.reset()
        perm = torch.randperm(len(X_train), device=device)

        epoch_grad_vars = []
        epoch_loss, epoch_ce, epoch_intra, epoch_inter = [], [], [], []

        for batch_idx, start in enumerate(range(0, len(perm), batch_size)):
            idx = perm[start : start + batch_size]
            X_batch, y_batch = X_train[idx], y_train[idx]

            for x, label in zip(X_batch, y_batch):
                _, rho_x = forward_circuit(x, theta)
                prototype_bank.update(int(label.item()), rho_x)
            batch_prototypes = prototype_bank.means()

            loss, L_CE, L_intra, L_inter = maqt_loss(
                theta, classifier_head, ce_loss_fn,
                X_batch, y_batch, batch_prototypes, forward_circuit,
                lambda1=lambda1, lambda2=lambda2, device=device,
            )

            optimizer.zero_grad()
            loss.backward()

            if COMPUTE_GRAD_VAR:
                gvar, _ = gradient_variance(
                    theta, classifier_head, ce_loss_fn,
                    X_batch, y_batch, batch_prototypes, forward_circuit,
                    lambda1=lambda1, lambda2=lambda2, device=device,
                )
                epoch_grad_vars.append(gvar)

            optimizer.step()

            epoch_loss.append(float(loss.item()))
            epoch_ce.append(float(L_CE.item()))
            epoch_intra.append(float(L_intra.item()))
            epoch_inter.append(float(L_inter.item()))

        mean_gvar = float(np.mean(epoch_grad_vars)) if epoch_grad_vars else 0.0
        plateau = mean_gvar < barren_plateau_var

        history["loss"].append(float(np.mean(epoch_loss)))
        history["l_ce"].append(float(np.mean(epoch_ce)))
        history["l_intra"].append(float(np.mean(epoch_intra)))
        history["l_inter"].append(float(np.mean(epoch_inter)))
        history["grad_var"].append(mean_gvar)
        history["barren_plateau"].append(bool(plateau))

        y_true, y_pred = predict_labels(
            X_val, y_val, theta, classifier_head, forward_circuit, device
        )
        val_f1 = float(f1_score(y_true, y_pred, average="macro", zero_division=0))
        history["val_macro_f1"].append(val_f1)
        history["epoch_sec"].append(time.perf_counter() - epoch_t0)

        print(
            f"[λ1={lambda1}, λ2={lambda2}] "
            f"epoch {epoch+1:02d}/{epochs} | "
            f"loss={history['loss'][-1]:.4f} | "
            f"l_intra={history['l_intra'][-1]:.4f} | "
            f"l_inter={history['l_inter'][-1]:.4f} | "
            f"val_f1={val_f1:.4f} | "
            f"grad_var={mean_gvar:.2e} | barren={plateau}"
        )

    summary = {
        "lambda1": float(lambda1),
        "lambda2": float(lambda2),
        "epochs": epochs,
        "train_sec": float(time.perf_counter() - t0),
        "val_macro_f1_last": history["val_macro_f1"][-1],
        "val_macro_f1_best": float(max(history["val_macro_f1"])),
        "l_intra_last": history["l_intra"][-1],
        "l_inter_last": history["l_inter"][-1],
        "grad_var_last": history["grad_var"][-1],
        "grad_var_min": float(min(history["grad_var"])) if history["grad_var"] else None,
        "barren_plateau_any": bool(any(history["barren_plateau"])),
        "barren_plateau_ok": not bool(any(history["barren_plateau"])),  # True if never collapsed
    }
    return history, summary

# %%
sensitivity_rows = []
histories = {}

for lambda1, lambda2 in lambda_grid:
    print("=" * 72)
    print(f"training λ1={lambda1}, λ2={lambda2}")
    hist, summary = train_one_lambda(lambda1, lambda2)
    histories[(lambda1, lambda2)] = hist
    sensitivity_rows.append(summary)

sensitivity_df = pd.DataFrame(sensitivity_rows).sort_values(
    ["val_macro_f1_best", "l_intra_last"], ascending=[False, True]
)
sensitivity_df
# Out:
# ========================================================================
# training λ1=0.0, λ2=0.0
# [λ1=0.0, λ2=0.0] epoch 01/10 | loss=0.9353 | l_intra=0.2041 | l_inter=-0.4165 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.0] epoch 02/10 | loss=0.8558 | l_intra=0.1970 | l_inter=-0.4279 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.0] epoch 03/10 | loss=0.8281 | l_intra=0.1736 | l_inter=-0.3742 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.0] epoch 04/10 | loss=0.8086 | l_intra=0.1637 | l_inter=-0.4263 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.0] epoch 05/10 | loss=0.8003 | l_intra=0.1745 | l_inter=-0.3688 | val_f1=0.1691 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.0] epoch 06/10 | loss=0.7998 | l_intra=0.1619 | l_inter=-0.3814 | val_f1=0.5490 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.0] epoch 07/10 | loss=0.8060 | l_intra=0.1558 | l_inter=-0.3875 | val_f1=0.5191 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.0] epoch 08/10 | loss=0.7948 | l_intra=0.1786 | l_inter=-0.4076 | val_f1=0.4191 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.0] epoch 09/10 | loss=0.7888 | l_intra=0.1576 | l_inter=-0.3832 | val_f1=0.5077 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.0] epoch 10/10 | loss=0.7809 | l_intra=0.1654 | l_inter=-0.3905 | val_f1=0.5191 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=0.0, λ2=0.33
# [λ1=0.0, λ2=0.33] epoch 01/10 | loss=0.7978 | l_intra=0.2041 | l_inter=-0.4165 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.33] epoch 02/10 | loss=0.7145 | l_intra=0.1970 | l_inter=-0.4279 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.33] epoch 03/10 | loss=0.7046 | l_intra=0.1736 | l_inter=-0.3742 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.33] epoch 04/10 | loss=0.6679 | l_intra=0.1637 | l_inter=-0.4263 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.33] epoch 05/10 | loss=0.6786 | l_intra=0.1745 | l_inter=-0.3688 | val_f1=0.1691 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.33] epoch 06/10 | loss=0.6739 | l_intra=0.1619 | l_inter=-0.3814 | val_f1=0.5490 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.33] epoch 07/10 | loss=0.6781 | l_intra=0.1558 | l_inter=-0.3875 | val_f1=0.5191 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.33] epoch 08/10 | loss=0.6603 | l_intra=0.1786 | l_inter=-0.4076 | val_f1=0.4191 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.33] epoch 09/10 | loss=0.6623 | l_intra=0.1576 | l_inter=-0.3832 | val_f1=0.5077 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.33] epoch 10/10 | loss=0.6520 | l_intra=0.1654 | l_inter=-0.3905 | val_f1=0.5191 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=0.0, λ2=0.66
# [λ1=0.0, λ2=0.66] epoch 01/10 | loss=0.6604 | l_intra=0.2041 | l_inter=-0.4165 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.66] epoch 02/10 | loss=0.5733 | l_intra=0.1970 | l_inter=-0.4279 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.66] epoch 03/10 | loss=0.5811 | l_intra=0.1736 | l_inter=-0.3742 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.66] epoch 04/10 | loss=0.5273 | l_intra=0.1637 | l_inter=-0.4263 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.66] epoch 05/10 | loss=0.5568 | l_intra=0.1745 | l_inter=-0.3688 | val_f1=0.1691 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.66] epoch 06/10 | loss=0.5481 | l_intra=0.1619 | l_inter=-0.3814 | val_f1=0.5490 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.66] epoch 07/10 | loss=0.5502 | l_intra=0.1558 | l_inter=-0.3875 | val_f1=0.5191 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.66] epoch 08/10 | loss=0.5258 | l_intra=0.1786 | l_inter=-0.4076 | val_f1=0.4191 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.66] epoch 09/10 | loss=0.5358 | l_intra=0.1576 | l_inter=-0.3832 | val_f1=0.5077 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=0.66] epoch 10/10 | loss=0.5231 | l_intra=0.1654 | l_inter=-0.3905 | val_f1=0.5191 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=0.0, λ2=1.0
# [λ1=0.0, λ2=1.0] epoch 01/10 | loss=0.5188 | l_intra=0.2041 | l_inter=-0.4165 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=1.0] epoch 02/10 | loss=0.4278 | l_intra=0.1970 | l_inter=-0.4279 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=1.0] epoch 03/10 | loss=0.4539 | l_intra=0.1736 | l_inter=-0.3742 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=1.0] epoch 04/10 | loss=0.3823 | l_intra=0.1637 | l_inter=-0.4263 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=1.0] epoch 05/10 | loss=0.4314 | l_intra=0.1745 | l_inter=-0.3688 | val_f1=0.1691 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=1.0] epoch 06/10 | loss=0.4184 | l_intra=0.1619 | l_inter=-0.3814 | val_f1=0.5490 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=1.0] epoch 07/10 | loss=0.4185 | l_intra=0.1558 | l_inter=-0.3875 | val_f1=0.5191 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=1.0] epoch 08/10 | loss=0.3872 | l_intra=0.1786 | l_inter=-0.4076 | val_f1=0.4191 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=1.0] epoch 09/10 | loss=0.4055 | l_intra=0.1576 | l_inter=-0.3832 | val_f1=0.5077 | grad_var=0.00e+00 | barren=True
# [λ1=0.0, λ2=1.0] epoch 10/10 | loss=0.3904 | l_intra=0.1654 | l_inter=-0.3905 | val_f1=0.5191 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=0.33, λ2=0.0
# [λ1=0.33, λ2=0.0] epoch 01/10 | loss=1.0011 | l_intra=0.1967 | l_inter=-0.4177 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.0] epoch 02/10 | loss=0.9235 | l_intra=0.1948 | l_inter=-0.4317 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.0] epoch 03/10 | loss=0.8887 | l_intra=0.1684 | l_inter=-0.3723 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.0] epoch 04/10 | loss=0.8586 | l_intra=0.1596 | l_inter=-0.4224 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.0] epoch 05/10 | loss=0.8544 | l_intra=0.1690 | l_inter=-0.3605 | val_f1=0.2941 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.0] epoch 06/10 | loss=0.8505 | l_intra=0.1522 | l_inter=-0.3688 | val_f1=0.2533 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.0] epoch 07/10 | loss=0.8559 | l_intra=0.1444 | l_inter=-0.3696 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.0] epoch 08/10 | loss=0.8505 | l_intra=0.1661 | l_inter=-0.3908 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.0] epoch 09/10 | loss=0.8384 | l_intra=0.1465 | l_inter=-0.3669 | val_f1=0.2764 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.0] epoch 10/10 | loss=0.8358 | l_intra=0.1509 | l_inter=-0.3664 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=0.33, λ2=0.33
# [λ1=0.33, λ2=0.33] epoch 01/10 | loss=0.8633 | l_intra=0.1967 | l_inter=-0.4177 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.33] epoch 02/10 | loss=0.7810 | l_intra=0.1948 | l_inter=-0.4317 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.33] epoch 03/10 | loss=0.7659 | l_intra=0.1684 | l_inter=-0.3723 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.33] epoch 04/10 | loss=0.7192 | l_intra=0.1596 | l_inter=-0.4224 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.33] epoch 05/10 | loss=0.7354 | l_intra=0.1690 | l_inter=-0.3605 | val_f1=0.2941 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.33] epoch 06/10 | loss=0.7288 | l_intra=0.1522 | l_inter=-0.3688 | val_f1=0.2533 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.33] epoch 07/10 | loss=0.7339 | l_intra=0.1444 | l_inter=-0.3696 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.33] epoch 08/10 | loss=0.7215 | l_intra=0.1661 | l_inter=-0.3908 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.33] epoch 09/10 | loss=0.7173 | l_intra=0.1465 | l_inter=-0.3669 | val_f1=0.2764 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.33] epoch 10/10 | loss=0.7149 | l_intra=0.1509 | l_inter=-0.3664 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=0.33, λ2=0.66
# [λ1=0.33, λ2=0.66] epoch 01/10 | loss=0.7255 | l_intra=0.1967 | l_inter=-0.4177 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.66] epoch 02/10 | loss=0.6386 | l_intra=0.1948 | l_inter=-0.4317 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.66] epoch 03/10 | loss=0.6430 | l_intra=0.1684 | l_inter=-0.3723 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.66] epoch 04/10 | loss=0.5798 | l_intra=0.1596 | l_inter=-0.4224 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.66] epoch 05/10 | loss=0.6165 | l_intra=0.1690 | l_inter=-0.3605 | val_f1=0.2941 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.66] epoch 06/10 | loss=0.6071 | l_intra=0.1522 | l_inter=-0.3688 | val_f1=0.2533 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.66] epoch 07/10 | loss=0.6120 | l_intra=0.1444 | l_inter=-0.3696 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.66] epoch 08/10 | loss=0.5926 | l_intra=0.1661 | l_inter=-0.3908 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.66] epoch 09/10 | loss=0.5962 | l_intra=0.1465 | l_inter=-0.3669 | val_f1=0.2764 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=0.66] epoch 10/10 | loss=0.5940 | l_intra=0.1509 | l_inter=-0.3664 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=0.33, λ2=1.0
# [λ1=0.33, λ2=1.0] epoch 01/10 | loss=0.5835 | l_intra=0.1967 | l_inter=-0.4177 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=1.0] epoch 02/10 | loss=0.4918 | l_intra=0.1948 | l_inter=-0.4317 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=1.0] epoch 03/10 | loss=0.5164 | l_intra=0.1684 | l_inter=-0.3723 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=1.0] epoch 04/10 | loss=0.4362 | l_intra=0.1596 | l_inter=-0.4224 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=1.0] epoch 05/10 | loss=0.4939 | l_intra=0.1690 | l_inter=-0.3605 | val_f1=0.2941 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=1.0] epoch 06/10 | loss=0.4817 | l_intra=0.1522 | l_inter=-0.3688 | val_f1=0.2533 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=1.0] epoch 07/10 | loss=0.4863 | l_intra=0.1444 | l_inter=-0.3696 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=1.0] epoch 08/10 | loss=0.4597 | l_intra=0.1661 | l_inter=-0.3908 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=1.0] epoch 09/10 | loss=0.4714 | l_intra=0.1465 | l_inter=-0.3669 | val_f1=0.2764 | grad_var=0.00e+00 | barren=True
# [λ1=0.33, λ2=1.0] epoch 10/10 | loss=0.4694 | l_intra=0.1509 | l_inter=-0.3664 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=0.66, λ2=0.0
# [λ1=0.66, λ2=0.0] epoch 01/10 | loss=1.0640 | l_intra=0.1930 | l_inter=-0.4189 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.0] epoch 02/10 | loss=0.9951 | l_intra=0.1930 | l_inter=-0.4368 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.0] epoch 03/10 | loss=0.9506 | l_intra=0.1682 | l_inter=-0.3728 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.0] epoch 04/10 | loss=0.9150 | l_intra=0.1609 | l_inter=-0.4217 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.0] epoch 05/10 | loss=0.9131 | l_intra=0.1693 | l_inter=-0.3582 | val_f1=0.2941 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.0] epoch 06/10 | loss=0.9004 | l_intra=0.1497 | l_inter=-0.3649 | val_f1=0.2657 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.0] epoch 07/10 | loss=0.9031 | l_intra=0.1406 | l_inter=-0.3616 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.0] epoch 08/10 | loss=0.9041 | l_intra=0.1606 | l_inter=-0.3818 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.0] epoch 09/10 | loss=0.8844 | l_intra=0.1410 | l_inter=-0.3587 | val_f1=0.3249 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.0] epoch 10/10 | loss=0.8834 | l_intra=0.1447 | l_inter=-0.3554 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=0.66, λ2=0.33
# [λ1=0.66, λ2=0.33] epoch 01/10 | loss=0.9258 | l_intra=0.1930 | l_inter=-0.4189 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.33] epoch 02/10 | loss=0.8510 | l_intra=0.1930 | l_inter=-0.4368 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.33] epoch 03/10 | loss=0.8276 | l_intra=0.1682 | l_inter=-0.3728 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.33] epoch 04/10 | loss=0.7758 | l_intra=0.1609 | l_inter=-0.4217 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.33] epoch 05/10 | loss=0.7949 | l_intra=0.1693 | l_inter=-0.3582 | val_f1=0.2941 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.33] epoch 06/10 | loss=0.7800 | l_intra=0.1497 | l_inter=-0.3649 | val_f1=0.2657 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.33] epoch 07/10 | loss=0.7838 | l_intra=0.1406 | l_inter=-0.3616 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.33] epoch 08/10 | loss=0.7781 | l_intra=0.1606 | l_inter=-0.3818 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.33] epoch 09/10 | loss=0.7661 | l_intra=0.1410 | l_inter=-0.3587 | val_f1=0.3249 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.33] epoch 10/10 | loss=0.7661 | l_intra=0.1447 | l_inter=-0.3554 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=0.66, λ2=0.66
# [λ1=0.66, λ2=0.66] epoch 01/10 | loss=0.7876 | l_intra=0.1930 | l_inter=-0.4189 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.66] epoch 02/10 | loss=0.7069 | l_intra=0.1930 | l_inter=-0.4368 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.66] epoch 03/10 | loss=0.7046 | l_intra=0.1682 | l_inter=-0.3728 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.66] epoch 04/10 | loss=0.6367 | l_intra=0.1609 | l_inter=-0.4217 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.66] epoch 05/10 | loss=0.6767 | l_intra=0.1693 | l_inter=-0.3582 | val_f1=0.2941 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.66] epoch 06/10 | loss=0.6596 | l_intra=0.1497 | l_inter=-0.3649 | val_f1=0.2657 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.66] epoch 07/10 | loss=0.6645 | l_intra=0.1406 | l_inter=-0.3616 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.66] epoch 08/10 | loss=0.6521 | l_intra=0.1606 | l_inter=-0.3818 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.66] epoch 09/10 | loss=0.6477 | l_intra=0.1410 | l_inter=-0.3587 | val_f1=0.3249 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=0.66] epoch 10/10 | loss=0.6488 | l_intra=0.1447 | l_inter=-0.3554 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=0.66, λ2=1.0
# [λ1=0.66, λ2=1.0] epoch 01/10 | loss=0.6452 | l_intra=0.1930 | l_inter=-0.4189 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=1.0] epoch 02/10 | loss=0.5584 | l_intra=0.1930 | l_inter=-0.4368 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=1.0] epoch 03/10 | loss=0.5778 | l_intra=0.1682 | l_inter=-0.3728 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=1.0] epoch 04/10 | loss=0.4933 | l_intra=0.1609 | l_inter=-0.4217 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=1.0] epoch 05/10 | loss=0.5550 | l_intra=0.1693 | l_inter=-0.3582 | val_f1=0.2941 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=1.0] epoch 06/10 | loss=0.5355 | l_intra=0.1497 | l_inter=-0.3649 | val_f1=0.2657 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=1.0] epoch 07/10 | loss=0.5416 | l_intra=0.1406 | l_inter=-0.3616 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=1.0] epoch 08/10 | loss=0.5223 | l_intra=0.1606 | l_inter=-0.3818 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=1.0] epoch 09/10 | loss=0.5257 | l_intra=0.1410 | l_inter=-0.3587 | val_f1=0.3249 | grad_var=0.00e+00 | barren=True
# [λ1=0.66, λ2=1.0] epoch 10/10 | loss=0.5280 | l_intra=0.1447 | l_inter=-0.3554 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=1.0, λ2=0.0
# [λ1=1.0, λ2=0.0] epoch 01/10 | loss=1.1279 | l_intra=0.1906 | l_inter=-0.4198 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.0] epoch 02/10 | loss=1.0686 | l_intra=0.1928 | l_inter=-0.4425 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.0] epoch 03/10 | loss=1.0159 | l_intra=0.1700 | l_inter=-0.3778 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.0] epoch 04/10 | loss=0.9761 | l_intra=0.1637 | l_inter=-0.4259 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.0] epoch 05/10 | loss=0.9775 | l_intra=0.1720 | l_inter=-0.3615 | val_f1=0.2941 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.0] epoch 06/10 | loss=0.9548 | l_intra=0.1507 | l_inter=-0.3674 | val_f1=0.3136 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.0] epoch 07/10 | loss=0.9534 | l_intra=0.1409 | l_inter=-0.3618 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.0] epoch 08/10 | loss=0.9598 | l_intra=0.1591 | l_inter=-0.3804 | val_f1=0.2671 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.0] epoch 09/10 | loss=0.9322 | l_intra=0.1387 | l_inter=-0.3571 | val_f1=0.3498 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.0] epoch 10/10 | loss=0.9327 | l_intra=0.1425 | l_inter=-0.3529 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=1.0, λ2=0.33
# [λ1=1.0, λ2=0.33] epoch 01/10 | loss=0.9894 | l_intra=0.1906 | l_inter=-0.4198 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.33] epoch 02/10 | loss=0.9226 | l_intra=0.1928 | l_inter=-0.4425 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.33] epoch 03/10 | loss=0.8913 | l_intra=0.1700 | l_inter=-0.3778 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.33] epoch 04/10 | loss=0.8356 | l_intra=0.1637 | l_inter=-0.4259 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.33] epoch 05/10 | loss=0.8582 | l_intra=0.1720 | l_inter=-0.3615 | val_f1=0.2941 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.33] epoch 06/10 | loss=0.8335 | l_intra=0.1507 | l_inter=-0.3674 | val_f1=0.3136 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.33] epoch 07/10 | loss=0.8340 | l_intra=0.1409 | l_inter=-0.3618 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.33] epoch 08/10 | loss=0.8343 | l_intra=0.1591 | l_inter=-0.3804 | val_f1=0.2671 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.33] epoch 09/10 | loss=0.8144 | l_intra=0.1387 | l_inter=-0.3571 | val_f1=0.3498 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.33] epoch 10/10 | loss=0.8163 | l_intra=0.1425 | l_inter=-0.3529 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=1.0, λ2=0.66
# [λ1=1.0, λ2=0.66] epoch 01/10 | loss=0.8508 | l_intra=0.1906 | l_inter=-0.4198 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.66] epoch 02/10 | loss=0.7765 | l_intra=0.1928 | l_inter=-0.4425 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.66] epoch 03/10 | loss=0.7666 | l_intra=0.1700 | l_inter=-0.3778 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.66] epoch 04/10 | loss=0.6950 | l_intra=0.1637 | l_inter=-0.4259 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.66] epoch 05/10 | loss=0.7389 | l_intra=0.1720 | l_inter=-0.3615 | val_f1=0.2941 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.66] epoch 06/10 | loss=0.7123 | l_intra=0.1507 | l_inter=-0.3674 | val_f1=0.3136 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.66] epoch 07/10 | loss=0.7146 | l_intra=0.1409 | l_inter=-0.3618 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.66] epoch 08/10 | loss=0.7088 | l_intra=0.1591 | l_inter=-0.3804 | val_f1=0.2671 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.66] epoch 09/10 | loss=0.6965 | l_intra=0.1387 | l_inter=-0.3571 | val_f1=0.3498 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=0.66] epoch 10/10 | loss=0.6998 | l_intra=0.1425 | l_inter=-0.3529 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# ========================================================================
# training λ1=1.0, λ2=1.0
# [λ1=1.0, λ2=1.0] epoch 01/10 | loss=0.7081 | l_intra=0.1906 | l_inter=-0.4198 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=1.0] epoch 02/10 | loss=0.6261 | l_intra=0.1928 | l_inter=-0.4425 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=1.0] epoch 03/10 | loss=0.6382 | l_intra=0.1700 | l_inter=-0.3778 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=1.0] epoch 04/10 | loss=0.5502 | l_intra=0.1637 | l_inter=-0.4259 | val_f1=0.1679 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=1.0] epoch 05/10 | loss=0.6160 | l_intra=0.1720 | l_inter=-0.3615 | val_f1=0.2941 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=1.0] epoch 06/10 | loss=0.5874 | l_intra=0.1507 | l_inter=-0.3674 | val_f1=0.3136 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=1.0] epoch 07/10 | loss=0.5916 | l_intra=0.1409 | l_inter=-0.3618 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=1.0] epoch 08/10 | loss=0.5795 | l_intra=0.1591 | l_inter=-0.3804 | val_f1=0.2671 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=1.0] epoch 09/10 | loss=0.5751 | l_intra=0.1387 | l_inter=-0.3571 | val_f1=0.3498 | grad_var=0.00e+00 | barren=True
# [λ1=1.0, λ2=1.0] epoch 10/10 | loss=0.5798 | l_intra=0.1425 | l_inter=-0.3529 | val_f1=0.2405 | grad_var=0.00e+00 | barren=True
#     lambda1  lambda2  epochs    train_sec  val_macro_f1_last  \
# 0      0.00     0.00      10  2303.348274           0.519118
# 1      0.00     0.33      10  2348.226767           0.519118
# 2      0.00     0.66      10  2243.782003           0.519118
# 3      0.00     1.00      10  2131.268419           0.519118
# 12     1.00     0.00      10  2183.207475           0.240546
# 13     1.00     0.33      10  2141.789435           0.240546
# 14     1.00     0.66      10  2127.600743           0.240546
# 15     1.00     1.00      10  2155.131612           0.240546
# 8      0.66     0.00      10  2147.409718           0.240546
# 9      0.66     0.33      10  2169.353679           0.240546
# 10     0.66     0.66      10  2187.346716           0.240546
# 11     0.66     1.00      10  2187.453435           0.240546
# 4      0.33     0.00      10  2712.141144           0.240546
# 5      0.33     0.33      10  2215.767407           0.240546
# 6      0.33     0.66      10  2150.503902           0.240546
# 7      0.33     1.00      10  2178.053738           0.240546
#
#     val_macro_f1_best  l_intra_last  l_inter_last  grad_var_last  \
# 0            0.548993      0.165361     -0.390519            0.0
# 1            0.548993      0.165361     -0.390519            0.0
# 2            0.548993      0.165361     -0.390519            0.0
# 3            0.548993      0.165361     -0.390519            0.0
# 12           0.349805      0.142479     -0.352895            0.0
# 13           0.349805      0.142479     -0.352895            0.0
# 14           0.349805      0.142479     -0.352895            0.0
# 15           0.349805      0.142479     -0.352895            0.0
# 8            0.324885      0.144717     -0.355403            0.0
# 9            0.324885      0.144717     -0.355403            0.0
# 10           0.324885      0.144717     -0.355403            0.0
# 11           0.324885      0.144717     -0.355403            0.0
# 4            0.294065      0.150853     -0.366370            0.0
# 5            0.294065      0.150853     -0.366370            0.0
# 6            0.294065      0.150853     -0.366370            0.0
# 7            0.294065      0.150853     -0.366370            0.0
#
#     grad_var_min  barren_plateau_any  barren_plateau_ok
# 0            0.0                True              False
# 1            0.0                True              False
# 2            0.0                True              False
# 3            0.0                True              False
# 12           0.0                True              False
# 13           0.0                True              False
# 14           0.0                True              False
# 15           0.0                True              False
# 8            0.0                True              False
# 9            0.0                True              False
# 10           0.0                True              False
# 11           0.0                True              False
# 4            0.0                True              False
# 5            0.0                True              False
# 6            0.0                True              False
# 7            0.0                True              False

# %%
cols = ["lambda1","lambda2","val_macro_f1_best","l_intra_last","l_inter_last",
        "grad_var_min","barren_plateau_any","barren_plateau_ok","train_sec"]
print(sensitivity_df[cols].to_string(index=False))
print(f"barren collapses: {int(sensitivity_df['barren_plateau_any'].sum())}/{len(sensitivity_df)}")
# Out:
#  lambda1  lambda2  val_macro_f1_best  l_intra_last  l_inter_last  grad_var_min  barren_plateau_any  barren_plateau_ok   train_sec
#     0.00     0.00           0.548993      0.165361     -0.390519           0.0                True              False 2303.348274
#     0.00     0.33           0.548993      0.165361     -0.390519           0.0                True              False 2348.226767
#     0.00     0.66           0.548993      0.165361     -0.390519           0.0                True              False 2243.782003
#     0.00     1.00           0.548993      0.165361     -0.390519           0.0                True              False 2131.268419
#     1.00     0.00           0.349805      0.142479     -0.352895           0.0                True              False 2183.207475
#     1.00     0.33           0.349805      0.142479     -0.352895           0.0                True              False 2141.789435
#     1.00     0.66           0.349805      0.142479     -0.352895           0.0                True              False 2127.600743
#     1.00     1.00           0.349805      0.142479     -0.352895           0.0                True              False 2155.131612
#     0.66     0.00           0.324885      0.144717     -0.355403           0.0                True              False 2147.409718
#     0.66     0.33           0.324885      0.144717     -0.355403           0.0                True              False 2169.353679
#     0.66     0.66           0.324885      0.144717     -0.355403           0.0                True              False 2187.346716
#     0.66     1.00           0.324885      0.144717     -0.355403           0.0                True              False 2187.453435
#     0.33     0.00           0.294065      0.150853     -0.366370           0.0                True              False 2712.141144
#     0.33     0.33           0.294065      0.150853     -0.366370           0.0                True              False 2215.767407
#     0.33     0.66           0.294065      0.150853     -0.366370           0.0                True              False 2150.503902
#     0.33     1.00           0.294065      0.150853     -0.366370           0.0                True              False 2178.053738
# barren collapses: 16/16

# %%
# plots (heatmap)
pivot_f1 = sensitivity_df.pivot(index="lambda1", columns="lambda2", values="val_macro_f1_best")
pivot_intra = sensitivity_df.pivot(index="lambda1", columns="lambda2", values="l_intra_last")
pivot_inter = sensitivity_df.pivot(index="lambda1", columns="lambda2", values="l_inter_last")

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

for ax, piv, title in [
    (axes[0], pivot_f1, r"best val macro-F1"),
    (axes[1], pivot_intra, r"last $L_{intra}$ (want ↓)"),
    (axes[2], pivot_inter, r"last $L_{inter}$ (want ↓ / more neg.)"),
]:

    sns.heatmap(piv, ax=ax, annot=True, fmt=".3f", cmap="viridis")
    ax.set_xlabel(r"$\lambda_2$")
    ax.set_ylabel(r"$\lambda_1$")
    ax.set_title(title)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Logging

# %%
# write log (final)
log_path = write_history_log(
    {"sensitivity": sensitivity_rows},
    notebook=f"{NOTEBOOK_NAME}.ipynb",
    extra={
        "dataset": dataset,
        "data_path": data_path,
        "split_prefix": split_prefix,
        "seed": seed,
        "epochs": epochs,
        "batch_size": batch_size,
        "lr": lr,
        "n_train": int(len(X_train)),
        "n_val": int(len(X_val)),
        "num_qubits": num_qubits,
        "num_layers": num_layers,
        "noise_rate": noise_rate,
        "barren_plateau_var": barren_plateau_var,
        "lambda1_grid": lambda1_grid,
        "lambda2_grid": lambda2_grid,
        "best_row": sensitivity_df.iloc[0].to_dict(),
        "class_names": list(class_names),
    },
    log_dir="logs",
)
csv_path = Path("logs") / f"{NOTEBOOK_NAME}-sensitivity.csv"
sensitivity_df.to_csv(csv_path, index=False)
print(log_path.resolve())
print(csv_path.resolve())
# Out:
# /home/lawun330/Desktop/quantum-sentinel/logs/tune-lambdas-bot-iot.log
# /home/lawun330/Desktop/quantum-sentinel/logs/tune-lambdas-bot-iot-sensitivity.csv
