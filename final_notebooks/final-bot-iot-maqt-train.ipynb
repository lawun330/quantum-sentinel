# %% [markdown]
# # MAQT Prototypes with FROZEN Features: BoT-IoT
# ## All Samples | ~148,000 Train | Batch Size 64
# ## 50 Epochs (Early Stopping with Patience = 5) | LR Decay (Start at 0.01)
# ## Target (y) = "label_multiclass" | Data Reupload = 2

# %% [markdown]
# ## Setup

# %%
import pennylane as qp
from pennylane import numpy as np
import torch

import matplotlib.pyplot as plt
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import json
from pathlib import Path
import time

# %%
from scripts.constants import (
    DEFAULT_EPOCHS, DEFAULT_LR, DEFAULT_BATCH_SIZE,
    DEFAULT_LAMBDA1, DEFAULT_LAMBDA2, DEFAULT_NOISE_RATE,
    BARREN_PLATEAU_VAR_THRESHOLD, DEFAULT_N_TRIALS, DEFAULT_PATIENCE,
)
from scripts.data import (
    class_balance_table,
    capped_sample,
    stratified_head,
    plot_class_balance_bars,
    plot_class_balance_pie,
    greedy_kcenter_sample,
    greedy_dpp_sample,
    plot_dataset_and_sampling_analysis,
    load_split,
    to_angles,
)
from scripts.circuit import build_forward_circuit, create_quantum_device
from scripts.train import train_maqt
from scripts.utils import get_torch_device, to_np_y
from scripts.logging import write_history_log
from scripts.memory import is_oom_error, run_batched_safely, safe_empty_cache
from scripts.prototypes import prototype_summary
from scripts.gradient import gradient_variance_probe
from scripts.theory import verify_fidelity_convention

# %%
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available?: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA device name: {torch.cuda.get_device_name(0)}")
    print(f"Current CUDA device index: {torch.cuda.current_device()}")
# Out:
# PyTorch version: 2.12.1+cu126
# CUDA available?: True
# CUDA device name: NVIDIA GeForce GTX 1060
# Current CUDA device index: 0

# %% [markdown]
# ## Config

# %%
NOTEBOOK_NAME = "final-bot-iot-maqt-train"

dataset = "BoT-IoT"
target_col = "label_multiclass"
data_path = f"data/FROZEN/{dataset}"
frozen_feat_path = "team-artifacts/teamC_week3_FROZEN_handoff.json"

SEED = 42

# %%
check = verify_fidelity_convention(dim=4, n_trials=30, seed=SEED)
print("Fidelity-convention self-check PASSED:", check)
# Out:
# Fidelity-convention self-check PASSED: {'max_pairwise_disagreement': 0.0, 'max_fvg_violation': 0.0}

# %% [markdown]
# ## Load Team C's FROZEN Features

# %%
handoff = json.loads(Path(frozen_feat_path).read_text())
FEATURE_COLS = list(handoff["frozen_subsets"][dataset]["features"])
print(f"Team C selector: {handoff['frozen_subsets'][dataset]['selector']}")
print(f"k={len(FEATURE_COLS)} features: {FEATURE_COLS}")
# Out:
# Team C selector: QIGPSO
# k=10 features: ['n_pkts_total', 'n_bytes_total', 'src_bytes', 'rate', 'pkt_size_min', 'pkt_size_max', 'pkt_size_mean', 'pkt_size_std', 'protocol', 'conn_state']

# %% [markdown]
# ## Load Team A's FROZEN Dataset

# %%
# load all data
X_train_full, y_train_full, class_names, df_train = load_split(
    data_path, f"train", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_cal_full, y_cal_full, _, df_cal = load_split(
    data_path, f"calibration", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_test_full, y_test_full, _, df_test = load_split(
    data_path, f"test", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_zero_full, y_zero_full, _, df_zero = load_split(
    data_path, f"zeroday", target_col, csv=True, selected_cols=FEATURE_COLS, return_df = True
)

# check shape
print(f"train   : {X_train_full.shape, y_train_full.shape}\n\
cal     : {X_cal_full.shape, y_cal_full.shape}\n\
test    : {X_test_full.shape, y_test_full.shape}\n\
zero    : {X_zero_full.shape, y_zero_full.shape}\n\
classes : {class_names}\n"
)

df_train.head(3)
# Out:
# train   : ((148729, 10), (148729,))
# cal     : ((18591, 10), (18591,))
# test    : ((18591, 10), (18591,))
# zero    : ((683, 10), (683,))
# classes : ['DDoS', 'DoS', 'Normal', 'Reconnaissance']
#    n_pkts_total  n_bytes_total  src_bytes      rate  pkt_size_min  \
# 0     -0.262256      -0.798644  -0.774964 -0.356930      0.000000
# 1      0.427561      -0.121016   0.000000 -0.123704      0.000000
# 2      0.768961       0.200956   0.368220  1.725276      0.761987
#
#    pkt_size_max  pkt_size_mean  pkt_size_std  protocol  conn_state  \
# 0      0.123458      -0.266091      0.827772       0.0         0.0
# 1      0.120431       0.030826      0.766490       0.0         0.0
# 2      0.244690       0.422755      0.618673       0.0         0.0
#
#   label_multiclass
# 0              DoS
# 1              DoS
# 2             DDoS

# %% [markdown]
# ## EDA (Before Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train_full, class_names,
    title=f"train (n={len(to_np_y(y_train_full))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 4

# %% [markdown]
# ## Scaling

# %%
# fit scaler on full train (raw); transform elsewhere via to_angles()
scaler = StandardScaler()
X_train_full_scaled = scaler.fit_transform(X_train_full)
print(f"scaled full train: {X_train_full_scaled.shape}")
# Out:
# scaled full train: (148729, 10)

# %% [markdown]
# ## PCA (Optional)

# %%
USE_PCA = True   # set to False to skip PCA
TARGET_VARIANCE = 0.95

# %%
if USE_PCA:
    pca_full = PCA(random_state=SEED).fit(X_train_full_scaled)
    ratios = pca_full.explained_variance_ratio_
    cum = np.cumsum(ratios)
    n_feat = len(ratios)

    print(f"features (raw dim): {n_feat}")
    print("explained_variance_ratio_:", np.round(ratios, 4))
    print("cumulative:               ", np.round(cum, 4))
    for k in range(1, n_feat + 1):
        print(f"first {k} PCs keep {cum[k - 1]*100:.2f}% variance")

    # smallest k with >= target variance
    k95 = int(np.searchsorted(cum, TARGET_VARIANCE) + 1)
    k95 = min(k95, len(cum))  # safety
    print(f"components needed for >={TARGET_VARIANCE*100}% variance: {k95}")

    fig, ax = plt.subplots(1, 1, figsize=(8, 5))
    ax.bar(range(1, n_feat + 1), ratios, color="slateblue", alpha=0.7, label="per-PC")
    ax.plot(range(1, n_feat + 1), cum, marker="o", color="darkblue", label="cumulative")
    ax.axhline(TARGET_VARIANCE, color="red", linestyle="--", label=f"Target({TARGET_VARIANCE*100}%)")
    ax.axvline(k95, color="green", linestyle=":", label=f"k={k95}")
    ax.set_xlabel("PCA component")
    ax.set_ylabel("explained variance ratio")
    ax.set_title("PCA explained feature variance")
    ax.legend()
    plt.tight_layout()
    plt.show()

    pca = PCA(n_components=k95, random_state=SEED)
    X_train_full_feat = pca.fit_transform(X_train_full_scaled)
else:
    pca = None
    k95 = X_train_full_scaled.shape[1]
    X_train_full_feat = X_train_full_scaled

# angle bounds from full train feature space (pca or scaled)
x_min, x_max = X_train_full_feat.min(0), X_train_full_feat.max(0)
print(f"feature dim for angles: {X_train_full_feat.shape[1]} | USE_PCA={USE_PCA}")
# Out:
# features (raw dim): 10
# explained_variance_ratio_: [0.3698 0.2823 0.1538 0.0927 0.0827 0.0085 0.0052 0.0034 0.0008 0.0007]
# cumulative:                [0.3698 0.6521 0.8059 0.8986 0.9813 0.9898 0.995  0.9985 0.9993 1.    ]
# first 1 PCs keep 36.98% variance
# first 2 PCs keep 65.21% variance
# first 3 PCs keep 80.59% variance
# first 4 PCs keep 89.86% variance
# first 5 PCs keep 98.13% variance
# first 6 PCs keep 98.98% variance
# first 7 PCs keep 99.50% variance
# first 8 PCs keep 99.85% variance
# first 9 PCs keep 99.93% variance
# first 10 PCs keep 100.00% variance
# components needed for >=95.0% variance: 5
# feature dim for angles: 5 | USE_PCA=True

# %% [markdown]
# ## Data Subset (Optional)

# %%
SUBSET = False   # set to False for the full dataset
PER_CLASS_CAP = 30000

# %%
# compare sampling strategies on RAW full train, then apply DPP coreset
if SUBSET:
    plot_dataset_and_sampling_analysis(
        X_train_full,
        y_train_full,
        per_class_cap=PER_CLASS_CAP,
        class_names=class_names,
        seed=SEED,
    )

    print(f"\nRunning representative DPP coreset sampling (cap={PER_CLASS_CAP})...")
    X_train, y_train = greedy_dpp_sample(
        X_train_full, y_train_full, per_class_cap=PER_CLASS_CAP, seed=SEED
    )
    print(f"Coreset selected: {X_train.shape[0]} samples.")
else:
    X_train, y_train = X_train_full, y_train_full
    print(f"using full train (no subset): {X_train.shape[0]} samples")

print(f"train raw: {X_train.shape, y_train.shape} | SUBSET={SUBSET} | cap={PER_CLASS_CAP if SUBSET else 'all'}")
# Out:
# using full train (no subset): 148729 samples
# train raw: ((148729, 10), (148729,)) | SUBSET=False | cap=all

# %% [markdown]
# ## EDA (After Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train, class_names,
    title=f"train (n={len(to_np_y(y_train))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 4

# %% [markdown]
# ## Mapping Features $\rightarrow$ [0, $\pi$]

# %%
# raw -> scale -> optional pca -> [0, pi] using bounds from full train
X_train_angles_all = to_angles(
    X_train, scaler, x_min, x_max, pca=pca if USE_PCA else None, angle_max=np.pi
)

# seeded stratified holdout from train for early stopping (cal/test untouched)
VAL_FRAC = 0.1
_y_all = y_train
idx = np.arange(len(X_train_angles_all))
idx_fit, idx_val = train_test_split(
    idx, test_size=VAL_FRAC, stratify=_y_all, random_state=SEED,
)
X_train_angles, y_train = X_train_angles_all[idx_fit], _y_all[idx_fit]
X_val_angles, y_val = X_train_angles_all[idx_val], _y_all[idx_val]
print(
    f"angles fit: {X_train_angles.shape} | val: {X_val_angles.shape} | "
    f"VAL_FRAC={VAL_FRAC} | USE_PCA={USE_PCA} | SUBSET={SUBSET}"
)

fig, ax1 = plt.subplots(1, 1, figsize=(7, 4))
ax1.hist(X_train_angles.flatten(), bins=50, color="teal", alpha=0.8)
ax1.set_xlabel("angle (radians)")
ax1.set_title("Angle-encoded train (fit) feature distribution")
plt.tight_layout()
plt.show()
# Out:
# angles fit: (133856, 5) | val: (14873, 5) | VAL_FRAC=0.1 | USE_PCA=True | SUBSET=False

# %% [markdown]
# ## Quantum Circuit: Angle Encoding, Data Reuploading, and Adding Noise
#
# $$
# x\xrightarrow[\text{encode}]{\phi(x)}\ket{\psi(x)}\xrightarrow[\text{variational}]{U(\theta)}\ket{\Phi(x)}\xrightarrow{\Lambda_p}\rho(x)
# $$
# - $x$: classical data
# - $\phi(x)$: `qp.AngleEmbedding()`
# - $\ket{\psi(x)}$: quantum state after encoding
# - $U(\theta)$: `qp.StronglyEntanglingLayers()`
# - $\ket{\Phi(x)}$: quantum state after variational transform
# - $\rho(x)=\Lambda_p(\ket{\Phi(x)}\bra{\Phi(x)})$: standard depolarization channel to model NISQ noise

# %%
num_qubits = int(k95)           # pca comps if USE_PCA; else scaled feature dim
num_layers = 2                  # reupload same classical data
noise_rate = DEFAULT_NOISE_RATE
print(f"num_qubits={num_qubits} (USE_PCA={USE_PCA})")
# Out:
# num_qubits=5 (USE_PCA=True)

# %%
# initialize devices
device = get_torch_device()
dev = create_quantum_device(num_qubits) # or dev = qp.device("default.mixed", wires=num_qubits)

# define circuit
forward_circuit = build_forward_circuit(dev, num_qubits, num_layers, noise_rate=noise_rate)

# %% [markdown]
# ## Gradient Variance Probe

# %%
barren_plateau_var = BARREN_PLATEAU_VAR_THRESHOLD
n_trials = 5

safe_empty_cache()

# probe on CPU (recommended)
x_probe = X_train_angles[:1]

try:
    grad_var, grad_samples = gradient_variance_probe(
        forward_circuit, x_probe, num_qubits, num_layers,
        n_trials=n_trials,
        device=torch.device("cpu"),
    )

    print(f"pre-train grad var = {grad_var:.2e} (thr={barren_plateau_var:.0e})")
    if grad_var < barren_plateau_var:
        print("warning: possible barren plateau architecture")

    plt.figure(figsize=(6, 4)); plt.hist(grad_samples, bins=15, color="darkcyan", alpha=0.8)
    plt.title(f"Gradient-variance probe (var={grad_var:.2e})"); plt.tight_layout(); plt.show()

except RuntimeError as e:
    if is_oom_error(e):
        print("\t[OOM] barren-plateau probe skipped (non-critical diagnostic).")
        safe_empty_cache()
    else:
        raise
# Out:
# pre-train grad var = 3.16e-09 (thr=1e-06)
# warning: possible barren plateau architecture

# %% [markdown]
# ## Training
#
# $$
# L = L_{CE} + \lambda_1*L_{intra} + \lambda_2*L_{inter}
# $$
#
# Minimizing:
# - $L_{CE}$ adjusts $\theta$ for better class predictions.
# - $L_{intra}$ pulls each sample toward its class prototype
# - $L_{inter}$ pushs different-class prototypes apart (maximize trace distance)

# %%
epochs = 50
batch_size = 64
lr = 0.01
lambda1 = 0.5
lambda2 = 0.1
early_stopping = True
patience = 5
min_delta = 0.001

out_dir = Path("final_notebooks") / "final_artifacts"  # final BoT-IoT artifacts (flat)
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_dir = out_dir / f"{NOTEBOOK_NAME}_seed{SEED}"
latest_ckpt = ckpt_dir / "maqt-latest.pt"
resume_from = latest_ckpt if latest_ckpt.exists() else None

print(f"checkpoint_dir: {ckpt_dir}")
print(f"resume_from: {resume_from}")
# Out:
# checkpoint_dir: final_notebooks/final_artifacts/final-bot-iot-maqt_seed42
# resume_from: None

# %%
torch.manual_seed(SEED)

result = run_batched_safely(
    train_maqt,
    X_train_angles,
    y_train,
    n_classes=num_classes,
    n_qubits=num_qubits,
    n_layers=num_layers,
    forward_circuit=forward_circuit,
    device=device,
    epochs=epochs,
    lr=lr,
    use_lr_schedule=True,  # auto LR
    batch_size=batch_size,
    min_batch=2,
    label="train_maqt",
    lambda1_max=lambda1,
    lambda2_max=lambda2,
    use_weighted_sampler=True,
    seed=SEED,
    early_stopping=early_stopping,
    patience=patience,
    min_delta=min_delta,
    X_val=X_val_angles,
    y_val=y_val,
    checkpoint_dir=ckpt_dir,
    save_every_epoch=True,
    resume_from=resume_from,
    reset_early_stopping_on_resume=True,
    heartbeat_every_steps=20,  # pass None to less verbose
    notebook_name=NOTEBOOK_NAME,
    log_dir=ckpt_dir,
)

if result is None:
    raise RuntimeError("train_maqt failed even at min_batch (OOM)")

theta, head, prototypes, ema_protos, history = result
theta_star = theta
classifier_head = head
safe_empty_cache()
print(
    "\n"
    f"epochs_ran={history.get('epochs_ran')} | "
    f"best_epoch={history.get('best_epoch')} | "
    f"stopped_early={history.get('stopped_early')} | "
    f"stop_reason={history.get('stop_reason')}"
)
# Out:
# 	epoch 1 step 20 (1%) loss=1.2896 elapsed=12s eta=1235s
# 	epoch 1 step 40 (2%) loss=1.1926 elapsed=37s eta=1917s
# 	epoch 1 step 60 (3%) loss=1.1074 elapsed=66s eta=2235s
# 	epoch 1 step 80 (4%) loss=1.0133 elapsed=94s eta=2375s
# 	epoch 1 step 100 (5%) loss=0.8854 elapsed=124s eta=2462s
# 	epoch 1 step 120 (6%) loss=0.8299 elapsed=152s eta=2502s
# 	epoch 1 step 140 (7%) loss=0.8720 elapsed=181s eta=2521s
# 	epoch 1 step 160 (8%) loss=0.8574 elapsed=210s eta=2529s
# 	epoch 1 step 180 (9%) loss=0.7222 elapsed=238s eta=2529s
# 	epoch 1 step 200 (10%) loss=0.7882 elapsed=267s eta=2521s
# 	epoch 2 step 1900 (91%) loss=0.5644 elapsed=1146s eta=116s
# 	epoch 2 step 1920 (92%) loss=0.4278 elapsed=1175s eta=105s
# 	epoch 2 step 1940 (93%) loss=0.5101 elapsed=1204s eta=94s
# 	epoch 2 step 1960 (94%) loss=0.5468 elapsed=1233s eta=83s
# 	epoch 2 step 1980 (95%) loss=0.6212 elapsed=1261s eta=71s
# 	epoch 2 step 2000 (96%) loss=0.4337 elapsed=1291s eta=59s
# 	epoch 2 step 2020 (97%) loss=0.5012 elapsed=1320s eta=47s
# 	epoch 2 step 2040 (98%) loss=0.5868 elapsed=1349s eta=34s
# 	epoch 2 step 2060 (98%) loss=0.5614 elapsed=1378s eta=21s
# 	epoch 2 step 2080 (99%) loss=0.3706 elapsed=1407s eta=8s
# epoch  2/50 | time 1420.5s | loss 0.5061 | L_CE 0.5021 | L_intra 0.1823 | L_inter -0.5068 | grad_var 6.71e-03 | intra_fid 0.818 | inter_TD 0.503 | val_loss 0.7425 | lr 9.99e-03 | peak_mem=50MB | best=0.7425@ep2 | bad=0/5
#   saved checkpoint: final_notebooks/final_artifacts/final-bot-iot-maqt_seed42/maqt-epoch002.pt
# 	epoch 3 step 20 (1%) loss=0.4553 elapsed=11s eta=1168s
# 	epoch 3 step 40 (2%) loss=0.4730 elapsed=23s eta=1157s
# 	epoch 3 step 60 (3%) loss=0.6224 elapsed=34s eta=1143s
# 	epoch 3 step 80 (4%) loss=0.4210 elapsed=45s eta=1130s
# 	epoch 3 step 100 (5%) loss=0.4799 elapsed=56s eta=1118s
# 	epoch 3 step 120 (6%) loss=0.5307 elapsed=67s eta=1108s
# 	epoch 3 step 140 (7%) loss=0.4674 elapsed=79s eta=1098s
# 	epoch 3 step 160 (8%) loss=0.3730 elapsed=90s eta=1088s
# 	epoch 3 step 180 (9%) loss=0.5367 elapsed=101s eta=1077s
# 	epoch 3 step 200 (10%) loss=0.4580 elapsed=113s eta=1066s
# 	epoch 3 step 220 (11%) loss=0.5989 elapsed=124s eta=1056s
# 	epoch 3 step 240 (11%) loss=0.3654 elapsed=135s eta=1045s
# 	epoch 3 step 260 (12%) loss=0.6369 elapsed=147s eta=1034s
# 	epoch 3 step 280 (13%) loss=0.4942 elapsed=158s eta=1022s
# 	epoch 3 step 300 (14%) loss=0.3879 elapsed=169s eta=1011s
# 	epoch 3 step 320 (15%) loss=0.5166 elapsed=181s eta=1000s
# 	epoch 3 step 340 (16%) loss=0.5395 elapsed=192s eta=989s
# 	epoch 3 step 360 (17%) loss=0.6159 elapsed=203s eta=978s
# 	epoch 3 step 380 (18%) loss=0.5037 elapsed=215s eta=967s
# 	epoch 3 step 400 (19%) loss=0.4907 elapsed=226s eta=955s
# 	epoch 3 step 420 (20%) loss=0.6912 elapsed=237s eta=944s
# 	epoch 3 step 440 (21%) loss=0.4175 elapsed=249s eta=933s
# 	epoch 3 step 460 (22%) loss=0.4782 elapsed=260s eta=921s
# 	epoch 3 step 480 (23%) loss=0.4093 elapsed=271s eta=910s
# 	epoch 3 step 500 (24%) loss=0.5293 elapsed=282s eta=899s
# 	epoch 3 step 520 (25%) loss=0.4531 elapsed=294s eta=888s
# 	epoch 3 step 540 (26%) loss=0.5232 elapsed=305s eta=877s
# 	epoch 3 step 560 (27%) loss=0.4209 elapsed=316s eta=865s
# 	epoch 3 step 580 (28%) loss=0.2989 elapsed=328s eta=854s
# 	epoch 3 step 600 (29%) loss=0.4348 elapsed=339s eta=843s
# 	epoch 3 step 620 (30%) loss=0.5980 elapsed=350s eta=832s
# 	epoch 3 step 640 (31%) loss=0.4175 elapsed=362s eta=821s
# 	epoch 3 step 660 (32%) loss=0.4229 elapsed=373s eta=809s
# 	epoch 3 step 680 (33%) loss=0.5721 elapsed=384s eta=798s
# 	epoch 3 step 700 (33%) loss=0.5104 elapsed=396s eta=787s
# 	epoch 3 step 720 (34%) loss=0.4665 elapsed=407s eta=775s
# 	epoch 3 step 740 (35%) loss=0.5653 elapsed=418s eta=764s
# 	epoch 3 step 760 (36%) loss=0.4606 elapsed=430s eta=753s
# 	epoch 3 step 780 (37%) loss=0.4367 elapsed=441s eta=741s
# 	epoch 3 step 800 (38%) loss=0.4875 elapsed=452s eta=730s
# 	epoch 3 step 820 (39%) loss=0.6995 elapsed=464s eta=719s
# 	epoch 3 step 840 (40%) loss=0.4378 elapsed=475s eta=708s
# 	epoch 3 step 860 (41%) loss=0.5282 elapsed=486s eta=697s
# 	epoch 3 step 880 (42%) loss=0.5081 elapsed=498s eta=685s
# 	epoch 3 step 900 (43%) loss=0.6236 elapsed=509s eta=674s
# 	epoch 3 step 920 (44%) loss=0.5138 elapsed=520s eta=663s
# 	epoch 3 step 940 (45%) loss=0.5243 elapsed=532s eta=651s
# 	epoch 3 step 960 (46%) loss=0.5539 elapsed=543s eta=640s
# 	epoch 3 step 980 (47%) loss=0.4235 elapsed=554s eta=629s
# 	epoch 3 step 1000 (48%) loss=0.5159 elapsed=566s eta=618s
# 	epoch 3 step 1020 (49%) loss=0.4693 elapsed=577s eta=606s
# 	epoch 3 step 1040 (50%) loss=0.4204 elapsed=589s eta=595s
# 	epoch 3 step 1060 (51%) loss=0.4614 elapsed=600s eta=584s
# 	epoch 3 step 1080 (52%) loss=0.4734 elapsed=612s eta=573s
# 	epoch 3 step 1100 (53%) loss=0.3207 elapsed=623s eta=561s
# 	epoch 3 step 1120 (54%) loss=0.4861 elapsed=634s eta=550s
# 	epoch 3 step 1140 (55%) loss=0.6272 elapsed=646s eta=539s
# 	epoch 3 step 1160 (55%) loss=0.5974 elapsed=657s eta=528s
# 	epoch 3 step 1180 (56%) loss=0.5092 elapsed=668s eta=516s
# 	epoch 3 step 1200 (57%) loss=0.6729 elapsed=680s eta=505s
# 	epoch 3 step 1220 (58%) loss=0.3727 elapsed=691s eta=494s
# 	epoch 3 step 1240 (59%) loss=0.6075 elapsed=703s eta=482s
# 	epoch 3 step 1260 (60%) loss=0.4355 elapsed=714s eta=471s
# 	epoch 3 step 1280 (61%) loss=0.5806 elapsed=725s eta=460s
# 	epoch 3 step 1300 (62%) loss=0.5199 elapsed=737s eta=449s
# 	epoch 3 step 1320 (63%) loss=0.3969 elapsed=748s eta=437s
# 	epoch 3 step 1340 (64%) loss=0.3250 elapsed=760s eta=426s
# 	epoch 3 step 1360 (65%) loss=0.5423 elapsed=771s eta=415s
# 	epoch 3 step 1380 (66%) loss=0.6071 elapsed=782s eta=403s
# 	epoch 3 step 1400 (67%) loss=0.6460 elapsed=794s eta=392s
# 	epoch 3 step 1420 (68%) loss=0.4652 elapsed=805s eta=381s
# 	epoch 3 step 1440 (69%) loss=0.4145 elapsed=817s eta=369s
# 	epoch 3 step 1460 (70%) loss=0.5374 elapsed=828s eta=358s
# 	epoch 3 step 1480 (71%) loss=0.3467 elapsed=839s eta=347s
# 	epoch 3 step 1500 (72%) loss=0.4295 elapsed=851s eta=335s
# 	epoch 3 step 1520 (73%) loss=0.5055 elapsed=862s eta=324s
# 	epoch 3 step 1540 (74%) loss=0.6113 elapsed=874s eta=313s
# 	epoch 3 step 1560 (75%) loss=0.4312 elapsed=885s eta=301s
# 	epoch 3 step 1580 (76%) loss=0.5875 elapsed=896s eta=290s
# 	epoch 3 step 1600 (77%) loss=0.4019 elapsed=908s eta=279s
# 	epoch 3 step 1620 (77%) loss=0.3803 elapsed=920s eta=268s
# 	epoch 3 step 1640 (78%) loss=0.5146 elapsed=931s eta=256s
# 	epoch 3 step 1660 (79%) loss=0.4237 elapsed=942s eta=245s
# 	epoch 3 step 1680 (80%) loss=0.3999 elapsed=954s eta=234s
# 	epoch 3 step 1700 (81%) loss=0.3805 elapsed=965s eta=222s
# 	epoch 3 step 1720 (82%) loss=0.4744 elapsed=976s eta=211s
# 	epoch 3 step 1740 (83%) loss=0.4428 elapsed=987s eta=199s
# 	epoch 3 step 1760 (84%) loss=0.3770 elapsed=999s eta=188s
# 	epoch 3 step 1780 (85%) loss=0.6668 elapsed=1010s eta=177s
# 	epoch 3 step 1800 (86%) loss=0.5178 elapsed=1021s eta=165s
# 	epoch 3 step 1820 (87%) loss=0.5034 elapsed=1033s eta=154s
# 	epoch 3 step 1840 (88%) loss=0.6212 elapsed=1044s eta=143s
# 	epoch 3 step 1860 (89%) loss=0.4894 elapsed=1055s eta=131s
# 	epoch 3 step 1880 (90%) loss=0.4402 elapsed=1067s eta=120s
# 	epoch 3 step 1900 (91%) loss=0.3500 elapsed=1078s eta=109s
# 	epoch 3 step 1920 (92%) loss=0.4698 elapsed=1090s eta=97s
# 	epoch 3 step 1940 (93%) loss=0.5623 elapsed=1101s eta=86s
# 	epoch 3 step 1960 (94%) loss=0.4852 elapsed=1112s eta=75s
# 	epoch 3 step 1980 (95%) loss=0.5091 elapsed=1123s eta=63s
# 	epoch 3 step 2000 (96%) loss=0.3804 elapsed=1135s eta=52s
# 	epoch 3 step 2020 (97%) loss=0.5590 elapsed=1146s eta=41s
# 	epoch 3 step 2040 (98%) loss=0.3993 elapsed=1158s eta=29s
# 	epoch 6 step 980 (47%) loss=0.3955 elapsed=563s eta=638s
# 	epoch 6 step 1000 (48%) loss=0.5995 elapsed=574s eta=626s
# 	epoch 6 step 1020 (49%) loss=0.3335 elapsed=586s eta=615s
# 	epoch 6 step 1040 (50%) loss=0.4369 elapsed=597s eta=604s
# 	epoch 6 step 1060 (51%) loss=0.4012 elapsed=609s eta=593s
# 	epoch 6 step 1080 (52%) loss=0.5951 elapsed=621s eta=582s
# 	epoch 6 step 1100 (53%) loss=0.4422 elapsed=633s eta=570s
# 	epoch 6 step 1120 (54%) loss=0.6094 elapsed=644s eta=559s
# 	epoch 6 step 1140 (55%) loss=0.4612 elapsed=655s eta=547s
# 	epoch 6 step 1160 (55%) loss=0.3790 elapsed=667s eta=535s
# 	epoch 6 step 1180 (56%) loss=0.4825 elapsed=678s eta=524s
# 	epoch 6 step 1200 (57%) loss=0.5531 elapsed=690s eta=513s
# 	epoch 6 step 1220 (58%) loss=0.4527 elapsed=702s eta=501s
# 	epoch 6 step 1240 (59%) loss=0.3571 elapsed=713s eta=490s
# 	epoch 6 step 1260 (60%) loss=0.5850 elapsed=725s eta=478s
# 	epoch 6 step 1280 (61%) loss=0.5199 elapsed=736s eta=467s
# 	epoch 6 step 1300 (62%) loss=0.4361 elapsed=748s eta=455s
# 	epoch 6 step 1320 (63%) loss=0.3390 elapsed=759s eta=444s
# 	epoch 6 step 1340 (64%) loss=0.3953 elapsed=771s eta=432s
# 	epoch 6 step 1360 (65%) loss=0.4166 elapsed=782s eta=421s
# 	epoch 6 step 1380 (66%) loss=0.3773 elapsed=794s eta=409s
# 	epoch 6 step 1400 (67%) loss=0.4780 elapsed=805s eta=398s
# 	epoch 6 step 1420 (68%) loss=0.4966 elapsed=817s eta=386s
# 	epoch 6 step 1440 (69%) loss=0.4720 elapsed=828s eta=375s
# 	epoch 6 step 1460 (70%) loss=0.4342 elapsed=840s eta=363s
# 	epoch 6 step 1480 (71%) loss=0.4669 elapsed=851s eta=352s
# 	epoch 6 step 1500 (72%) loss=0.3716 elapsed=863s eta=340s
# 	epoch 6 step 1520 (73%) loss=0.4807 elapsed=874s eta=329s
# 	epoch 6 step 1540 (74%) loss=0.4719 elapsed=885s eta=317s
# 	epoch 6 step 1560 (75%) loss=0.4110 elapsed=897s eta=306s
# 	epoch 6 step 1580 (76%) loss=0.3845 elapsed=908s eta=294s
# 	epoch 6 step 1600 (77%) loss=0.4329 elapsed=920s eta=283s
# 	epoch 6 step 1620 (77%) loss=0.4348 elapsed=931s eta=271s
# 	epoch 6 step 1640 (78%) loss=0.3996 elapsed=943s eta=260s
# 	epoch 6 step 1660 (79%) loss=0.5117 elapsed=954s eta=248s
# 	epoch 6 step 1680 (80%) loss=0.4378 elapsed=966s eta=237s
# 	epoch 6 step 1700 (81%) loss=0.4504 elapsed=977s eta=225s
# 	epoch 6 step 1720 (82%) loss=0.3305 elapsed=989s eta=214s
# 	epoch 6 step 1740 (83%) loss=0.5133 elapsed=1000s eta=202s
# 	epoch 6 step 1760 (84%) loss=0.5497 elapsed=1011s eta=191s
# 	epoch 6 step 1780 (85%) loss=0.4468 elapsed=1023s eta=179s
# 	epoch 6 step 1800 (86%) loss=0.4859 elapsed=1034s eta=168s
# 	epoch 6 step 1820 (87%) loss=0.6461 elapsed=1046s eta=156s
# 	epoch 6 step 1840 (88%) loss=0.5084 elapsed=1058s eta=145s
# 	epoch 6 step 1860 (89%) loss=0.4082 elapsed=1069s eta=133s
# 	epoch 6 step 1880 (90%) loss=0.4972 elapsed=1081s eta=122s
# 	epoch 6 step 1900 (91%) loss=0.3445 elapsed=1092s eta=110s
# 	epoch 6 step 1920 (92%) loss=0.4995 elapsed=1104s eta=99s
# 	epoch 6 step 1940 (93%) loss=0.3931 elapsed=1116s eta=87s
# 	epoch 6 step 1960 (94%) loss=0.4803 elapsed=1127s eta=76s
# 	epoch 6 step 1980 (95%) loss=0.4354 elapsed=1139s eta=64s
# 	epoch 6 step 2000 (96%) loss=0.4172 elapsed=1150s eta=53s
# 	epoch 6 step 2020 (97%) loss=0.4900 elapsed=1162s eta=41s
# 	epoch 6 step 2040 (98%) loss=0.3822 elapsed=1174s eta=30s
# 	epoch 6 step 2060 (98%) loss=0.4467 elapsed=1185s eta=18s
# 	epoch 6 step 2080 (99%) loss=0.5512 elapsed=1197s eta=7s
# epoch  6/50 | time 1203.8s | loss 0.4627 | L_CE 0.4429 | L_intra 0.1806 | L_inter -0.5077 | grad_var 1.63e-02 | intra_fid 0.819 | inter_TD 0.520 | val_loss 0.6865 | lr 9.76e-03 | peak_mem=50MB | best=0.6837@ep4 | bad=2/5
#   saved checkpoint: final_notebooks/final_artifacts/final-bot-iot-maqt_seed42/maqt-epoch006.pt
# 	epoch 7 step 20 (1%) loss=0.4131 elapsed=12s eta=1212s
# 	epoch 7 step 40 (2%) loss=0.4541 elapsed=23s eta=1186s
# 	epoch 7 step 60 (3%) loss=0.4114 elapsed=35s eta=1172s
# 	epoch 7 step 80 (4%) loss=0.5175 elapsed=46s eta=1162s
# 	epoch 7 step 100 (5%) loss=0.3471 elapsed=58s eta=1151s
# 	epoch 7 step 120 (6%) loss=0.4663 elapsed=69s eta=1137s
# 	epoch 7 step 140 (7%) loss=0.4200 elapsed=81s eta=1127s
# 	epoch 7 step 160 (8%) loss=0.4328 elapsed=92s eta=1116s
# 	epoch 7 step 180 (9%) loss=0.4004 elapsed=104s eta=1105s
# 	epoch 7 step 200 (10%) loss=0.4158 elapsed=116s eta=1094s
# 	epoch 7 step 220 (11%) loss=0.5490 elapsed=127s eta=1083s
# 	epoch 7 step 240 (11%) loss=0.6270 elapsed=139s eta=1072s
# 	epoch 7 step 260 (12%) loss=0.4005 elapsed=151s eta=1060s
# 	epoch 7 step 280 (13%) loss=0.4462 elapsed=162s eta=1048s
# 	epoch 7 step 300 (14%) loss=0.6471 elapsed=173s eta=1035s
# 	epoch 7 step 320 (15%) loss=0.5393 elapsed=185s eta=1023s
# 	epoch 7 step 1900 (91%) loss=0.5178 elapsed=1094s eta=110s
# 	epoch 7 step 1920 (92%) loss=0.4782 elapsed=1105s eta=99s
# 	epoch 7 step 1940 (93%) loss=0.5323 elapsed=1117s eta=87s
# 	epoch 7 step 1960 (94%) loss=0.4014 elapsed=1128s eta=76s
# 	epoch 7 step 1980 (95%) loss=0.4508 elapsed=1140s eta=64s
# 	epoch 7 step 2000 (96%) loss=0.4794 elapsed=1152s eta=53s
# 	epoch 7 step 2020 (97%) loss=0.4239 elapsed=1163s eta=41s
# 	epoch 7 step 2040 (98%) loss=0.4340 elapsed=1175s eta=30s
# 	epoch 7 step 2060 (98%) loss=0.5528 elapsed=1186s eta=18s
# 	epoch 7 step 2080 (99%) loss=0.4380 elapsed=1198s eta=7s
# epoch  7/50 | time 1204.6s | loss 0.4627 | L_CE 0.4388 | L_intra 0.1813 | L_inter -0.5079 | grad_var 1.76e-02 | intra_fid 0.819 | inter_TD 0.512 | val_loss 0.7137 | lr 9.65e-03 | peak_mem=50MB | best=0.6837@ep4 | bad=3/5
#   saved checkpoint: final_notebooks/final_artifacts/final-bot-iot-maqt_seed42/maqt-epoch007.pt
# 	epoch 8 step 20 (1%) loss=0.4426 elapsed=11s eta=1191s
# 	epoch 8 step 40 (2%) loss=0.3341 elapsed=23s eta=1174s
# 	epoch 8 step 60 (3%) loss=0.4666 elapsed=34s eta=1162s
# 	epoch 8 step 80 (4%) loss=0.4387 elapsed=46s eta=1153s
# 	epoch 8 step 100 (5%) loss=0.4367 elapsed=57s eta=1144s
# 	epoch 8 step 120 (6%) loss=0.5041 elapsed=69s eta=1136s
# 	epoch 8 step 140 (7%) loss=0.5787 elapsed=81s eta=1123s
# 	epoch 8 step 160 (8%) loss=0.5560 elapsed=92s eta=1111s
# 	epoch 8 step 180 (9%) loss=0.6647 elapsed=103s eta=1099s
# 	epoch 8 step 200 (10%) loss=0.4856 elapsed=115s eta=1087s
# 	epoch 8 step 220 (11%) loss=0.5597 elapsed=127s eta=1076s
# 	epoch 8 step 240 (11%) loss=0.5119 elapsed=138s eta=1064s
# 	epoch 8 step 260 (12%) loss=0.4322 elapsed=149s eta=1053s
# 	epoch 8 step 280 (13%) loss=0.4599 elapsed=161s eta=1042s
# 	epoch 8 step 300 (14%) loss=0.5697 elapsed=173s eta=1031s
# 	epoch 8 step 320 (15%) loss=0.4339 elapsed=184s eta=1020s
# 	epoch 8 step 340 (16%) loss=0.2996 elapsed=196s eta=1009s
# 	epoch 8 step 360 (17%) loss=0.4667 elapsed=207s eta=997s
# 	epoch 8 step 380 (18%) loss=0.4569 elapsed=219s eta=985s
# 	epoch 8 step 400 (19%) loss=0.4439 elapsed=230s eta=974s
# 	epoch 8 step 420 (20%) loss=0.5075 elapsed=242s eta=963s
# 	epoch 8 step 440 (21%) loss=0.4667 elapsed=253s eta=951s
# 	epoch 8 step 460 (22%) loss=0.5448 elapsed=265s eta=939s
# 	epoch 8 step 480 (23%) loss=0.3530 elapsed=276s eta=927s
# 	epoch 22 step 1520 (73%) loss=0.4694 elapsed=865s eta=325s
# 	epoch 22 step 1540 (74%) loss=0.2910 elapsed=876s eta=314s
# 	epoch 22 step 1560 (75%) loss=0.4128 elapsed=888s eta=302s
# 	epoch 22 step 1580 (76%) loss=0.3934 elapsed=899s eta=291s
# 	epoch 22 step 1600 (77%) loss=0.4042 elapsed=910s eta=280s
# 	epoch 22 step 1620 (77%) loss=0.5349 elapsed=922s eta=268s
# 	epoch 22 step 1640 (78%) loss=0.5461 elapsed=933s eta=257s
# 	epoch 22 step 1660 (79%) loss=0.3791 elapsed=944s eta=245s
# 	epoch 22 step 1680 (80%) loss=0.5770 elapsed=956s eta=234s
# 	epoch 22 step 1700 (81%) loss=0.7121 elapsed=967s eta=223s
# 	epoch 22 step 1720 (82%) loss=0.3588 elapsed=979s eta=211s
# 	epoch 22 step 1740 (83%) loss=0.4468 elapsed=990s eta=200s
# 	epoch 22 step 1760 (84%) loss=0.5649 elapsed=1001s eta=189s
# 	epoch 22 step 1780 (85%) loss=0.3491 elapsed=1013s eta=177s
# 	epoch 22 step 1800 (86%) loss=0.4271 elapsed=1024s eta=166s
# 	epoch 22 step 1820 (87%) loss=0.4324 elapsed=1035s eta=154s
# 	epoch 22 step 1840 (88%) loss=0.4656 elapsed=1047s eta=143s
# 	epoch 22 step 1860 (89%) loss=0.5432 elapsed=1058s eta=132s
# 	epoch 22 step 1880 (90%) loss=0.5021 elapsed=1069s eta=120s
# 	epoch 22 step 1900 (91%) loss=0.3936 elapsed=1081s eta=109s
# 	epoch 22 step 1920 (92%) loss=0.5260 elapsed=1092s eta=98s
# 	epoch 22 step 1940 (93%) loss=0.4634 elapsed=1103s eta=86s
# 	epoch 22 step 1960 (94%) loss=0.4456 elapsed=1115s eta=75s
# 	epoch 22 step 1980 (95%) loss=0.4220 elapsed=1126s eta=63s
# 	epoch 22 step 2000 (96%) loss=0.4562 elapsed=1138s eta=52s
# 	epoch 22 step 2020 (97%) loss=0.6556 elapsed=1149s eta=41s
# 	epoch 22 step 2040 (98%) loss=0.4233 elapsed=1160s eta=29s
# 	epoch 22 step 2060 (98%) loss=0.6904 elapsed=1172s eta=18s
# 	epoch 22 step 2080 (99%) loss=0.5999 elapsed=1183s eta=7s
# epoch 22/50 | time 1189.5s | loss 0.4584 | L_CE 0.4191 | L_intra 0.1810 | L_inter -0.5118 | grad_var 2.36e-02 | intra_fid 0.819 | inter_TD 0.514 | val_loss 0.6857 | lr 6.28e-03 | peak_mem=50MB | best=0.6572@ep19 | bad=3/5
#   saved checkpoint: final_notebooks/final_artifacts/final-bot-iot-maqt_seed42/maqt-epoch022.pt
# 	epoch 23 step 20 (1%) loss=0.6558 elapsed=11s eta=1168s
# 	epoch 23 step 40 (2%) loss=0.5670 elapsed=23s eta=1157s
# 	epoch 23 step 60 (3%) loss=0.3646 elapsed=34s eta=1147s
# 	epoch 23 step 80 (4%) loss=0.4426 elapsed=45s eta=1135s
# 	epoch 23 step 900 (43%) loss=0.3483 elapsed=510s eta=675s
# 	epoch 23 step 920 (44%) loss=0.3947 elapsed=522s eta=664s
# 	epoch 23 step 940 (45%) loss=0.5171 elapsed=533s eta=653s
# 	epoch 23 step 960 (46%) loss=0.4209 elapsed=544s eta=642s
# 	epoch 23 step 980 (47%) loss=0.5137 elapsed=556s eta=630s
# 	epoch 23 step 1000 (48%) loss=0.3199 elapsed=567s eta=619s
# 	epoch 23 step 1020 (49%) loss=0.5403 elapsed=579s eta=608s
# 	epoch 23 step 1040 (50%) loss=0.5138 elapsed=590s eta=596s
# 	epoch 23 step 1060 (51%) loss=0.4071 elapsed=601s eta=585s
# 	epoch 23 step 1080 (52%) loss=0.6701 elapsed=613s eta=574s
# 	epoch 23 step 1100 (53%) loss=0.3430 elapsed=624s eta=562s
# 	epoch 23 step 1120 (54%) loss=0.5754 elapsed=635s eta=551s
# 	epoch 23 step 1140 (55%) loss=0.5491 elapsed=647s eta=540s
# 	epoch 23 step 1160 (55%) loss=0.3955 elapsed=658s eta=528s
# 	epoch 23 step 1180 (56%) loss=0.4555 elapsed=669s eta=517s
# 	epoch 23 step 1200 (57%) loss=0.4144 elapsed=681s eta=506s
# 	epoch 23 step 1220 (58%) loss=0.4652 elapsed=692s eta=495s
# 	epoch 23 step 1240 (59%) loss=0.3761 elapsed=704s eta=483s
# 	epoch 23 step 1260 (60%) loss=0.4271 elapsed=715s eta=472s
# 	epoch 23 step 1280 (61%) loss=0.4708 elapsed=727s eta=461s
# 	epoch 23 step 1300 (62%) loss=0.4246 elapsed=738s eta=449s
# 	epoch 23 step 1320 (63%) loss=0.4711 elapsed=749s eta=438s
# 	epoch 23 step 1340 (64%) loss=0.3594 elapsed=761s eta=427s
# 	epoch 23 step 1360 (65%) loss=0.3097 elapsed=772s eta=415s
# 	epoch 23 step 1380 (66%) loss=0.5104 elapsed=784s eta=404s
# 	epoch 23 step 1400 (67%) loss=0.5165 elapsed=795s eta=393s
# 	epoch 23 step 1420 (68%) loss=0.3976 elapsed=807s eta=382s
# 	epoch 23 step 1440 (69%) loss=0.5447 elapsed=818s eta=370s
# 	epoch 23 step 1460 (70%) loss=0.4561 elapsed=830s eta=359s
# 	epoch 23 step 1480 (71%) loss=0.4928 elapsed=842s eta=348s
# 	epoch 23 step 1500 (72%) loss=0.4077 elapsed=853s eta=336s
# 	epoch 23 step 1520 (73%) loss=0.4868 elapsed=864s eta=325s
# 	epoch 23 step 1540 (74%) loss=0.4814 elapsed=876s eta=314s
# 	epoch 23 step 1560 (75%) loss=0.4526 elapsed=887s eta=302s
# 	epoch 23 step 1580 (76%) loss=0.3281 elapsed=899s eta=291s
# 	epoch 23 step 1600 (77%) loss=0.4746 elapsed=910s eta=280s
# 	epoch 23 step 1620 (77%) loss=0.3175 elapsed=921s eta=268s
# 	epoch 23 step 1640 (78%) loss=0.6847 elapsed=933s eta=257s
# 	epoch 23 step 1660 (79%) loss=0.4508 elapsed=944s eta=245s
# 	epoch 23 step 1680 (80%) loss=0.4014 elapsed=956s eta=234s
# 	epoch 23 step 1700 (81%) loss=0.5085 elapsed=967s eta=223s
# 	epoch 23 step 1720 (82%) loss=0.4581 elapsed=978s eta=211s
# 	epoch 23 step 1740 (83%) loss=0.4199 elapsed=989s eta=200s
# 	epoch 23 step 1760 (84%) loss=0.4659 elapsed=1001s eta=188s
# 	epoch 23 step 1780 (85%) loss=0.4543 elapsed=1012s eta=177s
# 	epoch 23 step 1800 (86%) loss=0.4829 elapsed=1023s eta=166s
# 	epoch 23 step 1820 (87%) loss=0.5506 elapsed=1035s eta=154s
# 	epoch 23 step 1840 (88%) loss=0.5497 elapsed=1046s eta=143s
# 	epoch 23 step 1860 (89%) loss=0.4773 elapsed=1057s eta=132s
# 	epoch 23 step 1880 (90%) loss=0.3935 elapsed=1069s eta=120s
# 	epoch 23 step 1900 (91%) loss=0.4722 elapsed=1080s eta=109s
# 	epoch 23 step 1920 (92%) loss=0.4475 elapsed=1091s eta=97s
# 	epoch 23 step 1940 (93%) loss=0.3789 elapsed=1103s eta=86s
# 	epoch 23 step 1960 (94%) loss=0.3451 elapsed=1114s eta=75s
# 	epoch 23 step 1980 (95%) loss=0.5755 elapsed=1125s eta=63s
# 	epoch 23 step 2000 (96%) loss=0.4706 elapsed=1136s eta=52s
# 	epoch 23 step 2020 (97%) loss=0.6460 elapsed=1148s eta=41s
# 	epoch 23 step 2040 (98%) loss=0.5056 elapsed=1159s eta=29s
# 	epoch 23 step 2060 (98%) loss=0.4245 elapsed=1170s eta=18s
# 	epoch 23 step 2080 (99%) loss=0.4519 elapsed=1182s eta=7s
# epoch 23/50 | time 1188.4s | loss 0.4575 | L_CE 0.4181 | L_intra 0.1812 | L_inter -0.5115 | grad_var 2.35e-02 | intra_fid 0.819 | inter_TD 0.519 | val_loss 0.7194 | lr 5.98e-03 | peak_mem=50MB | best=0.6572@ep19 | bad=4/5
#   saved checkpoint: final_notebooks/final_artifacts/final-bot-iot-maqt_seed42/maqt-epoch023.pt
# 	epoch 24 step 20 (1%) loss=0.2983 elapsed=11s eta=1179s
# 	epoch 24 step 40 (2%) loss=0.4404 elapsed=23s eta=1162s
# 	epoch 24 step 60 (3%) loss=0.5343 elapsed=34s eta=1150s
# 	epoch 24 step 80 (4%) loss=0.5270 elapsed=45s eta=1140s
# 	epoch 24 step 100 (5%) loss=0.4544 elapsed=57s eta=1127s
# 	epoch 24 step 120 (6%) loss=0.5317 elapsed=68s eta=1115s
# 	epoch 24 step 140 (7%) loss=0.4297 elapsed=79s eta=1104s
# 	epoch 24 step 160 (8%) loss=0.4373 elapsed=91s eta=1093s
# 	epoch 24 step 180 (9%) loss=0.3957 elapsed=102s eta=1082s
# 	epoch 24 step 200 (10%) loss=0.5370 elapsed=113s eta=1070s
# 	epoch 24 step 220 (11%) loss=0.3856 elapsed=125s eta=1059s
# 	epoch 24 step 240 (11%) loss=0.4634 elapsed=136s eta=1048s
# 	epoch 24 step 1060 (51%) loss=0.4503 elapsed=603s eta=587s
# 	epoch 24 step 1080 (52%) loss=0.5162 elapsed=615s eta=576s
# 	epoch 24 step 1100 (53%) loss=0.4220 elapsed=626s eta=564s
# 	epoch 24 step 1120 (54%) loss=0.4305 elapsed=637s eta=553s
# 	epoch 24 step 1140 (55%) loss=0.4878 elapsed=649s eta=542s
# 	epoch 24 step 1160 (55%) loss=0.5624 elapsed=660s eta=530s
# 	epoch 24 step 1180 (56%) loss=0.3720 elapsed=672s eta=519s
# 	epoch 24 step 1200 (57%) loss=0.4354 elapsed=683s eta=507s
# 	epoch 24 step 1220 (58%) loss=0.3989 elapsed=694s eta=496s
# 	epoch 24 step 1240 (59%) loss=0.4541 elapsed=706s eta=485s
# 	epoch 24 step 1260 (60%) loss=0.4117 elapsed=717s eta=473s
# 	epoch 24 step 1280 (61%) loss=0.4122 elapsed=728s eta=462s
# 	epoch 24 step 1300 (62%) loss=0.3791 elapsed=740s eta=450s
# 	epoch 24 step 1320 (63%) loss=0.4944 elapsed=751s eta=439s
# 	epoch 24 step 1340 (64%) loss=0.4591 elapsed=762s eta=428s
# 	epoch 24 step 1360 (65%) loss=0.3644 elapsed=774s eta=416s
# 	epoch 24 step 1380 (66%) loss=0.4295 elapsed=785s eta=405s
# 	epoch 24 step 1400 (67%) loss=0.5616 elapsed=797s eta=393s
# 	epoch 24 step 1420 (68%) loss=0.3814 elapsed=808s eta=382s
# 	epoch 24 step 1440 (69%) loss=0.4837 elapsed=820s eta=371s
# 	epoch 24 step 1460 (70%) loss=0.4061 elapsed=831s eta=359s
# 	epoch 24 step 1480 (71%) loss=0.4412 elapsed=843s eta=348s
# 	epoch 24 step 1500 (72%) loss=0.4930 elapsed=854s eta=337s
# 	epoch 24 step 1520 (73%) loss=0.3575 elapsed=865s eta=325s
# 	epoch 24 step 1540 (74%) loss=0.3677 elapsed=877s eta=314s
# 	epoch 24 step 1560 (75%) loss=0.7078 elapsed=888s eta=303s
# 	epoch 24 step 1580 (76%) loss=0.5502 elapsed=900s eta=291s
# 	epoch 24 step 1600 (77%) loss=0.4028 elapsed=911s eta=280s
# 	epoch 24 step 1620 (77%) loss=0.5228 elapsed=922s eta=268s
# 	epoch 24 step 1640 (78%) loss=0.5324 elapsed=934s eta=257s
# 	epoch 24 step 1660 (79%) loss=0.4111 elapsed=945s eta=246s
# 	epoch 24 step 1680 (80%) loss=0.4352 elapsed=956s eta=234s
# 	epoch 24 step 1700 (81%) loss=0.3747 elapsed=968s eta=223s
# 	epoch 24 step 1720 (82%) loss=0.5463 elapsed=979s eta=211s
# 	epoch 24 step 1740 (83%) loss=0.4075 elapsed=990s eta=200s
# 	epoch 24 step 1760 (84%) loss=0.4033 elapsed=1002s eta=189s
# 	epoch 24 step 1780 (85%) loss=0.3999 elapsed=1013s eta=177s
# 	epoch 24 step 1800 (86%) loss=0.4731 elapsed=1024s eta=166s
# 	epoch 24 step 1820 (87%) loss=0.3736 elapsed=1036s eta=154s
# 	epoch 24 step 1840 (88%) loss=0.4041 elapsed=1047s eta=143s
# 	epoch 24 step 1860 (89%) loss=0.4386 elapsed=1059s eta=132s
# 	epoch 24 step 1880 (90%) loss=0.5211 elapsed=1070s eta=120s
# 	epoch 24 step 1900 (91%) loss=0.3670 elapsed=1081s eta=109s
# 	epoch 24 step 1920 (92%) loss=0.4205 elapsed=1092s eta=98s
# 	epoch 24 step 1940 (93%) loss=0.4759 elapsed=1104s eta=86s
# 	epoch 24 step 1960 (94%) loss=0.5424 elapsed=1115s eta=75s
# 	epoch 24 step 1980 (95%) loss=0.5369 elapsed=1126s eta=63s
# 	epoch 24 step 2000 (96%) loss=0.5272 elapsed=1137s eta=52s
# 	epoch 24 step 2020 (97%) loss=0.4091 elapsed=1149s eta=41s
# 	epoch 24 step 2040 (98%) loss=0.4512 elapsed=1160s eta=29s
# 	epoch 24 step 2060 (98%) loss=0.3190 elapsed=1172s eta=18s
# 	epoch 24 step 2080 (99%) loss=0.4362 elapsed=1183s eta=7s
# epoch 24/50 | time 1189.3s | loss 0.4597 | L_CE 0.4205 | L_intra 0.1804 | L_inter -0.5104 | grad_var 2.39e-02 | intra_fid 0.820 | inter_TD 0.510 | val_loss 0.6786 | lr 5.67e-03 | peak_mem=50MB | best=0.6572@ep19 | bad=5/5
#   saved checkpoint: final_notebooks/final_artifacts/final-bot-iot-maqt_seed42/maqt-epoch024.pt
# early stopping at epoch 24: no val_loss improvement for 5 epochs (best=0.6572 @ epoch 19)
# restored best MAQT weights from epoch 19 (val_loss=0.6572)
#
# epochs_ran=24 | best_epoch=19 | stopped_early=True | stop_reason=early_stopping

# %% [markdown]
# ## Prototypes

# %%
proto_df = pd.DataFrame(prototype_summary(prototypes, class_names))
proto_df
# Out:
#             class  dim     trace
# 0            DDoS   32  1.000001
# 1             DoS   32  1.000001
# 2          Normal   32  1.000001
# 3  Reconnaissance   32  1.000001

# %%
# save prototypes (all-in-one checkpoint)
out_dir = Path("final_notebooks") / "final_artifacts"
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_path = out_dir / f"{NOTEBOOK_NAME}-checkpoint.pt"
torch.save(
    {
        "theta": theta_star.detach().cpu(),
        "head_state_dict": head.state_dict(),
        "prototypes": {k: v.detach().cpu() for k, v in prototypes.items()},

        # rebuild / inference meta
        "class_names": list(class_names),
        "num_classes": num_classes,
        "num_qubits": num_qubits,
        "num_layers": num_layers,
        "noise_rate": noise_rate,

        # FROZEN feature + angle pipeline (must match train)
        "feature_cols": list(FEATURE_COLS),
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "target_col": target_col,
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "scaler": scaler,                    # StandardScaler fitted on full train
        "pca": pca,                          # PCA fitted on scaled full train (or None)
        "k95": int(k95),
        "angle_x_min": np.asarray(x_min),    # on pca space if USE_PCA else scaled space
        "angle_x_max": np.asarray(x_max),
        "angle_min": 0.0,
        "angle_max": float(np.pi),
    },
    ckpt_path,
)
print("published:", ckpt_path.resolve())
# Out:
# published: /home/lawun330/Desktop/quantum-sentinel/final_notebooks/final_artifacts/final-bot-iot-maqt-checkpoint.pt

# %% [markdown]
# ## Visualization

# %%
# plots
epochs_x = range(1, len(history["loss"]) + 1)

fig, axes = plt.subplots(1, 3, figsize=(14, 4))

# total loss
axes[0].plot(epochs_x, history["loss"], marker="o")
axes[0].set_title("Total loss")
axes[0].set_xlabel("Epoch")

# decomposed (weighted like the objective)
axes[1].plot(epochs_x, history["loss"], marker=None, label=r"$L$")
axes[1].plot(epochs_x, history["L_CE"], "--", label=r"$L_{CE}$")
axes[1].plot(epochs_x, [lambda1 * v for v in history["L_intra"]], "--", label=r"$\lambda_1 L_{intra}$")
axes[1].plot(epochs_x, [lambda2 * v for v in history["L_inter"]], "--", label=r"$\lambda_2 L_{inter}$")
axes[1].set_title(r"$Decomposed L = L_{CE}+\lambda_1 L_{intra}+\lambda_2 L_{inter}$")
axes[1].legend(fontsize=8)

# grad var
axes[2].plot(epochs_x, history["grad_var"], marker="o", color="tab:orange")
axes[2].axhline(1e-6, color="red", linestyle="--", label="plateau thr")  # or BARREN_PLATEAU_VAR_THRESHOLD
axes[2].set_title("Gradient variance")
axes[2].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Logging

# %%
# write log (final)
log_path = write_history_log(
    history,
    NOTEBOOK_NAME,
    extra={
        ## data
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "dataset": dataset,
        "feature_cols": FEATURE_COLS,
        "target_col": target_col,
        "n_train": len(X_train),
        "class_names": list(class_names),
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "num_qubits": num_qubits,
        "k95": int(k95),

        # algo 1: MAQT train
        "epochs": epochs,
        "batch_size": batch_size,
        "lr": lr,
        "lambda1": lambda1,
        "lambda2": lambda2,

        ## quantum model
        "noise_rate": noise_rate,
        "num_layers": num_layers,
        "num_classes": num_classes,

        ## training
        "train_total_sec": float(sum(history["epoch_sec"])) if history.get("epoch_sec") else None,
        "loss_last": float(history["loss"][-1]) if history["loss"] else None,
        "barren_plateau_var": barren_plateau_var,
        "barren_plateau_any": bool(
            any(g < barren_plateau_var for g in history["grad_var"])
        ) if history.get("grad_var") else None,
        "seed": SEED,
        "early_stopping": early_stopping,
        "patience": patience,
        "best_epoch": history.get("best_epoch"),
        "best_score": history.get("best_score"),
        "stopped_early": history.get("stopped_early"),
        "epochs_ran": history.get("epochs_ran"),
        "stop_reason": history.get("stop_reason"),
        "interrupted": history.get("interrupted"),
        "checkpoint_dir": str(ckpt_dir),
    },
    log_dir="logs",
)
print(f"wrote {log_path.resolve()}")
# Out:
# wrote /home/lawun330/Desktop/quantum-sentinel/logs/final-bot-iot-maqt.log
