# %% [markdown]
# # CE-only VQC with FROZEN Features: BoT-IoT
# ## All Samples | ~148,000 Train | Batch Size 64
# ## Fair MAQT ablation baseline (same data/circuit/hparams; CE loss only)
# ## 50 Epochs (Early Stopping with Patience = 5) | LR Decay (Start at 0.01)
# ## Target (y) = "label_multiclass" | Data Reupload = 2

# %% [markdown]
# ## Setup

# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import torch
from pennylane import numpy as np
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from scripts.circuit import build_forward_circuit, create_quantum_device
from scripts.constants import (
    BARREN_PLATEAU_VAR_THRESHOLD,
    DEFAULT_NOISE_RATE,
)
from scripts.data import (
    greedy_dpp_sample,
    load_split,
    plot_class_balance_pie,
    plot_dataset_and_sampling_analysis,
    to_angles,
)
from scripts.gradient import gradient_variance_probe
from scripts.logging import write_history_log
from scripts.memory import is_oom_error, run_batched_safely, safe_empty_cache
from scripts.prototypes import PrototypeBank, prototype_summary
from scripts.theory import verify_fidelity_convention
from scripts.train import train_plain_vqc
from scripts.utils import get_torch_device, to_np_y

# %%
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available?: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA device name: {torch.cuda.get_device_name(0)}")
    print(f"Current CUDA device index: {torch.cuda.current_device()}")
# Out:
# PyTorch version: 2.12.1+cu126
# CUDA available?: True
# CUDA device name: NVIDIA GeForce GTX 1060
# Current CUDA device index: 0

# %% [markdown]
# ## Config

# %%
NOTEBOOK_NAME = "final-bot-iot-vqc-train"

dataset = "BoT-IoT"
target_col = "label_multiclass"
data_path = f"data/FROZEN/{dataset}"
frozen_feat_path = "team-artifacts/teamC_week3_FROZEN_handoff.json"

SEED = 42

# %%
check = verify_fidelity_convention(dim=4, n_trials=30, seed=SEED)
print("Fidelity-convention self-check PASSED:", check)
# Out:
# Fidelity-convention self-check PASSED: {'max_pairwise_disagreement': 0.0, 'max_fvg_violation': 0.0}

# %% [markdown]
# ## Load Team C's FROZEN Features

# %%
handoff = json.loads(Path(frozen_feat_path).read_text())
FEATURE_COLS = list(handoff["frozen_subsets"][dataset]["features"])
print(f"Team C selector: {handoff['frozen_subsets'][dataset]['selector']}")
print(f"k={len(FEATURE_COLS)} features: {FEATURE_COLS}")
# Out:
# Team C selector: QIGPSO
# k=10 features: ['n_pkts_total', 'n_bytes_total', 'src_bytes', 'rate', 'pkt_size_min', 'pkt_size_max', 'pkt_size_mean', 'pkt_size_std', 'protocol', 'conn_state']

# %% [markdown]
# ## Load Team A's FROZEN Dataset

# %%
# load all data
X_train_full, y_train_full, class_names, df_train = load_split(
    data_path, "train", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_cal_full, y_cal_full, _, df_cal = load_split(
    data_path, "calibration", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_test_full, y_test_full, _, df_test = load_split(
    data_path, "test", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_zero_full, y_zero_full, _, df_zero = load_split(
    data_path, "zeroday", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)

# check shape
print(f"train   : {X_train_full.shape, y_train_full.shape}\n\
cal     : {X_cal_full.shape, y_cal_full.shape}\n\
test    : {X_test_full.shape, y_test_full.shape}\n\
zero    : {X_zero_full.shape, y_zero_full.shape}\n\
classes : {class_names}\n"
)

df_train.head(3)
# Out:
# train   : ((148729, 10), (148729,))
# cal     : ((18591, 10), (18591,))
# test    : ((18591, 10), (18591,))
# zero    : ((683, 10), (683,))
# classes : ['DDoS', 'DoS', 'Normal', 'Reconnaissance']
#    n_pkts_total  n_bytes_total  src_bytes      rate  pkt_size_min  \
# 0     -0.262256      -0.798644  -0.774964 -0.356930      0.000000
# 1      0.427561      -0.121016   0.000000 -0.123704      0.000000
# 2      0.768961       0.200956   0.368220  1.725276      0.761987
#
#    pkt_size_max  pkt_size_mean  pkt_size_std  protocol  conn_state  \
# 0      0.123458      -0.266091      0.827772       0.0         0.0
# 1      0.120431       0.030826      0.766490       0.0         0.0
# 2      0.244690       0.422755      0.618673       0.0         0.0
#
#   label_multiclass
# 0              DoS
# 1              DoS
# 2             DDoS

# %% [markdown]
# ## EDA (Before Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train_full, class_names,
    title=f"train (n={len(to_np_y(y_train_full))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 4

# %% [markdown]
# ## Scaling

# %%
# fit scaler on full train (raw); transform elsewhere via to_angles()
scaler = StandardScaler()
X_train_full_scaled = scaler.fit_transform(X_train_full)
print(f"scaled full train: {X_train_full_scaled.shape}")
# Out:
# scaled full train: (148729, 10)

# %% [markdown]
# ## PCA (Optional)

# %%
USE_PCA = True   # set to False to skip PCA
TARGET_VARIANCE = 0.95

# %%
if USE_PCA:
    pca_full = PCA(random_state=SEED).fit(X_train_full_scaled)
    ratios = pca_full.explained_variance_ratio_
    cum = np.cumsum(ratios)
    n_feat = len(ratios)

    print(f"features (raw dim): {n_feat}")
    print("explained_variance_ratio_:", np.round(ratios, 4))
    print("cumulative:               ", np.round(cum, 4))
    for k in range(1, n_feat + 1):
        print(f"first {k} PCs keep {cum[k - 1]*100:.2f}% variance")

    # smallest k with >= target variance
    k95 = int(np.searchsorted(cum, TARGET_VARIANCE) + 1)
    k95 = min(k95, len(cum))  # safety
    print(f"components needed for >={TARGET_VARIANCE*100}% variance: {k95}")

    fig, ax = plt.subplots(1, 1, figsize=(8, 5))
    ax.bar(range(1, n_feat + 1), ratios, color="slateblue", alpha=0.7, label="per-PC")
    ax.plot(range(1, n_feat + 1), cum, marker="o", color="darkblue", label="cumulative")
    ax.axhline(TARGET_VARIANCE, color="red", linestyle="--", label=f"Target({TARGET_VARIANCE*100}%)")
    ax.axvline(k95, color="green", linestyle=":", label=f"k={k95}")
    ax.set_xlabel("PCA component")
    ax.set_ylabel("explained variance ratio")
    ax.set_title("PCA explained feature variance")
    ax.legend()
    plt.tight_layout()
    plt.show()

    pca = PCA(n_components=k95, random_state=SEED)
    X_train_full_feat = pca.fit_transform(X_train_full_scaled)
else:
    pca = None
    k95 = X_train_full_scaled.shape[1]
    X_train_full_feat = X_train_full_scaled

# angle bounds from full train feature space (pca or scaled)
x_min, x_max = X_train_full_feat.min(0), X_train_full_feat.max(0)
print(f"feature dim for angles: {X_train_full_feat.shape[1]} | USE_PCA={USE_PCA}")
# Out:
# features (raw dim): 10
# explained_variance_ratio_: [0.3698 0.2823 0.1538 0.0927 0.0827 0.0085 0.0052 0.0034 0.0008 0.0007]
# cumulative:                [0.3698 0.6521 0.8059 0.8986 0.9813 0.9898 0.995  0.9985 0.9993 1.    ]
# first 1 PCs keep 36.98% variance
# first 2 PCs keep 65.21% variance
# first 3 PCs keep 80.59% variance
# first 4 PCs keep 89.86% variance
# first 5 PCs keep 98.13% variance
# first 6 PCs keep 98.98% variance
# first 7 PCs keep 99.50% variance
# first 8 PCs keep 99.85% variance
# first 9 PCs keep 99.93% variance
# first 10 PCs keep 100.00% variance
# components needed for >=95.0% variance: 5
# feature dim for angles: 5 | USE_PCA=True

# %% [markdown]
# ## Data Subset (Optional)

# %%
SUBSET = False   # set to False for the full dataset
PER_CLASS_CAP = 3000

# %%
# compare sampling strategies on RAW full train, then apply DPP coreset
if SUBSET:
    plot_dataset_and_sampling_analysis(
        X_train_full,
        y_train_full,
        per_class_cap=PER_CLASS_CAP,
        class_names=class_names,
        seed=SEED,
    )

    print(f"\nRunning representative DPP coreset sampling (cap={PER_CLASS_CAP})...")
    X_train, y_train = greedy_dpp_sample(
        X_train_full, y_train_full, per_class_cap=PER_CLASS_CAP, seed=SEED
    )
    print(f"Coreset selected: {X_train.shape[0]} samples.")
else:
    X_train, y_train = X_train_full, y_train_full
    print(f"using full train (no subset): {X_train.shape[0]} samples")

print(f"train raw: {X_train.shape, y_train.shape} | SUBSET={SUBSET} | cap={PER_CLASS_CAP if SUBSET else 'all'}")
# Out:
# using full train (no subset): 148729 samples
# train raw: ((148729, 10), (148729,)) | SUBSET=False | cap=all

# %% [markdown]
# ## EDA (After Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train, class_names,
    title=f"train subset (n={len(to_np_y(y_train))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 4

# %% [markdown]
# ## Mapping Features $\rightarrow$ [0, $\pi$]

# %%
# raw -> scale -> optional pca -> [0, pi] using bounds from full train
X_train_angles_all = to_angles(
    X_train, scaler, x_min, x_max, pca=pca if USE_PCA else None, angle_max=np.pi
)

# seeded stratified holdout from train for early stopping (cal/test untouched)
VAL_FRAC = 0.1
_y_all = y_train
idx = np.arange(len(X_train_angles_all))
idx_fit, idx_val = train_test_split(
    idx, test_size=VAL_FRAC, stratify=_y_all, random_state=SEED,
)
X_train_angles, y_train = X_train_angles_all[idx_fit], _y_all[idx_fit]
X_val_angles, y_val = X_train_angles_all[idx_val], _y_all[idx_val]
print(
    f"angles fit: {X_train_angles.shape} | val: {X_val_angles.shape} | "
    f"VAL_FRAC={VAL_FRAC} | USE_PCA={USE_PCA} | SUBSET={SUBSET}"
)

fig, ax1 = plt.subplots(1, 1, figsize=(7, 4))
ax1.hist(X_train_angles.flatten(), bins=50, color="teal", alpha=0.8)
ax1.set_xlabel("angle (radians)")
ax1.set_title("Angle-encoded train (fit) feature distribution")
plt.tight_layout()
plt.show()
# Out:
# angles fit: (133856, 5) | val: (14873, 5) | VAL_FRAC=0.1 | USE_PCA=True | SUBSET=False

# %% [markdown]
# ## Quantum Circuit: Angle Encoding, Data Reuploading, and Adding Noise
#
# $$
# x\xrightarrow[\text{encode}]{\phi(x)}\ket{\psi(x)}\xrightarrow[\text{variational}]{U(\theta)}\ket{\Phi(x)}\xrightarrow{\Lambda_p}\rho(x)
# $$
# - $x$: classical data
# - $\phi(x)$: `qp.AngleEmbedding()`
# - $\ket{\psi(x)}$: quantum state after encoding
# - $U(\theta)$: `qp.StronglyEntanglingLayers()`
# - $\ket{\Phi(x)}$: quantum state after variational transform
# - $\rho(x)=\Lambda_p(\ket{\Phi(x)}\bra{\Phi(x)})$: standard depolarization channel to model NISQ noise

# %%
num_qubits = int(k95)           # pca comps if USE_PCA; else scaled feature dim
num_layers = 2                  # reupload same classical data
noise_rate = DEFAULT_NOISE_RATE
print(f"num_qubits={num_qubits} (USE_PCA={USE_PCA})")
# Out:
# num_qubits=5 (USE_PCA=True)

# %%
# initialize devices
device = get_torch_device()
dev = create_quantum_device(num_qubits) # or dev = qp.device("default.mixed", wires=num_qubits)

# define circuit
forward_circuit = build_forward_circuit(dev, num_qubits, num_layers, noise_rate=noise_rate)

# %% [markdown]
# ## Gradient Variance Probe

# %%
barren_plateau_var = BARREN_PLATEAU_VAR_THRESHOLD
n_trials = 5

safe_empty_cache()

# probe on CPU (recommended)
x_probe = X_train_angles[:1]

try:
    grad_var, grad_samples = gradient_variance_probe(
        forward_circuit, x_probe, num_qubits, num_layers,
        n_trials=n_trials,
        device=torch.device("cpu"),
    )

    print(f"pre-train grad var = {grad_var:.2e} (thr={barren_plateau_var:.0e})")
    if grad_var < barren_plateau_var:
        print("warning: possible barren plateau architecture")

    plt.figure(figsize=(6, 4)); plt.hist(grad_samples, bins=15, color="darkcyan", alpha=0.8)
    plt.title(f"Gradient-variance probe (var={grad_var:.2e})"); plt.tight_layout(); plt.show()

except RuntimeError as e:
    if is_oom_error(e):
        print("\t[OOM] barren-plateau probe skipped (non-critical diagnostic).")
        safe_empty_cache()
    else:
        raise
# Out:
# pre-train grad var = 3.16e-09 (thr=1e-06)
# warning: possible barren plateau architecture

# %% [markdown]
# ## Training
#
# $$
# L = L_{CE}
# $$
#
# CE-only baseline: same quantum circuit + classical head as MAQT, no prototype losses.
#
# Minimizing $L_{CE}$ adjusts $\theta$ for better class predictions.

# %%
epochs = 50
batch_size = 64
lr = 0.01
early_stopping = True
patience = 5
min_delta = 0.001

out_dir = Path("artifacts") / dataset
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_dir = out_dir / f"{NOTEBOOK_NAME}_seed{SEED}"
latest_ckpt = ckpt_dir / "plain-latest.pt"
# old capped-subset ckpts are not compatible with full-data MAQT-matched run
RESUME = False
resume_from = latest_ckpt if (RESUME and latest_ckpt.exists()) else None

print(f"checkpoint_dir: {ckpt_dir}")
print(f"resume_from: {resume_from}")
# Out:
# checkpoint_dir: artifacts/BoT-IoT/final-bot-iot-vqc-train_seed42
# resume_from: None

# %%
torch.manual_seed(SEED)

result = run_batched_safely(
    train_plain_vqc,
    X_train_angles,
    y_train,
    n_classes=num_classes,
    n_qubits=num_qubits,
    n_layers=num_layers,
    forward_circuit=forward_circuit,
    device=device,
    epochs=epochs,
    lr=lr,
    use_lr_schedule=True,  # auto LR (match final-bot-iot-maqt)
    batch_size=batch_size,
    min_batch=2,
    label="train_plain_vqc",
    use_weighted_sampler=True,
    seed=SEED,
    early_stopping=early_stopping,
    patience=patience,
    min_delta=min_delta,
    X_val=X_val_angles,
    y_val=y_val,
    checkpoint_dir=ckpt_dir,
    save_every_epoch=True,
    resume_from=resume_from,
    reset_early_stopping_on_resume=True,
    heartbeat_every_steps=20,  # pass None to less verbose
    notebook_name=NOTEBOOK_NAME,
    log_dir=ckpt_dir,
)

if result is None:
    raise RuntimeError("train_plain_vqc failed even at min_batch (OOM)")

theta, head, history = result
theta_star = theta
classifier_head = head
safe_empty_cache()
print(
    "\n"
    f"epochs_ran={history.get('epochs_ran')} | "
    f"best_epoch={history.get('best_epoch')} | "
    f"stopped_early={history.get('stopped_early')} | "
    f"stop_reason={history.get('stop_reason')}"
)
# Out:
# 	epoch 1 step 20 (1%) loss=1.2896 elapsed=3s eta=271s
# 	epoch 1 step 40 (2%) loss=1.1926 elapsed=5s eta=242s
# 	epoch 1 step 60 (3%) loss=1.1074 elapsed=7s eta=234s
# 	epoch 1 step 80 (4%) loss=1.0133 elapsed=9s eta=228s
# 	epoch 1 step 100 (5%) loss=0.8854 elapsed=11s eta=223s
# 	epoch 1 step 120 (6%) loss=0.8299 elapsed=13s eta=220s
# 	epoch 1 step 140 (7%) loss=0.8720 elapsed=16s eta=220s
# 	epoch 1 step 160 (8%) loss=0.8574 elapsed=18s eta=219s
# 	epoch 1 step 180 (9%) loss=0.7222 elapsed=20s eta=216s
# 	epoch 1 step 200 (10%) loss=0.7882 elapsed=22s eta=212s
# 	epoch 1 step 220 (11%) loss=0.7252 elapsed=25s eta=210s
# 	epoch 1 step 240 (11%) loss=0.6879 elapsed=27s eta=207s
# 	epoch 1 step 260 (12%) loss=0.6360 elapsed=29s eta=204s
# 	epoch 1 step 280 (13%) loss=0.7196 elapsed=31s eta=201s
# 	epoch 1 step 300 (14%) loss=0.7204 elapsed=33s eta=198s
# 	epoch 1 step 320 (15%) loss=0.6336 elapsed=35s eta=196s
# 	epoch 1 step 340 (16%) loss=0.6531 elapsed=37s eta=193s
# 	epoch 1 step 360 (17%) loss=0.7725 elapsed=40s eta=190s
#   saved checkpoint: artifacts/BoT-IoT/final-bot-iot-vqc-train_seed42/plain-epoch002.pt
# 	epoch 3 step 20 (1%) loss=0.4477 elapsed=2s eta=244s
# 	epoch 3 step 40 (2%) loss=0.4630 elapsed=5s eta=232s
# 	epoch 3 step 60 (3%) loss=0.6144 elapsed=7s eta=226s
# 	epoch 3 step 80 (4%) loss=0.4140 elapsed=9s eta=224s
# 	epoch 3 step 100 (5%) loss=0.4726 elapsed=11s eta=220s
# 	epoch 3 step 120 (6%) loss=0.5252 elapsed=13s eta=218s
# 	epoch 3 step 140 (7%) loss=0.4596 elapsed=15s eta=215s
# 	epoch 3 step 160 (8%) loss=0.3640 elapsed=18s eta=212s
# 	epoch 3 step 180 (9%) loss=0.5275 elapsed=20s eta=210s
# 	epoch 3 step 200 (10%) loss=0.4503 elapsed=22s eta=208s
# 	epoch 3 step 220 (11%) loss=0.5884 elapsed=24s eta=208s
# 	epoch 3 step 240 (11%) loss=0.3583 elapsed=27s eta=205s
# 	epoch 3 step 260 (12%) loss=0.6274 elapsed=29s eta=202s
# 	epoch 3 step 280 (13%) loss=0.4852 elapsed=31s eta=199s
# 	epoch 3 step 300 (14%) loss=0.3785 elapsed=33s eta=197s
# 	epoch 3 step 320 (15%) loss=0.5104 elapsed=35s eta=195s
# 	epoch 3 step 340 (16%) loss=0.5330 elapsed=37s eta=193s
# 	epoch 3 step 360 (17%) loss=0.6076 elapsed=40s eta=190s
# 	epoch 3 step 380 (18%) loss=0.4946 elapsed=42s eta=188s
# 	epoch 3 step 400 (19%) loss=0.4852 elapsed=44s eta=185s
# 	epoch 3 step 420 (20%) loss=0.6828 elapsed=47s eta=185s
# 	epoch 3 step 440 (21%) loss=0.4094 elapsed=50s eta=187s
# 	epoch 3 step 460 (22%) loss=0.4698 elapsed=53s eta=189s
# 	epoch 3 step 480 (23%) loss=0.4034 elapsed=56s eta=186s
# 	epoch 3 step 500 (24%) loss=0.5195 elapsed=58s eta=183s
# 	epoch 3 step 520 (25%) loss=0.4452 elapsed=60s eta=181s
# 	epoch 3 step 540 (26%) loss=0.5143 elapsed=62s eta=178s
# 	epoch 3 step 560 (27%) loss=0.4138 elapsed=64s eta=175s
# 	epoch 3 step 580 (28%) loss=0.2904 elapsed=66s eta=173s
# 	epoch 3 step 600 (29%) loss=0.4266 elapsed=69s eta=170s
# 	epoch 3 step 620 (30%) loss=0.5910 elapsed=71s eta=168s
# 	epoch 3 step 640 (31%) loss=0.4109 elapsed=73s eta=165s
# 	epoch 3 step 660 (32%) loss=0.4143 elapsed=75s eta=163s
# 	epoch 3 step 680 (33%) loss=0.5622 elapsed=77s eta=161s
# 	epoch 3 step 700 (33%) loss=0.5019 elapsed=80s eta=158s
# 	epoch 3 step 720 (34%) loss=0.4617 elapsed=82s eta=155s
# 	epoch 3 step 740 (35%) loss=0.5573 elapsed=84s eta=153s
# 	epoch 3 step 760 (36%) loss=0.4511 elapsed=86s eta=151s
# 	epoch 3 step 780 (37%) loss=0.4271 elapsed=90s eta=151s
# 	epoch 3 step 800 (38%) loss=0.4798 elapsed=92s eta=149s
# 	epoch 3 step 820 (39%) loss=0.6896 elapsed=95s eta=147s
# 	epoch 3 step 840 (40%) loss=0.4318 elapsed=97s eta=144s
# 	epoch 3 step 860 (41%) loss=0.5207 elapsed=99s eta=142s
# 	epoch 3 step 880 (42%) loss=0.4998 elapsed=101s eta=140s
# 	epoch 3 step 900 (43%) loss=0.6118 elapsed=103s eta=137s
# 	epoch 3 step 920 (44%) loss=0.5065 elapsed=106s eta=135s
# 	epoch 3 step 940 (45%) loss=0.5142 elapsed=108s eta=132s
# 	epoch 3 step 960 (46%) loss=0.5463 elapsed=110s eta=130s
# 	epoch 3 step 980 (47%) loss=0.4148 elapsed=112s eta=127s
# 	epoch 3 step 1000 (48%) loss=0.5086 elapsed=114s eta=125s
# 	epoch 3 step 1020 (49%) loss=0.4626 elapsed=117s eta=123s
# 	epoch 3 step 1040 (50%) loss=0.4135 elapsed=119s eta=120s
# 	epoch 3 step 1060 (51%) loss=0.4546 elapsed=121s eta=118s
# 	epoch 3 step 1080 (52%) loss=0.4610 elapsed=125s eta=117s
# 	epoch 3 step 1100 (53%) loss=0.3109 elapsed=128s eta=116s
# 	epoch 3 step 1120 (54%) loss=0.4764 elapsed=132s eta=114s
# 	epoch 3 step 1140 (55%) loss=0.6211 elapsed=134s eta=112s
# 	epoch 3 step 1160 (55%) loss=0.5913 elapsed=136s eta=109s
# 	epoch 3 step 1180 (56%) loss=0.5031 elapsed=138s eta=107s
# 	epoch 3 step 1200 (57%) loss=0.6649 elapsed=140s eta=104s
# 	epoch 3 step 1220 (58%) loss=0.3648 elapsed=143s eta=102s
# 	epoch 3 step 1240 (59%) loss=0.6047 elapsed=145s eta=99s
# 	epoch 3 step 1260 (60%) loss=0.4296 elapsed=147s eta=97s
# 	epoch 3 step 1280 (61%) loss=0.5725 elapsed=149s eta=95s
# 	epoch 3 step 1300 (62%) loss=0.5130 elapsed=151s eta=92s
# 	epoch 3 step 1320 (63%) loss=0.3896 elapsed=155s eta=90s
# 	epoch 3 step 1340 (64%) loss=0.3173 elapsed=157s eta=88s
# 	epoch 3 step 1360 (65%) loss=0.5354 elapsed=160s eta=86s
# 	epoch 3 step 1380 (66%) loss=0.6014 elapsed=162s eta=83s
# 	epoch 3 step 1400 (67%) loss=0.6348 elapsed=164s eta=81s
# 	epoch 3 step 1420 (68%) loss=0.4558 elapsed=166s eta=79s
# 	epoch 3 step 1440 (69%) loss=0.4081 elapsed=168s eta=76s
# 	epoch 3 step 1460 (70%) loss=0.5264 elapsed=171s eta=74s
# 	epoch 3 step 1480 (71%) loss=0.3384 elapsed=173s eta=71s
# 	epoch 3 step 1500 (72%) loss=0.4213 elapsed=175s eta=69s
# 	epoch 3 step 1520 (73%) loss=0.4964 elapsed=177s eta=67s
# 	epoch 3 step 1540 (74%) loss=0.6035 elapsed=179s eta=64s
# 	epoch 3 step 1560 (75%) loss=0.4250 elapsed=183s eta=62s
# 	epoch 3 step 1580 (76%) loss=0.5793 elapsed=186s eta=60s
# 	epoch 3 step 1600 (77%) loss=0.3939 elapsed=188s eta=58s
# 	epoch 3 step 1620 (77%) loss=0.3715 elapsed=190s eta=55s
# 	epoch 3 step 1640 (78%) loss=0.5063 elapsed=192s eta=53s
# 	epoch 3 step 1660 (79%) loss=0.4140 elapsed=194s eta=51s
# 	epoch 3 step 1680 (80%) loss=0.3926 elapsed=197s eta=48s
# 	epoch 3 step 1700 (81%) loss=0.3728 elapsed=199s eta=46s
# 	epoch 3 step 1720 (82%) loss=0.4667 elapsed=201s eta=43s
# 	epoch 3 step 1740 (83%) loss=0.4355 elapsed=203s eta=41s
# 	epoch 3 step 1760 (84%) loss=0.3695 elapsed=206s eta=39s
# 	epoch 3 step 1780 (85%) loss=0.6556 elapsed=208s eta=36s
# 	epoch 3 step 1800 (86%) loss=0.5099 elapsed=211s eta=34s
# 	epoch 3 step 1820 (87%) loss=0.4950 elapsed=215s eta=32s
# 	epoch 3 step 1840 (88%) loss=0.6114 elapsed=217s eta=30s
# 	epoch 3 step 1860 (89%) loss=0.4792 elapsed=219s eta=27s
# 	epoch 3 step 1880 (90%) loss=0.4333 elapsed=222s eta=25s
# 	epoch 3 step 1900 (91%) loss=0.3445 elapsed=224s eta=23s
# 	epoch 3 step 1920 (92%) loss=0.4622 elapsed=226s eta=20s
# 	epoch 3 step 1940 (93%) loss=0.5557 elapsed=228s eta=18s
# 	epoch 3 step 1960 (94%) loss=0.4784 elapsed=230s eta=15s
# 	epoch 3 step 1980 (95%) loss=0.4999 elapsed=233s eta=13s
# 	epoch 3 step 2000 (96%) loss=0.3731 elapsed=235s eta=11s
# 	epoch 3 step 2020 (97%) loss=0.5536 elapsed=237s eta=8s
# 	epoch 3 step 2040 (98%) loss=0.3918 elapsed=239s eta=6s
# 	epoch 3 step 2060 (98%) loss=0.5811 elapsed=242s eta=4s
# 	epoch 3 step 2080 (99%) loss=0.5812 elapsed=244s eta=1s
# epoch  3/50 | time 245.1s | loss 0.4777 | L_CE 0.4777 | grad_var 8.81e-03 | val_loss 0.7091 | lr 9.96e-03 | peak_mem=49MB | best=0.7091@ep3 | bad=0/5
#   saved checkpoint: artifacts/BoT-IoT/final-bot-iot-vqc-train_seed42/plain-epoch003.pt
# 	epoch 4 step 20 (1%) loss=0.5238 elapsed=2s eta=233s
# 	epoch 4 step 40 (2%) loss=0.4228 elapsed=4s eta=225s
# 	epoch 4 step 60 (3%) loss=0.5473 elapsed=7s eta=223s
# 	epoch 4 step 80 (4%) loss=0.4897 elapsed=9s eta=220s
# 	epoch 4 step 100 (5%) loss=0.4319 elapsed=11s eta=223s
# 	epoch 4 step 120 (6%) loss=0.5667 elapsed=14s eta=236s
# 	epoch 4 step 140 (7%) loss=0.5016 elapsed=18s eta=247s
# 	epoch 4 step 160 (8%) loss=0.5765 elapsed=20s eta=242s
# 	epoch 4 step 180 (9%) loss=0.5273 elapsed=22s eta=237s
# 	epoch 5 step 1980 (95%) loss=0.5356 elapsed=243s eta=14s
# 	epoch 5 step 2000 (96%) loss=0.4670 elapsed=245s eta=11s
# 	epoch 5 step 2020 (97%) loss=0.2927 elapsed=248s eta=9s
# 	epoch 5 step 2040 (98%) loss=0.3285 elapsed=250s eta=6s
# 	epoch 5 step 2060 (98%) loss=0.4302 elapsed=252s eta=4s
# 	epoch 5 step 2080 (99%) loss=0.4119 elapsed=254s eta=1s
# epoch  5/50 | time 255.8s | loss 0.4484 | L_CE 0.4484 | grad_var 1.39e-02 | val_loss 0.6985 | lr 9.84e-03 | peak_mem=49MB | best=0.6722@ep4 | bad=1/5
#   saved checkpoint: artifacts/BoT-IoT/final-bot-iot-vqc-train_seed42/plain-epoch005.pt
# 	epoch 6 step 20 (1%) loss=0.3237 elapsed=2s eta=239s
# 	epoch 6 step 40 (2%) loss=0.5215 elapsed=4s eta=230s
# 	epoch 6 step 60 (3%) loss=0.4762 elapsed=7s eta=223s
# 	epoch 6 step 80 (4%) loss=0.4416 elapsed=9s eta=220s
# 	epoch 6 step 100 (5%) loss=0.6137 elapsed=11s eta=217s
# 	epoch 6 step 120 (6%) loss=0.4079 elapsed=13s eta=216s
# 	epoch 6 step 140 (7%) loss=0.3708 elapsed=16s eta=225s
# 	epoch 6 step 160 (8%) loss=0.4026 elapsed=19s eta=235s
# 	epoch 6 step 180 (9%) loss=0.4146 elapsed=23s eta=242s
# 	epoch 6 step 200 (10%) loss=0.5560 elapsed=25s eta=239s
# 	epoch 6 step 220 (11%) loss=0.5313 elapsed=28s eta=234s
# 	epoch 6 step 240 (11%) loss=0.3959 elapsed=30s eta=229s
# 	epoch 6 step 260 (12%) loss=0.4345 elapsed=32s eta=224s
# 	epoch 6 step 280 (13%) loss=0.6052 elapsed=34s eta=221s
# 	epoch 6 step 300 (14%) loss=0.3876 elapsed=36s eta=217s
# 	epoch 6 step 320 (15%) loss=0.5304 elapsed=38s eta=213s
# 	epoch 6 step 340 (16%) loss=0.4366 elapsed=41s eta=209s
# 	epoch 6 step 360 (17%) loss=0.4431 elapsed=43s eta=206s
# 	epoch 6 step 380 (18%) loss=0.5072 elapsed=46s eta=207s
# 	epoch 6 step 400 (19%) loss=0.3511 elapsed=49s eta=208s
# 	epoch 6 step 420 (20%) loss=0.4213 elapsed=52s eta=208s
# 	epoch 6 step 440 (21%) loss=0.3950 elapsed=55s eta=205s
# 	epoch 6 step 460 (22%) loss=0.3922 elapsed=57s eta=202s
# 	epoch 6 step 480 (23%) loss=0.4516 elapsed=59s eta=198s
# 	epoch 6 step 500 (24%) loss=0.4767 elapsed=61s eta=195s
# 	epoch 6 step 520 (25%) loss=0.4220 elapsed=63s eta=192s
# 	epoch 6 step 540 (26%) loss=0.4384 elapsed=66s eta=189s
# 	epoch 6 step 560 (27%) loss=0.3473 elapsed=68s eta=186s
# 	epoch 6 step 580 (28%) loss=0.3338 elapsed=70s eta=183s
# 	epoch 6 step 600 (29%) loss=0.5382 elapsed=72s eta=180s
# 	epoch 6 step 1420 (68%) loss=0.4701 elapsed=174s eta=82s
# 	epoch 6 step 1440 (69%) loss=0.4509 elapsed=177s eta=80s
# 	epoch 6 step 1460 (70%) loss=0.4144 elapsed=180s eta=78s
# 	epoch 6 step 1480 (71%) loss=0.4490 elapsed=183s eta=75s
# 	epoch 6 step 1500 (72%) loss=0.3514 elapsed=185s eta=73s
# 	epoch 6 step 1520 (73%) loss=0.4545 elapsed=187s eta=70s
# 	epoch 6 step 1540 (74%) loss=0.4453 elapsed=189s eta=68s
# 	epoch 6 step 1560 (75%) loss=0.3928 elapsed=191s eta=65s
# 	epoch 6 step 1580 (76%) loss=0.3638 elapsed=194s eta=63s
# 	epoch 6 step 1600 (77%) loss=0.4116 elapsed=196s eta=60s
# 	epoch 6 step 1620 (77%) loss=0.4191 elapsed=198s eta=58s
# 	epoch 6 step 1640 (78%) loss=0.3823 elapsed=201s eta=55s
# 	epoch 6 step 1660 (79%) loss=0.4925 elapsed=205s eta=53s
# 	epoch 6 step 1680 (80%) loss=0.4171 elapsed=207s eta=51s
# 	epoch 6 step 1700 (81%) loss=0.4302 elapsed=210s eta=48s
# 	epoch 6 step 1720 (82%) loss=0.3138 elapsed=212s eta=46s
# 	epoch 6 step 1740 (83%) loss=0.4939 elapsed=214s eta=43s
# 	epoch 6 step 1760 (84%) loss=0.5350 elapsed=216s eta=41s
# 	epoch 6 step 1780 (85%) loss=0.4278 elapsed=218s eta=38s
# 	epoch 6 step 1800 (86%) loss=0.4704 elapsed=220s eta=36s
# 	epoch 6 step 1820 (87%) loss=0.6307 elapsed=223s eta=33s
# 	epoch 6 step 1840 (88%) loss=0.4883 elapsed=226s eta=31s
# 	epoch 6 step 1860 (89%) loss=0.3932 elapsed=230s eta=29s
# 	epoch 6 step 1880 (90%) loss=0.4809 elapsed=232s eta=26s
# 	epoch 6 step 1900 (91%) loss=0.3265 elapsed=235s eta=24s
# 	epoch 6 step 1920 (92%) loss=0.4837 elapsed=237s eta=21s
# 	epoch 6 step 1940 (93%) loss=0.3677 elapsed=239s eta=19s
# 	epoch 6 step 1960 (94%) loss=0.4556 elapsed=241s eta=16s
# 	epoch 6 step 1980 (95%) loss=0.4245 elapsed=243s eta=14s
# 	epoch 6 step 2000 (96%) loss=0.3943 elapsed=246s eta=11s
# 	epoch 6 step 2020 (97%) loss=0.4664 elapsed=248s eta=9s
# 	epoch 6 step 2040 (98%) loss=0.3623 elapsed=250s eta=6s
# 	epoch 6 step 2060 (98%) loss=0.4302 elapsed=253s eta=4s
# 	epoch 6 step 2080 (99%) loss=0.5371 elapsed=256s eta=1s
# epoch  6/50 | time 258.3s | loss 0.4431 | L_CE 0.4431 | grad_var 1.63e-02 | val_loss 0.6678 | lr 9.76e-03 | peak_mem=49MB | best=0.6678@ep6 | bad=0/5
#   saved checkpoint: artifacts/BoT-IoT/final-bot-iot-vqc-train_seed42/plain-epoch006.pt
# 	epoch 7 step 20 (1%) loss=0.3844 elapsed=2s eta=227s
# 	epoch 22 step 1400 (67%) loss=0.3755 elapsed=197s eta=97s
# 	epoch 22 step 1420 (68%) loss=0.3407 elapsed=200s eta=95s
# 	epoch 22 step 1440 (69%) loss=0.3164 elapsed=203s eta=92s
# 	epoch 22 step 1460 (70%) loss=0.2968 elapsed=206s eta=89s
# 	epoch 22 step 1480 (71%) loss=0.4254 elapsed=208s eta=86s
# 	epoch 22 step 1500 (72%) loss=0.2698 elapsed=211s eta=83s
# 	epoch 22 step 1520 (73%) loss=0.4341 elapsed=214s eta=80s
# 	epoch 22 step 1540 (74%) loss=0.2543 elapsed=217s eta=78s
# 	epoch 22 step 1560 (75%) loss=0.3699 elapsed=220s eta=75s
# 	epoch 22 step 1580 (76%) loss=0.3565 elapsed=223s eta=72s
# 	epoch 22 step 1600 (77%) loss=0.3641 elapsed=225s eta=69s
# 	epoch 22 step 1620 (77%) loss=0.4865 elapsed=228s eta=67s
# 	epoch 22 step 1640 (78%) loss=0.5007 elapsed=231s eta=64s
# 	epoch 22 step 1660 (79%) loss=0.3334 elapsed=234s eta=61s
# 	epoch 22 step 1680 (80%) loss=0.5247 elapsed=237s eta=58s
# 	epoch 22 step 1700 (81%) loss=0.6713 elapsed=240s eta=55s
# 	epoch 22 step 1720 (82%) loss=0.3093 elapsed=243s eta=52s
# 	epoch 22 step 1740 (83%) loss=0.4111 elapsed=245s eta=50s
# 	epoch 22 step 1760 (84%) loss=0.5267 elapsed=248s eta=47s
# 	epoch 22 step 1780 (85%) loss=0.3096 elapsed=251s eta=44s
# 	epoch 22 step 1800 (86%) loss=0.3854 elapsed=254s eta=41s
# 	epoch 22 step 1820 (87%) loss=0.3993 elapsed=257s eta=38s
# 	epoch 22 step 1840 (88%) loss=0.4155 elapsed=260s eta=35s
# 	epoch 22 step 1860 (89%) loss=0.5120 elapsed=263s eta=33s
# 	epoch 22 step 1880 (90%) loss=0.4608 elapsed=265s eta=30s
# 	epoch 22 step 1900 (91%) loss=0.3631 elapsed=268s eta=27s
# 	epoch 22 step 1920 (92%) loss=0.4936 elapsed=271s eta=24s
# 	epoch 22 step 1940 (93%) loss=0.4228 elapsed=274s eta=21s
# 	epoch 22 step 1960 (94%) loss=0.4123 elapsed=277s eta=19s
# 	epoch 22 step 1980 (95%) loss=0.3847 elapsed=279s eta=16s
# 	epoch 22 step 2000 (96%) loss=0.4206 elapsed=282s eta=13s
# 	epoch 22 step 2020 (97%) loss=0.6161 elapsed=285s eta=10s
# 	epoch 22 step 2040 (98%) loss=0.3809 elapsed=288s eta=7s
# 	epoch 22 step 2060 (98%) loss=0.6365 elapsed=291s eta=4s
# 	epoch 22 step 2080 (99%) loss=0.5576 elapsed=294s eta=2s
# epoch 22/50 | time 295.2s | loss 0.4190 | L_CE 0.4190 | grad_var 2.38e-02 | val_loss 0.6475 | lr 6.28e-03 | peak_mem=49MB | best=0.6194@ep19 | bad=3/5
#   saved checkpoint: artifacts/BoT-IoT/final-bot-iot-vqc-train_seed42/plain-epoch022.pt
# 	epoch 23 step 820 (39%) loss=0.3596 elapsed=117s eta=182s
# 	epoch 23 step 840 (40%) loss=0.3879 elapsed=120s eta=179s
# 	epoch 23 step 860 (41%) loss=0.4326 elapsed=123s eta=176s
# 	epoch 23 step 880 (42%) loss=0.4522 elapsed=126s eta=173s
# 	epoch 23 step 900 (43%) loss=0.3130 elapsed=129s eta=170s
# 	epoch 23 step 920 (44%) loss=0.3517 elapsed=131s eta=167s
# 	epoch 23 step 940 (45%) loss=0.4829 elapsed=134s eta=165s
# 	epoch 23 step 960 (46%) loss=0.3829 elapsed=137s eta=162s
# 	epoch 23 step 980 (47%) loss=0.4867 elapsed=140s eta=159s
# 	epoch 23 step 1000 (48%) loss=0.2654 elapsed=143s eta=156s
# 	epoch 23 step 1020 (49%) loss=0.5037 elapsed=146s eta=154s
# 	epoch 23 step 1040 (50%) loss=0.4684 elapsed=149s eta=151s
# 	epoch 23 step 1060 (51%) loss=0.3733 elapsed=152s eta=148s
# 	epoch 23 step 1080 (52%) loss=0.6280 elapsed=155s eta=145s
# 	epoch 23 step 1100 (53%) loss=0.3030 elapsed=158s eta=142s
# 	epoch 23 step 1120 (54%) loss=0.5408 elapsed=161s eta=140s
# 	epoch 23 step 1140 (55%) loss=0.5105 elapsed=164s eta=137s
# 	epoch 23 step 1160 (55%) loss=0.3642 elapsed=167s eta=134s
# 	epoch 23 step 1180 (56%) loss=0.4097 elapsed=170s eta=131s
# 	epoch 23 step 1200 (57%) loss=0.3779 elapsed=172s eta=128s
# 	epoch 23 step 1220 (58%) loss=0.4362 elapsed=175s eta=125s
# 	epoch 23 step 1240 (59%) loss=0.3291 elapsed=178s eta=122s
# 	epoch 23 step 1260 (60%) loss=0.3947 elapsed=181s eta=120s
# 	epoch 23 step 1280 (61%) loss=0.4330 elapsed=184s eta=117s
# 	epoch 23 step 1300 (62%) loss=0.3751 elapsed=187s eta=114s
# 	epoch 23 step 1320 (63%) loss=0.4323 elapsed=190s eta=111s
# 	epoch 23 step 1340 (64%) loss=0.3101 elapsed=193s eta=108s
# 	epoch 23 step 1360 (65%) loss=0.2742 elapsed=196s eta=105s
# 	epoch 23 step 1380 (66%) loss=0.4697 elapsed=199s eta=102s
# 	epoch 23 step 1400 (67%) loss=0.4882 elapsed=202s eta=100s
# 	epoch 23 step 1420 (68%) loss=0.3641 elapsed=205s eta=97s
# 	epoch 23 step 1440 (69%) loss=0.5069 elapsed=207s eta=94s
# 	epoch 23 step 1460 (70%) loss=0.4184 elapsed=210s eta=91s
# 	epoch 23 step 1480 (71%) loss=0.4511 elapsed=213s eta=88s
# 	epoch 23 step 1500 (72%) loss=0.3689 elapsed=216s eta=85s
# 	epoch 23 step 1520 (73%) loss=0.4291 elapsed=219s eta=82s
# 	epoch 23 step 1540 (74%) loss=0.4403 elapsed=221s eta=79s
# 	epoch 23 step 1560 (75%) loss=0.4143 elapsed=224s eta=76s
# 	epoch 23 step 1580 (76%) loss=0.2995 elapsed=227s eta=74s
# 	epoch 23 step 1600 (77%) loss=0.4422 elapsed=230s eta=71s
# 	epoch 23 step 1620 (77%) loss=0.2767 elapsed=234s eta=68s
# 	epoch 23 step 1640 (78%) loss=0.6262 elapsed=236s eta=65s
# 	epoch 23 step 1660 (79%) loss=0.4106 elapsed=239s eta=62s
# 	epoch 23 step 1680 (80%) loss=0.3502 elapsed=242s eta=59s
# 	epoch 23 step 1700 (81%) loss=0.4721 elapsed=245s eta=56s
# 	epoch 23 step 1720 (82%) loss=0.4098 elapsed=248s eta=54s
# 	epoch 23 step 1740 (83%) loss=0.3817 elapsed=251s eta=51s
# 	epoch 23 step 1760 (84%) loss=0.4221 elapsed=254s eta=48s
# 	epoch 23 step 1780 (85%) loss=0.4071 elapsed=257s eta=45s
# 	epoch 23 step 1800 (86%) loss=0.4377 elapsed=260s eta=42s
# 	epoch 23 step 1820 (87%) loss=0.5157 elapsed=263s eta=39s
# 	epoch 23 step 1840 (88%) loss=0.5103 elapsed=266s eta=36s
# 	epoch 23 step 1860 (89%) loss=0.4327 elapsed=268s eta=33s
# 	epoch 23 step 1880 (90%) loss=0.3628 elapsed=271s eta=31s
# 	epoch 23 step 1900 (91%) loss=0.4370 elapsed=274s eta=28s
# 	epoch 23 step 1920 (92%) loss=0.4049 elapsed=277s eta=25s
# 	epoch 23 step 1940 (93%) loss=0.3358 elapsed=280s eta=22s
# 	epoch 23 step 1960 (94%) loss=0.3053 elapsed=283s eta=19s
# 	epoch 23 step 1980 (95%) loss=0.5419 elapsed=286s eta=16s
# 	epoch 23 step 2000 (96%) loss=0.4214 elapsed=288s eta=13s
# 	epoch 23 step 2020 (97%) loss=0.5880 elapsed=291s eta=10s
# 	epoch 23 step 2040 (98%) loss=0.4786 elapsed=294s eta=7s
# 	epoch 23 step 2060 (98%) loss=0.3909 elapsed=297s eta=5s
# 	epoch 23 step 2080 (99%) loss=0.4081 elapsed=300s eta=2s
# epoch 23/50 | time 301.6s | loss 0.4180 | L_CE 0.4180 | grad_var 2.37e-02 | val_loss 0.6876 | lr 5.98e-03 | peak_mem=49MB | best=0.6194@ep19 | bad=4/5
#   saved checkpoint: artifacts/BoT-IoT/final-bot-iot-vqc-train_seed42/plain-epoch023.pt
# 	epoch 24 step 20 (1%) loss=0.2568 elapsed=3s eta=296s
# 	epoch 24 step 40 (2%) loss=0.4031 elapsed=6s eta=291s
# 	epoch 24 step 60 (3%) loss=0.4965 elapsed=8s eta=287s
# 	epoch 24 step 80 (4%) loss=0.4762 elapsed=11s eta=283s
# 	epoch 24 step 100 (5%) loss=0.4125 elapsed=14s eta=280s
# 	epoch 24 step 120 (6%) loss=0.4814 elapsed=17s eta=279s
# 	epoch 24 step 140 (7%) loss=0.3856 elapsed=20s eta=276s
# 	epoch 24 step 160 (8%) loss=0.3997 elapsed=23s eta=274s
# 	epoch 24 step 180 (9%) loss=0.3549 elapsed=26s eta=272s
# 	epoch 24 step 200 (10%) loss=0.5038 elapsed=28s eta=269s
# 	epoch 24 step 220 (11%) loss=0.3494 elapsed=32s eta=269s
# 	epoch 24 step 240 (11%) loss=0.4285 elapsed=34s eta=266s
# 	epoch 24 step 260 (12%) loss=0.3164 elapsed=37s eta=263s
# 	epoch 24 step 280 (13%) loss=0.3682 elapsed=40s eta=260s
# 	epoch 24 step 300 (14%) loss=0.3990 elapsed=43s eta=257s
# 	epoch 24 step 320 (15%) loss=0.3666 elapsed=46s eta=254s
# 	epoch 24 step 340 (16%) loss=0.4010 elapsed=49s eta=251s
# 	epoch 24 step 360 (17%) loss=0.3800 elapsed=52s eta=248s
# 	epoch 24 step 380 (18%) loss=0.3399 elapsed=55s eta=246s
# 	epoch 24 step 400 (19%) loss=0.5404 elapsed=57s eta=243s
# 	epoch 24 step 420 (20%) loss=0.3518 elapsed=60s eta=240s
# 	epoch 24 step 440 (21%) loss=0.4108 elapsed=63s eta=237s
# 	epoch 24 step 460 (22%) loss=0.3569 elapsed=66s eta=234s
# 	epoch 24 step 480 (23%) loss=0.3933 elapsed=69s eta=231s
# 	epoch 24 step 500 (24%) loss=0.3930 elapsed=72s eta=228s
# 	epoch 24 step 520 (25%) loss=0.6039 elapsed=74s eta=225s
# 	epoch 24 step 540 (26%) loss=0.3800 elapsed=77s eta=222s
# 	epoch 24 step 560 (27%) loss=0.3145 elapsed=80s eta=219s
# 	epoch 24 step 580 (28%) loss=0.3559 elapsed=83s eta=217s
# 	epoch 24 step 600 (29%) loss=0.5261 elapsed=86s eta=213s
# 	epoch 24 step 620 (30%) loss=0.7167 elapsed=89s eta=211s
# 	epoch 24 step 640 (31%) loss=0.4008 elapsed=92s eta=208s
# 	epoch 24 step 660 (32%) loss=0.4394 elapsed=95s eta=205s
# 	epoch 24 step 680 (33%) loss=0.4977 elapsed=97s eta=202s
# 	epoch 24 step 700 (33%) loss=0.4474 elapsed=100s eta=199s
# 	epoch 24 step 720 (34%) loss=0.3829 elapsed=103s eta=196s
# 	epoch 24 step 740 (35%) loss=0.4373 elapsed=106s eta=193s
# 	epoch 24 step 760 (36%) loss=0.4741 elapsed=109s eta=190s
# 	epoch 24 step 780 (37%) loss=0.4091 elapsed=111s eta=187s
# 	epoch 24 step 800 (38%) loss=0.2986 elapsed=114s eta=185s
# 	epoch 24 step 820 (39%) loss=0.3181 elapsed=117s eta=182s
# 	epoch 24 step 840 (40%) loss=0.5123 elapsed=120s eta=179s
# 	epoch 24 step 860 (41%) loss=0.7095 elapsed=123s eta=177s
# 	epoch 24 step 880 (42%) loss=0.3907 elapsed=127s eta=174s
# 	epoch 24 step 900 (43%) loss=0.3488 elapsed=129s eta=171s
# 	epoch 24 step 920 (44%) loss=0.3560 elapsed=132s eta=168s
# 	epoch 24 step 940 (45%) loss=0.6518 elapsed=135s eta=166s
# 	epoch 24 step 960 (46%) loss=0.6216 elapsed=138s eta=163s
# 	epoch 24 step 980 (47%) loss=0.3522 elapsed=141s eta=160s
# 	epoch 24 step 1000 (48%) loss=0.5677 elapsed=144s eta=157s
# 	epoch 24 step 1020 (49%) loss=0.4001 elapsed=147s eta=155s
# 	epoch 24 step 1040 (50%) loss=0.4988 elapsed=150s eta=152s
# 	epoch 24 step 1060 (51%) loss=0.4061 elapsed=153s eta=149s
# 	epoch 24 step 1080 (52%) loss=0.4756 elapsed=156s eta=146s
# 	epoch 24 step 1100 (53%) loss=0.3826 elapsed=159s eta=143s
# 	epoch 24 step 1120 (54%) loss=0.3899 elapsed=162s eta=140s
# 	epoch 24 step 1140 (55%) loss=0.4626 elapsed=165s eta=137s
# 	epoch 24 step 1160 (55%) loss=0.5160 elapsed=168s eta=135s
# 	epoch 24 step 1180 (56%) loss=0.3283 elapsed=170s eta=132s
# 	epoch 24 step 1200 (57%) loss=0.4062 elapsed=173s eta=129s
# 	epoch 24 step 1220 (58%) loss=0.3636 elapsed=176s eta=126s
# 	epoch 24 step 1240 (59%) loss=0.4230 elapsed=179s eta=123s
# 	epoch 24 step 1260 (60%) loss=0.3687 elapsed=182s eta=120s
# 	epoch 24 step 1280 (61%) loss=0.3717 elapsed=185s eta=117s
# 	epoch 24 step 1300 (62%) loss=0.3443 elapsed=187s eta=114s
# 	epoch 24 step 1320 (63%) loss=0.4638 elapsed=190s eta=111s
# 	epoch 24 step 1340 (64%) loss=0.4185 elapsed=193s eta=108s
# 	epoch 24 step 1360 (65%) loss=0.3275 elapsed=196s eta=105s
# 	epoch 24 step 1380 (66%) loss=0.3900 elapsed=199s eta=102s
# 	epoch 24 step 1400 (67%) loss=0.5239 elapsed=201s eta=99s
# 	epoch 24 step 1420 (68%) loss=0.3502 elapsed=205s eta=97s
# 	epoch 24 step 1440 (69%) loss=0.4366 elapsed=208s eta=94s
# 	epoch 24 step 1460 (70%) loss=0.3658 elapsed=210s eta=91s
# 	epoch 24 step 1480 (71%) loss=0.4058 elapsed=213s eta=88s
# 	epoch 24 step 1500 (72%) loss=0.4602 elapsed=216s eta=85s
# 	epoch 24 step 1520 (73%) loss=0.3161 elapsed=219s eta=82s
# 	epoch 24 step 1540 (74%) loss=0.3337 elapsed=222s eta=79s
# 	epoch 24 step 1560 (75%) loss=0.6649 elapsed=225s eta=77s
# 	epoch 24 step 1580 (76%) loss=0.5140 elapsed=228s eta=74s
# 	epoch 24 step 1600 (77%) loss=0.3724 elapsed=230s eta=71s
# 	epoch 24 step 1620 (77%) loss=0.4650 elapsed=233s eta=68s
# 	epoch 24 step 1640 (78%) loss=0.4850 elapsed=236s eta=65s
# 	epoch 24 step 1660 (79%) loss=0.3777 elapsed=239s eta=62s
# 	epoch 24 step 1680 (80%) loss=0.3926 elapsed=242s eta=59s
# 	epoch 24 step 1700 (81%) loss=0.3442 elapsed=245s eta=56s
# 	epoch 24 step 1720 (82%) loss=0.5022 elapsed=248s eta=54s
# 	epoch 24 step 1740 (83%) loss=0.3726 elapsed=251s eta=51s
# 	epoch 24 step 1760 (84%) loss=0.3631 elapsed=254s eta=48s
# 	epoch 24 step 1780 (85%) loss=0.3566 elapsed=257s eta=45s
# 	epoch 24 step 1800 (86%) loss=0.4355 elapsed=259s eta=42s
# 	epoch 24 step 1820 (87%) loss=0.3415 elapsed=262s eta=39s
# 	epoch 24 step 1840 (88%) loss=0.3749 elapsed=265s eta=36s
# 	epoch 24 step 1860 (89%) loss=0.3969 elapsed=268s eta=33s
# 	epoch 24 step 1880 (90%) loss=0.4850 elapsed=271s eta=30s
# 	epoch 24 step 1900 (91%) loss=0.3203 elapsed=274s eta=28s
# 	epoch 24 step 1920 (92%) loss=0.3872 elapsed=276s eta=25s
# 	epoch 24 step 1940 (93%) loss=0.4359 elapsed=279s eta=22s
# 	epoch 24 step 1960 (94%) loss=0.5109 elapsed=282s eta=19s
# 	epoch 24 step 1980 (95%) loss=0.5012 elapsed=285s eta=16s
# 	epoch 24 step 2000 (96%) loss=0.4818 elapsed=288s eta=13s
# 	epoch 24 step 2020 (97%) loss=0.3553 elapsed=291s eta=10s
# 	epoch 24 step 2040 (98%) loss=0.4045 elapsed=293s eta=7s
# 	epoch 24 step 2060 (98%) loss=0.2769 elapsed=296s eta=5s
# 	epoch 24 step 2080 (99%) loss=0.3974 elapsed=299s eta=2s
# epoch 24/50 | time 300.8s | loss 0.4203 | L_CE 0.4203 | grad_var 2.42e-02 | val_loss 0.6405 | lr 5.67e-03 | peak_mem=49MB | best=0.6194@ep19 | bad=5/5
#   saved checkpoint: artifacts/BoT-IoT/final-bot-iot-vqc-train_seed42/plain-epoch024.pt
# early stopping at epoch 24: no val_loss improvement for 5 epochs (best=0.6194 @ epoch 19)
# restored best plain-VQC weights from epoch 19 (val_loss=0.6194)
#
# epochs_ran=24 | best_epoch=19 | stopped_early=True | stop_reason=early_stopping

# %% [markdown]
# ## Prototypes
#
# Class-mean prototypes are computed post-hoc after CE training for later Algo-3 / geometry compare.

# %%
# post-hoc class-mean prototypes under frozen CE theta
proto_bank = PrototypeBank(classes=range(num_classes))
prototypes = proto_bank.compute(
    theta_star, X_train_angles, y_train, forward_circuit,
    device=device, batch_size=batch_size,
)

# %%
proto_df = pd.DataFrame(prototype_summary(prototypes, class_names))
proto_df
# Out:
#             class  dim  trace
# 0            DDoS   32    1.0
# 1             DoS   32    1.0
# 2          Normal   32    1.0
# 3  Reconnaissance   32    1.0

# %%
# save prototypes (all-in-one checkpoint)
out_dir = Path("final_notebooks") / "final_artifacts"
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_path = out_dir / f"{NOTEBOOK_NAME}-checkpoint.pt"
torch.save(
    {
        "theta": theta_star.detach().cpu(),
        "head_state_dict": head.state_dict(),
        "prototypes": {k: v.detach().cpu() for k, v in prototypes.items()},
        "train_mode": "CE-only",

        # rebuild / inference meta
        "class_names": list(class_names),
        "num_classes": num_classes,
        "num_qubits": num_qubits,
        "num_layers": num_layers,
        "noise_rate": noise_rate,

        # FROZEN feature + angle pipeline (must match train)
        "feature_cols": list(FEATURE_COLS),
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "target_col": target_col,
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "scaler": scaler,                    # StandardScaler fitted on full train
        "pca": pca,                          # PCA fitted on scaled full train (or None)
        "k95": int(k95),
        "angle_x_min": np.asarray(x_min),    # on pca space if USE_PCA else scaled space
        "angle_x_max": np.asarray(x_max),
        "angle_min": 0.0,
        "angle_max": float(np.pi),
    },
    ckpt_path,
)
print("published:", ckpt_path.resolve())
# Out:
# published: /home/lawun330/Desktop/quantum-sentinel/final_notebooks/final_artifacts/final-bot-iot-vqc-train-checkpoint.pt

# %% [markdown]
# ## Visualization

# %%
# plots
epochs_x = range(1, len(history["loss"]) + 1)

fig, axes = plt.subplots(1, 3, figsize=(14, 4))

# total loss (= CE for this baseline)
axes[0].plot(epochs_x, history["loss"], marker="o")
axes[0].set_title("Total loss ($L_{CE}$)")
axes[0].set_xlabel("Epoch")

# CE curve
axes[1].plot(epochs_x, history["loss"], marker=None, label=r"$L$")
axes[1].plot(epochs_x, history["L_CE"], "--", label=r"$L_{CE}$")
axes[1].set_title(r"$L = L_{CE}$ (CE-only)")
axes[1].legend(fontsize=8)

# grad var
axes[2].plot(epochs_x, history["grad_var"], marker="o", color="tab:orange")
axes[2].axhline(1e-6, color="red", linestyle="--", label="plateau thr")  # or BARREN_PLATEAU_VAR_THRESHOLD
axes[2].set_title("Gradient variance")
axes[2].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Logging

# %%
# write log (final)
log_path = write_history_log(
    history,
    NOTEBOOK_NAME,
    extra={
        ## data
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "dataset": dataset,
        "feature_cols": FEATURE_COLS,
        "target_col": target_col,
        "n_train": len(X_train),
        "class_names": list(class_names),
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "num_qubits": num_qubits,
        "k95": int(k95),

        # algo: CE-only train
        "train_mode": "CE-only",
        "epochs": epochs,
        "batch_size": batch_size,
        "lr": lr,
        "use_lr_schedule": True,

        ## quantum model
        "noise_rate": noise_rate,
        "num_layers": num_layers,
        "num_classes": num_classes,

        ## training
        "train_total_sec": float(sum(history["epoch_sec"])) if history.get("epoch_sec") else None,
        "loss_last": float(history["loss"][-1]) if history["loss"] else None,
        "barren_plateau_var": barren_plateau_var,
        "barren_plateau_any": bool(
            any(g < barren_plateau_var for g in history["grad_var"])
        ) if history.get("grad_var") else None,
        "seed": SEED,
        "early_stopping": early_stopping,
        "patience": patience,
        "best_epoch": history.get("best_epoch"),
        "best_score": history.get("best_score"),
        "stopped_early": history.get("stopped_early"),
        "epochs_ran": history.get("epochs_ran"),
        "stop_reason": history.get("stop_reason"),
        "interrupted": history.get("interrupted"),
        "checkpoint_dir": str(ckpt_dir),
    },
    log_dir="logs",
)
print(f"wrote {log_path.resolve()}")
# Out:
# wrote /home/lawun330/Desktop/quantum-sentinel/logs/final-bot-iot-vqc-train.log
