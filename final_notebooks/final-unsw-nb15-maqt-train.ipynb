# %% [markdown]
# # MAQT Prototypes with FROZEN Features: UNSW-NB15
# ## All Samples | ~80,000 Train | Batch Size 64
# ## Tuned Lambdas ($\lambda_1=0.66$ and $\lambda_2=0.33$)
# ## 50 Epochs (Early Stopping with Patience = 5) | LR Decay (Start at 0.01)
# ## Target (y) = "label_multiclass" | Data Reupload = 2

# %% [markdown]
# ## Setup

# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import torch
from pennylane import numpy as np
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from scripts.circuit import build_forward_circuit, create_quantum_device
from scripts.constants import (
    BARREN_PLATEAU_VAR_THRESHOLD,
    DEFAULT_NOISE_RATE,
)
from scripts.data import (
    greedy_dpp_sample,
    load_split,
    plot_class_balance_pie,
    plot_dataset_and_sampling_analysis,
    to_angles,
)
from scripts.gradient import gradient_variance_probe
from scripts.logging import write_history_log
from scripts.memory import is_oom_error, run_batched_safely, safe_empty_cache
from scripts.prototypes import prototype_summary
from scripts.theory import verify_fidelity_convention
from scripts.train import train_maqt
from scripts.utils import get_torch_device, to_np_y

# %%
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available?: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA device name: {torch.cuda.get_device_name(0)}")
    print(f"Current CUDA device index: {torch.cuda.current_device()}")
# Out:
# PyTorch version: 2.12.1+cu126
# CUDA available?: True
# CUDA device name: NVIDIA GeForce GTX 1060
# Current CUDA device index: 0

# %% [markdown]
# ## Config

# %%
NOTEBOOK_NAME = "final-unsw-nb15-maqt-train"

dataset = "UNSW-NB15"
target_col = "label_multiclass"
data_path = f"data/FROZEN/{dataset}"
frozen_feat_path = "team-artifacts/teamC_week3_FROZEN_handoff.json"

SEED = 42

# %%
check = verify_fidelity_convention(dim=4, n_trials=30, seed=SEED)
print("Fidelity-convention self-check PASSED:", check)
# Out:
# Fidelity-convention self-check PASSED: {'max_pairwise_disagreement': 0.0, 'max_fvg_violation': 0.0}

# %% [markdown]
# ## Load Team C's FROZEN Features

# %%
handoff = json.loads(Path(frozen_feat_path).read_text())
FEATURE_COLS = list(handoff["frozen_subsets"][dataset]["features"])
print(f"Team C selector: {handoff['frozen_subsets'][dataset]['selector']}")
print(f"k={len(FEATURE_COLS)} features: {FEATURE_COLS}")
# Out:
# Team C selector: RF
# k=10 features: ['duration', 'n_pkts_total', 'n_bytes_total', 'src_bytes', 'dst_bytes', 'rate', 'rate_src', 'rate_dst', 'pkt_size_mean', 'iat']

# %% [markdown]
# ## Load Team A's FROZEN Dataset

# %%
# load all data
X_train_full, y_train_full, class_names, df_train = load_split(
    data_path, "train", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_cal_full, y_cal_full, _, df_cal = load_split(
    data_path, "calibration", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_test_full, y_test_full, _, df_test = load_split(
    data_path, "test", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_zero_full, y_zero_full, _, df_zero = load_split(
    data_path, "zeroday", target_col, csv=True, selected_cols=FEATURE_COLS, return_df = True
)

# check shape
print(f"train   : {X_train_full.shape, y_train_full.shape}\n\
cal     : {X_cal_full.shape, y_cal_full.shape}\n\
test    : {X_test_full.shape, y_test_full.shape}\n\
zero    : {X_zero_full.shape, y_zero_full.shape}\n\
classes : {class_names}\n"
)

df_train.head(3)
# Out:
# train   : ((81215, 10), (81215,))
# cal     : ((10112, 10), (10112,))
# test    : ((10086, 10), (10086,))
# zero    : ((1216, 10), (1216,))
# classes : ['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic', 'Normal', 'Reconnaissance']
#    duration  n_pkts_total  n_bytes_total  src_bytes  dst_bytes      rate  \
# 0  1.731948      2.945547       1.419156   0.964095   2.766445  0.342217
# 1 -0.257683     -0.791538      -0.362735  -0.072596  -0.896015 -0.164247
# 2 -0.656785     -1.723042      -1.741032  -1.483457  -2.674885  1.885314
#
#    rate_src  rate_dst  pkt_size_mean       iat label_multiclass
# 0 -0.201876  0.996449      -0.396060 -0.031287         Exploits
# 1 -0.013491 -0.447216       0.719197  0.116867           Normal
# 2  1.819467 -1.827915      -1.168109 -1.025566          Generic

# %% [markdown]
# ## EDA (Before Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train_full, class_names,
    title=f"train (n={len(to_np_y(y_train_full))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 8

# %% [markdown]
# ## Scaling

# %%
# fit scaler on full train (raw); transform elsewhere via to_angles()
scaler = StandardScaler()
X_train_full_scaled = scaler.fit_transform(X_train_full)
print(f"scaled full train: {X_train_full_scaled.shape}")
# Out:
# scaled full train: (81215, 10)

# %% [markdown]
# ## PCA (Optional)

# %%
USE_PCA = True   # set to False to skip PCA
TARGET_VARIANCE = 0.95

# %%
if USE_PCA:
    pca_full = PCA(random_state=SEED).fit(X_train_full_scaled)
    ratios = pca_full.explained_variance_ratio_
    cum = np.cumsum(ratios)
    n_feat = len(ratios)

    print(f"features (raw dim): {n_feat}")
    print("explained_variance_ratio_:", np.round(ratios, 4))
    print("cumulative:               ", np.round(cum, 4))
    for k in range(1, n_feat + 1):
        print(f"first {k} PCs keep {cum[k - 1]*100:.2f}% variance")

    # smallest k with >= target variance
    k95 = int(np.searchsorted(cum, TARGET_VARIANCE) + 1)
    k95 = min(k95, len(cum))  # safety
    print(f"components needed for >={TARGET_VARIANCE*100}% variance: {k95}")

    fig, ax = plt.subplots(1, 1, figsize=(8, 5))
    ax.bar(range(1, n_feat + 1), ratios, color="slateblue", alpha=0.7, label="per-PC")
    ax.plot(range(1, n_feat + 1), cum, marker="o", color="darkblue", label="cumulative")
    ax.axhline(TARGET_VARIANCE, color="red", linestyle="--", label=f"Target({TARGET_VARIANCE*100}%)")
    ax.axvline(k95, color="green", linestyle=":", label=f"k={k95}")
    ax.set_xlabel("PCA component")
    ax.set_ylabel("explained variance ratio")
    ax.set_title("PCA explained feature variance")
    ax.legend()
    plt.tight_layout()
    plt.show()

    pca = PCA(n_components=k95, random_state=SEED)
    X_train_full_feat = pca.fit_transform(X_train_full_scaled)
else:
    pca = None
    k95 = X_train_full_scaled.shape[1]
    X_train_full_feat = X_train_full_scaled

# angle bounds from full train feature space (pca or scaled)
x_min, x_max = X_train_full_feat.min(0), X_train_full_feat.max(0)
print(f"feature dim for angles: {X_train_full_feat.shape[1]} | USE_PCA={USE_PCA}")
# Out:
# features (raw dim): 10
# explained_variance_ratio_: [4.114e-01 3.238e-01 1.793e-01 5.100e-02 2.120e-02 8.700e-03 3.700e-03
#  7.000e-04 2.000e-04 0.000e+00]
# cumulative:                [0.4114 0.7353 0.9145 0.9655 0.9868 0.9955 0.9992 0.9998 1.     1.    ]
# first 1 PCs keep 41.14% variance
# first 2 PCs keep 73.53% variance
# first 3 PCs keep 91.45% variance
# first 4 PCs keep 96.55% variance
# first 5 PCs keep 98.68% variance
# first 6 PCs keep 99.55% variance
# first 7 PCs keep 99.92% variance
# first 8 PCs keep 99.98% variance
# first 9 PCs keep 100.00% variance
# first 10 PCs keep 100.00% variance
# components needed for >=95.0% variance: 4
# feature dim for angles: 4 | USE_PCA=True

# %% [markdown]
# ## Data Subset (Optional)

# %%
SUBSET = False   # set to False for the full dataset
PER_CLASS_CAP = 300

# %%
# compare sampling strategies on RAW full train, then apply DPP coreset
if SUBSET:
    plot_dataset_and_sampling_analysis(
        X_train_full,
        y_train_full,
        per_class_cap=PER_CLASS_CAP,
        class_names=class_names,
        seed=SEED,
    )

    print(f"\nRunning representative DPP coreset sampling (cap={PER_CLASS_CAP})...")
    X_train, y_train = greedy_dpp_sample(
        X_train_full, y_train_full, per_class_cap=PER_CLASS_CAP, seed=SEED
    )
    print(f"Coreset selected: {X_train.shape[0]} samples.")
else:
    X_train, y_train = X_train_full, y_train_full
    print(f"using full train (no subset): {X_train.shape[0]} samples")

print(f"train raw: {X_train.shape, y_train.shape} | SUBSET={SUBSET} | cap={PER_CLASS_CAP if SUBSET else 'all'}")
# Out:
# using full train (no subset): 81215 samples
# train raw: ((81215, 10), (81215,)) | SUBSET=False | cap=all

# %% [markdown]
# ## EDA (After Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train, class_names,
    title=f"train (n={len(to_np_y(y_train))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 8

# %% [markdown]
# ## Mapping Features $\rightarrow$ [0, $\pi$]

# %%
# raw -> scale -> optional pca -> [0, pi] using bounds from full train
X_train_angles_all = to_angles(
    X_train, scaler, x_min, x_max, pca=pca if USE_PCA else None, angle_max=np.pi
)

# seeded stratified holdout from train for early stopping (cal/test untouched)
VAL_FRAC = 0.1
_y_all = y_train
idx = np.arange(len(X_train_angles_all))
idx_fit, idx_val = train_test_split(
    idx, test_size=VAL_FRAC, stratify=_y_all, random_state=SEED,
)
X_train_angles, y_train = X_train_angles_all[idx_fit], _y_all[idx_fit]
X_val_angles, y_val = X_train_angles_all[idx_val], _y_all[idx_val]
print(
    f"angles fit: {X_train_angles.shape} | val: {X_val_angles.shape} | "
    f"VAL_FRAC={VAL_FRAC} | USE_PCA={USE_PCA} | SUBSET={SUBSET}"
)

fig, ax1 = plt.subplots(1, 1, figsize=(7, 4))
ax1.hist(X_train_angles.flatten(), bins=50, color="teal", alpha=0.8)
ax1.set_xlabel("angle (radians)")
ax1.set_title("Angle-encoded train (fit) feature distribution")
plt.tight_layout()
plt.show()
# Out:
# angles fit: (73093, 4) | val: (8122, 4) | VAL_FRAC=0.1 | USE_PCA=True | SUBSET=False

# %% [markdown]
# ## Quantum Circuit: Angle Encoding, Data Reuploading, and Adding Noise
#
# $$
# x\xrightarrow[\text{encode}]{\phi(x)}\ket{\psi(x)}\xrightarrow[\text{variational}]{U(\theta)}\ket{\Phi(x)}\xrightarrow{\Lambda_p}\rho(x)
# $$
# - $x$: classical data
# - $\phi(x)$: `qp.AngleEmbedding()`
# - $\ket{\psi(x)}$: quantum state after encoding
# - $U(\theta)$: `qp.StronglyEntanglingLayers()`
# - $\ket{\Phi(x)}$: quantum state after variational transform
# - $\rho(x)=\Lambda_p(\ket{\Phi(x)}\bra{\Phi(x)})$: standard depolarization channel to model NISQ noise

# %%
num_qubits = int(k95)           # pca comps if USE_PCA; else scaled feature dim
num_layers = 2                  # reupload same classical data
noise_rate = DEFAULT_NOISE_RATE
print(f"num_qubits={num_qubits} (USE_PCA={USE_PCA})")
# Out:
# num_qubits=4 (USE_PCA=True)

# %%
# initialize devices
device = get_torch_device()
dev = create_quantum_device(num_qubits) # or dev = qp.device("default.mixed", wires=num_qubits)

# define circuit
forward_circuit = build_forward_circuit(dev, num_qubits, num_layers, noise_rate=noise_rate)

# %% [markdown]
# ## Gradient Variance Probe

# %%
barren_plateau_var = BARREN_PLATEAU_VAR_THRESHOLD
n_trials = 5

safe_empty_cache()

# probe on CPU (recommended)
x_probe = X_train_angles[:1]

try:
    grad_var, grad_samples = gradient_variance_probe(
        forward_circuit, x_probe, num_qubits, num_layers,
        n_trials=n_trials,
        device=torch.device("cpu"),
    )

    print(f"pre-train grad var = {grad_var:.2e} (thr={barren_plateau_var:.0e})")
    if grad_var < barren_plateau_var:
        print("warning: possible barren plateau architecture")

    plt.figure(figsize=(6, 4)); plt.hist(grad_samples, bins=15, color="darkcyan", alpha=0.8)
    plt.title(f"Gradient-variance probe (var={grad_var:.2e})"); plt.tight_layout(); plt.show()

except RuntimeError as e:
    if is_oom_error(e):
        print("\t[OOM] barren-plateau probe skipped (non-critical diagnostic).")
        safe_empty_cache()
    else:
        raise
# Out:
# pre-train grad var = 1.58e-07 (thr=1e-06)
# warning: possible barren plateau architecture

# %% [markdown]
# ## Training
#
# $$
# L = L_{CE} + \lambda_1*L_{intra} + \lambda_2*L_{inter}
# $$
#
# Minimizing:
# - $L_{CE}$ adjusts $\theta$ for better class predictions.
# - $L_{intra}$ pulls each sample toward its class prototype
# - $L_{inter}$ pushs different-class prototypes apart (maximize trace distance)

# %%
epochs = 50
batch_size = 64
lr = 0.01
lambda1 = 0.66
lambda2 = 0.33
early_stopping = True
patience = 5
min_delta = 0.001

out_dir = Path("artifacts") / dataset
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_dir = out_dir / f"{NOTEBOOK_NAME}_seed{SEED}"
latest_ckpt = ckpt_dir / "maqt-latest.pt"
resume_from = latest_ckpt if latest_ckpt.exists() else None

print(f"checkpoint_dir: {ckpt_dir}")
print(f"resume_from: {resume_from}")
# Out:
# checkpoint_dir: artifacts/UNSW-NB15/final-unsw-nb15-maqt-train_seed42
# resume_from: None

# %%
torch.manual_seed(SEED)

result = run_batched_safely(
    train_maqt,
    X_train_angles,
    y_train,
    n_classes=num_classes,
    n_qubits=num_qubits,
    n_layers=num_layers,
    forward_circuit=forward_circuit,
    device=device,
    epochs=epochs,
    lr=lr,
    use_lr_schedule=True,  # auto LR
    batch_size=batch_size,
    min_batch=2,
    label="train_maqt",
    lambda1_max=lambda1,
    lambda2_max=lambda2,
    use_weighted_sampler=True,
    seed=SEED,
    early_stopping=early_stopping,
    patience=patience,
    min_delta=min_delta,
    X_val=X_val_angles,
    y_val=y_val,
    checkpoint_dir=ckpt_dir,
    save_every_epoch=True,
    resume_from=resume_from,
    reset_early_stopping_on_resume=True,
    heartbeat_every_steps=100,  # pass None to less verbose
    notebook_name=NOTEBOOK_NAME,
    log_dir=ckpt_dir,
)

if result is None:
    raise RuntimeError("train_maqt failed even at min_batch (OOM)")

theta, head, prototypes, ema_protos, history = result
theta_star = theta
classifier_head = head
safe_empty_cache()
print(
    "\n"
    f"epochs_ran={history.get('epochs_ran')} | "
    f"best_epoch={history.get('best_epoch')} | "
    f"stopped_early={history.get('stopped_early')} | "
    f"stop_reason={history.get('stop_reason')}"
)
# Out:
# 	epoch 1 step 100 (9%) loss=2.0344 elapsed=197s eta=2058s
# 	epoch 1 step 200 (18%) loss=1.9675 elapsed=399s eta=1878s
# 	epoch 1 step 300 (26%) loss=1.8743 elapsed=478s eta=1342s
# 	epoch 1 step 400 (35%) loss=1.7201 elapsed=557s eta=1034s
# 	epoch 1 step 500 (44%) loss=1.8528 elapsed=633s eta=813s
# 	epoch 1 step 600 (53%) loss=1.7574 elapsed=722s eta=652s
# 	epoch 1 step 700 (61%) loss=1.7606 elapsed=796s eta=503s
# 	epoch 1 step 800 (70%) loss=1.8520 elapsed=870s eta=372s
# 	epoch 1 step 900 (79%) loss=1.7681 elapsed=944s eta=254s
# 	epoch 1 step 1000 (88%) loss=1.7585 elapsed=1018s eta=145s
# 	epoch 1 step 1100 (96%) loss=1.8009 elapsed=1093s eta=42s
# epoch  1/50 | time 1123.8s | loss 1.8143 | L_CE 1.8143 | L_intra 0.1486 | L_inter -0.4533 | grad_var 2.28e-03 | intra_fid 0.851 | inter_TD 0.267 | val_loss 1.6626 | lr 1.00e-02 | peak_mem=25MB | best=1.6626@ep1 | bad=0/5
#   saved checkpoint: artifacts/UNSW-NB15/final-unsw-nb15-maqt-train_seed42/maqt-epoch001.pt
# 	epoch 2 step 100 (9%) loss=1.7369 elapsed=75s eta=777s
# 	epoch 2 step 200 (18%) loss=1.5725 elapsed=150s eta=707s
# 	epoch 2 step 300 (26%) loss=1.7732 elapsed=225s eta=630s
# 	epoch 2 step 400 (35%) loss=1.7455 elapsed=299s eta=554s
# 	epoch 2 step 500 (44%) loss=1.6395 elapsed=373s eta=480s
# 	epoch 2 step 600 (53%) loss=1.6372 elapsed=448s eta=405s
# 	epoch 2 step 700 (61%) loss=1.6575 elapsed=524s eta=331s
# 	epoch 2 step 800 (70%) loss=1.4675 elapsed=599s eta=256s
# 	epoch 2 step 900 (79%) loss=1.7029 elapsed=674s eta=181s
# 	epoch 2 step 1000 (88%) loss=1.5790 elapsed=748s eta=106s
# 	epoch 2 step 1100 (96%) loss=1.7365 elapsed=823s eta=31s
# epoch  2/50 | time 855.5s | loss 1.6688 | L_CE 1.6744 | L_intra 0.1558 | L_inter -0.4820 | grad_var 7.27e-03 | intra_fid 0.844 | inter_TD 0.243 | val_loss 1.5962 | lr 9.99e-03 | peak_mem=25MB | best=1.5962@ep2 | bad=0/5
#   saved checkpoint: artifacts/UNSW-NB15/final-unsw-nb15-maqt-train_seed42/maqt-epoch002.pt
# 	epoch 3 step 100 (9%) loss=1.5812 elapsed=75s eta=784s
# 	epoch 3 step 200 (18%) loss=1.6688 elapsed=151s eta=711s
# 	epoch 3 step 300 (26%) loss=1.5704 elapsed=227s eta=638s
# 	epoch 3 step 400 (35%) loss=1.5629 elapsed=303s eta=563s
# 	epoch 3 step 500 (44%) loss=1.7394 elapsed=380s eta=487s
# 	epoch 3 step 600 (53%) loss=1.6052 elapsed=454s eta=411s
# 	epoch 3 step 700 (61%) loss=1.4449 elapsed=529s eta=334s
# 	epoch 3 step 800 (70%) loss=1.7588 elapsed=604s eta=258s
# 	epoch 3 step 900 (79%) loss=1.6451 elapsed=679s eta=183s
# 	epoch 3 step 1000 (88%) loss=1.6964 elapsed=753s eta=107s
# 	epoch 3 step 1100 (96%) loss=1.6273 elapsed=829s eta=32s
# epoch  3/50 | time 860.0s | loss 1.6244 | L_CE 1.6356 | L_intra 0.1480 | L_inter -0.4669 | grad_var 1.27e-02 | intra_fid 0.852 | inter_TD 0.254 | val_loss 1.5915 | lr 9.96e-03 | peak_mem=25MB | best=1.5915@ep3 | bad=0/5
#   saved checkpoint: artifacts/UNSW-NB15/final-unsw-nb15-maqt-train_seed42/maqt-epoch003.pt
# 	epoch 4 step 100 (9%) loss=1.5482 elapsed=74s eta=774s
# 	epoch 4 step 200 (18%) loss=1.6314 elapsed=149s eta=701s
# 	epoch 4 step 300 (26%) loss=1.7105 elapsed=224s eta=628s
# 	epoch 4 step 400 (35%) loss=1.4492 elapsed=298s eta=552s
# 	epoch 4 step 500 (44%) loss=1.6497 elapsed=373s eta=479s
# 	epoch 4 step 600 (53%) loss=1.6741 elapsed=448s eta=404s
# 	epoch 4 step 700 (61%) loss=1.8094 elapsed=522s eta=330s
# 	epoch 4 step 800 (70%) loss=1.6512 elapsed=597s eta=255s
# 	epoch 4 step 900 (79%) loss=1.7161 elapsed=672s eta=181s
# 	epoch 4 step 1000 (88%) loss=1.6677 elapsed=746s eta=106s
# 	epoch 4 step 1100 (96%) loss=1.3888 elapsed=821s eta=31s
# epoch  4/50 | time 852.3s | loss 1.5998 | L_CE 1.6167 | L_intra 0.1447 | L_inter -0.4602 | grad_var 1.73e-02 | intra_fid 0.855 | inter_TD 0.251 | val_loss 1.5087 | lr 9.91e-03 | peak_mem=25MB | best=1.5087@ep4 | bad=0/5
#   saved checkpoint: artifacts/UNSW-NB15/final-unsw-nb15-maqt-train_seed42/maqt-epoch004.pt
# 	epoch 5 step 100 (9%) loss=1.6038 elapsed=75s eta=781s
# 	epoch 5 step 200 (18%) loss=1.5711 elapsed=150s eta=705s
# 	epoch 5 step 300 (26%) loss=1.6166 elapsed=224s eta=629s
# 	epoch 5 step 400 (35%) loss=1.4914 elapsed=298s eta=553s
# 	epoch 5 step 500 (44%) loss=1.5488 elapsed=373s eta=479s
# 	epoch 5 step 600 (53%) loss=1.4488 elapsed=447s eta=404s
# 	epoch 5 step 700 (61%) loss=1.6387 elapsed=521s eta=329s
# 	epoch 5 step 800 (70%) loss=1.6129 elapsed=596s eta=255s
# 	epoch 5 step 900 (79%) loss=1.6500 elapsed=670s eta=180s
# 	epoch 5 step 1000 (88%) loss=1.7717 elapsed=744s eta=106s
# 	epoch 5 step 1100 (96%) loss=1.5516 elapsed=819s eta=31s
# epoch  5/50 | time 850.1s | loss 1.5818 | L_CE 1.6043 | L_intra 0.1423 | L_inter -0.4549 | grad_var 2.03e-02 | intra_fid 0.858 | inter_TD 0.271 | val_loss 1.5165 | lr 9.84e-03 | peak_mem=25MB | best=1.5087@ep4 | bad=1/5
#   saved checkpoint: artifacts/UNSW-NB15/final-unsw-nb15-maqt-train_seed42/maqt-epoch005.pt
# 	epoch 6 step 100 (9%) loss=1.4767 elapsed=74s eta=770s
# 	epoch 6 step 200 (18%) loss=1.5411 elapsed=148s eta=695s
# 	epoch 6 step 300 (26%) loss=1.6990 elapsed=222s eta=624s
# 	epoch 6 step 400 (35%) loss=1.4778 elapsed=297s eta=551s
# 	epoch 6 step 500 (44%) loss=1.5601 elapsed=371s eta=477s
# 	epoch 6 step 600 (53%) loss=1.6268 elapsed=445s eta=402s
# 	epoch 6 step 700 (61%) loss=1.5124 elapsed=520s eta=328s
# 	epoch 6 step 800 (70%) loss=1.5408 elapsed=594s eta=254s
# 	epoch 6 step 900 (79%) loss=1.5793 elapsed=669s eta=180s
# 	epoch 6 step 1000 (88%) loss=1.3801 elapsed=743s eta=106s
# 	epoch 6 step 1100 (96%) loss=1.4439 elapsed=818s eta=31s
# epoch  6/50 | time 848.8s | loss 1.5662 | L_CE 1.5943 | L_intra 0.1390 | L_inter -0.4486 | grad_var 2.34e-02 | intra_fid 0.861 | inter_TD 0.251 | val_loss 1.5225 | lr 9.76e-03 | peak_mem=25MB | best=1.5087@ep4 | bad=2/5
#   saved checkpoint: artifacts/UNSW-NB15/final-unsw-nb15-maqt-train_seed42/maqt-epoch006.pt
# 	epoch 7 step 100 (9%) loss=1.8127 elapsed=74s eta=776s
# 	epoch 7 step 200 (18%) loss=1.4721 elapsed=149s eta=700s
# 	epoch 7 step 300 (26%) loss=1.4926 elapsed=223s eta=625s
# 	epoch 7 step 400 (35%) loss=1.5684 elapsed=297s eta=551s
# 	epoch 7 step 500 (44%) loss=1.4483 elapsed=371s eta=477s
# 	epoch 7 step 600 (53%) loss=1.5501 elapsed=445s eta=402s
# 	epoch 7 step 700 (61%) loss=1.3559 elapsed=520s eta=328s
# 	epoch 7 step 800 (70%) loss=1.4727 elapsed=595s eta=254s
# 	epoch 7 step 900 (79%) loss=1.5507 elapsed=669s eta=180s
# 	epoch 7 step 1000 (88%) loss=1.5996 elapsed=743s eta=106s
# 	epoch 7 step 1100 (96%) loss=1.6112 elapsed=818s eta=31s
# epoch  7/50 | time 848.9s | loss 1.5526 | L_CE 1.5860 | L_intra 0.1369 | L_inter -0.4427 | grad_var 2.58e-02 | intra_fid 0.863 | inter_TD 0.228 | val_loss 1.6035 | lr 9.65e-03 | peak_mem=25MB | best=1.5087@ep4 | bad=3/5
#   saved checkpoint: artifacts/UNSW-NB15/final-unsw-nb15-maqt-train_seed42/maqt-epoch007.pt
# 	epoch 8 step 100 (9%) loss=1.6109 elapsed=75s eta=781s
# 	epoch 8 step 200 (18%) loss=1.5647 elapsed=150s eta=704s
# 	epoch 8 step 300 (26%) loss=1.7744 elapsed=224s eta=629s
# 	epoch 8 step 400 (35%) loss=1.5321 elapsed=298s eta=554s
# 	epoch 8 step 500 (44%) loss=1.5557 elapsed=373s eta=479s
# 	epoch 8 step 600 (53%) loss=1.6015 elapsed=448s eta=405s
# 	epoch 8 step 700 (61%) loss=1.5351 elapsed=522s eta=330s
# 	epoch 8 step 800 (70%) loss=1.6844 elapsed=597s eta=255s
# 	epoch 8 step 900 (79%) loss=1.4956 elapsed=671s eta=181s
# 	epoch 8 step 1000 (88%) loss=1.3991 elapsed=746s eta=106s
# 	epoch 8 step 1100 (96%) loss=1.4940 elapsed=820s eta=31s
# epoch  8/50 | time 851.6s | loss 1.5316 | L_CE 1.5702 | L_intra 0.1372 | L_inter -0.4416 | grad_var 2.69e-02 | intra_fid 0.863 | inter_TD 0.266 | val_loss 1.5104 | lr 9.53e-03 | peak_mem=25MB | best=1.5087@ep4 | bad=4/5
#   saved checkpoint: artifacts/UNSW-NB15/final-unsw-nb15-maqt-train_seed42/maqt-epoch008.pt
# 	epoch 9 step 100 (9%) loss=1.4513 elapsed=75s eta=779s
# 	epoch 9 step 200 (18%) loss=1.6384 elapsed=149s eta=703s
# 	epoch 9 step 300 (26%) loss=1.4074 elapsed=224s eta=627s
# 	epoch 9 step 400 (35%) loss=1.5633 elapsed=298s eta=552s
# 	epoch 9 step 500 (44%) loss=1.2796 elapsed=372s eta=478s
# 	epoch 9 step 600 (53%) loss=1.4176 elapsed=446s eta=403s
# 	epoch 9 step 700 (61%) loss=1.5042 elapsed=521s eta=329s
# 	epoch 9 step 800 (70%) loss=1.4501 elapsed=597s eta=255s
# 	epoch 9 step 900 (79%) loss=1.5631 elapsed=674s eta=181s
# 	epoch 9 step 1000 (88%) loss=1.6361 elapsed=748s eta=106s
# 	epoch 9 step 1100 (96%) loss=1.4100 elapsed=823s eta=31s
# epoch  9/50 | time 855.1s | loss 1.5230 | L_CE 1.5675 | L_intra 0.1357 | L_inter -0.4401 | grad_var 2.75e-02 | intra_fid 0.864 | inter_TD 0.254 | val_loss 1.5968 | lr 9.39e-03 | peak_mem=25MB | best=1.5087@ep4 | bad=5/5
#   saved checkpoint: artifacts/UNSW-NB15/final-unsw-nb15-maqt-train_seed42/maqt-epoch009.pt
# early stopping at epoch 9: no val_loss improvement for 5 epochs (best=1.5087 @ epoch 4)
# restored best MAQT weights from epoch 4 (val_loss=1.5087)
#
# epochs_ran=9 | best_epoch=4 | stopped_early=True | stop_reason=early_stopping

# %% [markdown]
# ## Prototypes

# %%
proto_df = pd.DataFrame(prototype_summary(prototypes, class_names))
proto_df
# Out:
#             class  dim     trace
# 0        Analysis   16  1.000001
# 1        Backdoor   16  1.000001
# 2             DoS   16  1.000001
# 3        Exploits   16  1.000001
# 4         Fuzzers   16  1.000001
# 5         Generic   16  1.000001
# 6          Normal   16  1.000001
# 7  Reconnaissance   16  1.000001

# %%
# save prototypes (all-in-one checkpoint)
out_dir = Path("artifacts") / dataset
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_path = out_dir / f"{NOTEBOOK_NAME}-checkpoint.pt"
torch.save(
    {
        "theta": theta_star.detach().cpu(),
        "head_state_dict": head.state_dict(),
        "prototypes": {k: v.detach().cpu() for k, v in prototypes.items()},

        # rebuild / inference meta
        "class_names": list(class_names),
        "num_classes": num_classes,
        "num_qubits": num_qubits,
        "num_layers": num_layers,
        "noise_rate": noise_rate,

        # FROZEN feature + angle pipeline (must match train)
        "feature_cols": list(FEATURE_COLS),
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "target_col": target_col,
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "scaler": scaler,                    # StandardScaler fitted on full train
        "pca": pca,                          # PCA fitted on scaled full train (or None)
        "k95": int(k95),
        "angle_x_min": np.asarray(x_min),    # on pca space if USE_PCA else scaled space
        "angle_x_max": np.asarray(x_max),
        "angle_min": 0.0,
        "angle_max": float(np.pi),
    },
    ckpt_path,
)
print("published:", ckpt_path.resolve())
# Out:
# published: /home/lawun330/Desktop/quantum-sentinel/artifacts/UNSW-NB15/final-unsw-nb15-maqt-train-checkpoint.pt

# %% [markdown]
# ## Visualization

# %%
# plots
epochs_x = range(1, len(history["loss"]) + 1)

fig, axes = plt.subplots(1, 3, figsize=(14, 4))

# total loss
axes[0].plot(epochs_x, history["loss"], marker="o")
axes[0].set_title("Total loss")
axes[0].set_xlabel("Epoch")

# decomposed (weighted like the objective)
axes[1].plot(epochs_x, history["loss"], marker=None, label=r"$L$")
axes[1].plot(epochs_x, history["L_CE"], "--", label=r"$L_{CE}$")
axes[1].plot(epochs_x, [lambda1 * v for v in history["L_intra"]], "--", label=r"$\lambda_1 L_{intra}$")
axes[1].plot(epochs_x, [lambda2 * v for v in history["L_inter"]], "--", label=r"$\lambda_2 L_{inter}$")
axes[1].set_title(r"$L = L_{CE}+\lambda_1 L_{intra}+\lambda_2 L_{inter}$")
axes[1].legend(fontsize=8)

# grad var
axes[2].plot(epochs_x, history["grad_var"], marker="o", color="tab:orange")
axes[2].axhline(1e-6, color="red", linestyle="--", label="plateau thr")  # or BARREN_PLATEAU_VAR_THRESHOLD
axes[2].set_title("Gradient variance")
axes[2].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Logging

# %%
# write log (final)
log_path = write_history_log(
    history,
    NOTEBOOK_NAME,
    extra={
        ## data
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "dataset": dataset,
        "feature_cols": FEATURE_COLS,
        "target_col": target_col,
        "n_train": len(X_train),
        "class_names": list(class_names),
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "num_qubits": num_qubits,
        "k95": int(k95),

        # algo 1: MAQT train
        "epochs": epochs,
        "batch_size": batch_size,
        "lr": lr,
        "lambda1": lambda1,
        "lambda2": lambda2,

        ## quantum model
        "noise_rate": noise_rate,
        "num_layers": num_layers,
        "num_classes": num_classes,

        ## training
        "train_total_sec": float(sum(history["epoch_sec"])) if history.get("epoch_sec") else None,
        "loss_last": float(history["loss"][-1]) if history["loss"] else None,
        "barren_plateau_var": barren_plateau_var,
        "barren_plateau_any": bool(
            any(g < barren_plateau_var for g in history["grad_var"])
        ) if history.get("grad_var") else None,
        "seed": SEED,
        "early_stopping": early_stopping,
        "patience": patience,
        "best_epoch": history.get("best_epoch"),
        "best_score": history.get("best_score"),
        "stopped_early": history.get("stopped_early"),
        "epochs_ran": history.get("epochs_ran"),
        "stop_reason": history.get("stop_reason"),
        "interrupted": history.get("interrupted"),
        "checkpoint_dir": str(ckpt_dir),
    },
    log_dir="logs",
)
print(f"wrote {log_path.resolve()}")
# Out:
# wrote /home/lawun330/Desktop/quantum-sentinel/logs/final-unsw-nb15-maqt-train.log
