# %% [markdown]
# # CE-only VQC with FROZEN Features: CICIoT2023
# ## DPP Cap (1000) | ~20,000 Train | 10% of Train as Val | Batch Size 64
# ## Fair MAQT ablation baseline (same data/circuit/hparams; CE loss only)
# ## 50 Epochs (Early Stopping with Patience = 5) | LR Decay (Start at 0.01)
# ## Target (y) = "label_multiclass" | Data Reupload = 2

# %% [markdown]
# ## Setup

# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import torch
from pennylane import numpy as np
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from scripts.circuit import build_forward_circuit, create_quantum_device
from scripts.constants import (
    BARREN_PLATEAU_VAR_THRESHOLD,
    DEFAULT_NOISE_RATE,
)
from scripts.data import (
    greedy_dpp_sample,
    load_split,
    plot_class_balance_pie,
    plot_dataset_and_sampling_analysis,
    to_angles,
)
from scripts.gradient import gradient_variance_probe
from scripts.logging import write_history_log
from scripts.memory import is_oom_error, run_batched_safely, safe_empty_cache
from scripts.prototypes import PrototypeBank, prototype_summary
from scripts.theory import verify_fidelity_convention
from scripts.train import train_plain_vqc
from scripts.utils import get_torch_device, to_np_y

# %%
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available?: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA device name: {torch.cuda.get_device_name(0)}")
    print(f"Current CUDA device index: {torch.cuda.current_device()}")
# Out:
# PyTorch version: 2.12.1+cu126
# CUDA available?: True
# CUDA device name: NVIDIA GeForce GTX 1060
# Current CUDA device index: 0

# %% [markdown]
# ## Config

# %%
NOTEBOOK_NAME = "final-ciciot2023-vqc-train"

dataset = "CICIoT2023"
target_col = "label_multiclass"
data_path = f"data/FROZEN/{dataset}"
frozen_feat_path = "team-artifacts/teamC_week3_FROZEN_handoff.json"

SEED = 42

# %%
check = verify_fidelity_convention(dim=4, n_trials=30, seed=SEED)
print("Fidelity-convention self-check PASSED:", check)
# Out:
# Fidelity-convention self-check PASSED: {'max_pairwise_disagreement': 0.0, 'max_fvg_violation': 0.0}

# %% [markdown]
# ## Load Team C's FROZEN Features

# %%
handoff = json.loads(Path(frozen_feat_path).read_text())
FEATURE_COLS = list(handoff["frozen_subsets"][dataset]["features"])
print(f"Team C selector: {handoff['frozen_subsets'][dataset]['selector']}")
print(f"k={len(FEATURE_COLS)} features: {FEATURE_COLS}")
# Out:
# Team C selector: MI
# k=10 features: ['duration', 'n_pkts_total', 'n_bytes_total', 'rate', 'pkt_size_min', 'pkt_size_max', 'pkt_size_mean', 'iat', 'protocol', 'conn_state']

# %% [markdown]
# ## Load Team A's FROZEN Dataset

# %%
# load all data
X_train_full, y_train_full, class_names, df_train = load_split(
    data_path, "train", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_cal_full, y_cal_full, _, df_cal = load_split(
    data_path,
    "calibration",
    target_col,
    csv=True,
    selected_cols=FEATURE_COLS,
    return_df=True,
)
X_test_full, y_test_full, _, df_test = load_split(
    data_path, "test", target_col, csv=True, selected_cols=FEATURE_COLS, return_df=True
)
X_zero_full, y_zero_full, _, df_zero = load_split(
    data_path,
    "zeroday",
    target_col,
    csv=True,
    selected_cols=FEATURE_COLS,
    return_df=True,
)

# check shape
print(
    f"train   : {X_train_full.shape, y_train_full.shape}\n\
cal     : {X_cal_full.shape, y_cal_full.shape}\n\
test    : {X_test_full.shape, y_test_full.shape}\n\
zero    : {X_zero_full.shape, y_zero_full.shape}\n\
classes : {class_names}\n"
)

df_train.head(3)
# Out:
# train   : ((151049, 10), (151049,))
# cal     : ((18883, 10), (18883,))
# test    : ((18883, 10), (18883,))
# zero    : ((10984, 10), (10984,))
# classes : ['Backdoor_Malware', 'BenignTraffic', 'BrowserHijacking', 'CommandInjection', 'DDoS-ACK_Fragmentation', 'DDoS-HTTP_Flood', 'DDoS-ICMP_Flood', 'DDoS-ICMP_Fragmentation', 'DDoS-PSHACK_Flood', 'DDoS-RSTFINFlood', 'DDoS-SYN_Flood', 'DDoS-SlowLoris', 'DDoS-SynonymousIP_Flood', 'DDoS-TCP_Flood', 'DDoS-UDP_Flood', 'DDoS-UDP_Fragmentation', 'DNS_Spoofing', 'DictionaryBruteForce', 'DoS-HTTP_Flood', 'DoS-SYN_Flood', 'DoS-TCP_Flood', 'DoS-UDP_Flood', 'MITM-ArpSpoofing', 'Recon-HostDiscovery', 'Recon-OSScan', 'Recon-PingSweep', 'Recon-PortScan', 'SqlInjection', 'Uploading_Attack', 'VulnerabilityScan', 'XSS']
#     duration  n_pkts_total  n_bytes_total      rate  pkt_size_min  \
# 0   0.114311      0.627152       0.005499 -0.306870      0.000000
# 1  11.888079     59.170326       2.426720  0.744359      2.613771
# 2   0.000000     -0.250922      -3.264916  0.257804     -3.259715
#
#    pkt_size_max  pkt_size_mean         iat  protocol  conn_state  \
# 0      0.050420       0.000000    0.855064  0.000000   -1.368171
# 1     22.605136      11.713125 -314.863555 -1.322219   -1.217438
# 2     -2.850162      -3.252384    0.020018 -1.000000    0.000000
#
#    label_multiclass
# 0  DDoS-RSTFINFlood
# 1     BenignTraffic
# 2   DDoS-ICMP_Flood

# %% [markdown]
# ## EDA (Before Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train_full,
    class_names,
    title=f"train (n={len(to_np_y(y_train_full))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 31

# %% [markdown]
# ## Scaling

# %%
# fit scaler on full train (raw); transform elsewhere via to_angles()
scaler = StandardScaler()
X_train_full_scaled = scaler.fit_transform(X_train_full)
print(f"scaled full train: {X_train_full_scaled.shape}")
# Out:
# scaled full train: (151049, 10)

# %% [markdown]
# ## PCA (Optional)

# %%
USE_PCA = True  # set to False to skip PCA
TARGET_VARIANCE = 0.95

# %%
if USE_PCA:
    pca_full = PCA(random_state=SEED).fit(X_train_full_scaled)
    ratios = pca_full.explained_variance_ratio_
    cum = np.cumsum(ratios)
    n_feat = len(ratios)

    print(f"features (raw dim): {n_feat}")
    print("explained_variance_ratio_:", np.round(ratios, 4))
    print("cumulative:               ", np.round(cum, 4))
    for k in range(1, n_feat + 1):
        print(f"first {k} PCs keep {cum[k - 1] * 100:.2f}% variance")

    # smallest k with >= target variance
    k95 = int(np.searchsorted(cum, TARGET_VARIANCE) + 1)
    k95 = min(k95, len(cum))  # safety
    print(f"components needed for >={TARGET_VARIANCE * 100}% variance: {k95}")

    fig, ax = plt.subplots(1, 1, figsize=(8, 5))
    ax.bar(range(1, n_feat + 1), ratios, color="slateblue", alpha=0.7, label="per-PC")
    ax.plot(range(1, n_feat + 1), cum, marker="o", color="darkblue", label="cumulative")
    ax.axhline(
        TARGET_VARIANCE,
        color="red",
        linestyle="--",
        label=f"Target({TARGET_VARIANCE * 100}%)",
    )
    ax.axvline(k95, color="green", linestyle=":", label=f"k={k95}")
    ax.set_xlabel("PCA component")
    ax.set_ylabel("explained variance ratio")
    ax.set_title("PCA explained feature variance")
    ax.legend()
    plt.tight_layout()
    plt.show()

    pca = PCA(n_components=k95, random_state=SEED)
    X_train_full_feat = pca.fit_transform(X_train_full_scaled)
else:
    pca = None
    k95 = X_train_full_scaled.shape[1]
    X_train_full_feat = X_train_full_scaled

# angle bounds from full train feature space (pca or scaled)
x_min, x_max = X_train_full_feat.min(0), X_train_full_feat.max(0)
print(f"feature dim for angles: {X_train_full_feat.shape[1]} | USE_PCA={USE_PCA}")
# Out:
# features (raw dim): 10
# explained_variance_ratio_: [4.321e-01 1.754e-01 1.195e-01 1.063e-01 6.910e-02 5.720e-02 2.430e-02
#  1.340e-02 2.500e-03 3.000e-04]
# cumulative:                [0.4321 0.6075 0.727  0.8333 0.9024 0.9596 0.9838 0.9973 0.9997 1.    ]
# first 1 PCs keep 43.21% variance
# first 2 PCs keep 60.75% variance
# first 3 PCs keep 72.70% variance
# first 4 PCs keep 83.33% variance
# first 5 PCs keep 90.24% variance
# first 6 PCs keep 95.96% variance
# first 7 PCs keep 98.38% variance
# first 8 PCs keep 99.73% variance
# first 9 PCs keep 99.97% variance
# first 10 PCs keep 100.00% variance
# components needed for >=95.0% variance: 6
# feature dim for angles: 6 | USE_PCA=True

# %% [markdown]
# ## Data Subset (Optional)

# %%
SUBSET = True  # set to False for the full dataset
PER_CLASS_CAP = 1000

# %%
# compare sampling strategies on RAW full train, then apply DPP coreset
if SUBSET:
    plot_dataset_and_sampling_analysis(
        X_train_full,
        y_train_full,
        per_class_cap=PER_CLASS_CAP,
        class_names=class_names,
        seed=SEED,
    )

    print(f"\nRunning representative DPP coreset sampling (cap={PER_CLASS_CAP})...")
    X_train, y_train = greedy_dpp_sample(
        X_train_full, y_train_full, per_class_cap=PER_CLASS_CAP, seed=SEED
    )
    print(f"Coreset selected: {X_train.shape[0]} samples.")
else:
    X_train, y_train = X_train_full, y_train_full
    print(f"using full train (no subset): {X_train.shape[0]} samples")

print(
    f"train raw: {X_train.shape, y_train.shape} | SUBSET={SUBSET} | cap={PER_CLASS_CAP if SUBSET else 'all'}"
)
# Out:
# Running representative DPP coreset sampling (cap=1000)...
# Coreset selected: 20156 samples.
# train raw: ((20156, 10), (20156,)) | SUBSET=True | cap=1000

# %% [markdown]
# ## EDA (After Preprocessing)

# %%
num_classes = len(class_names)
print(f"number of classes: {num_classes}")

# pie chart
fig, ax = plt.subplots(figsize=(8, 8))

plot_class_balance_pie(
    y_train,
    class_names,
    title=f"train subset (n={len(to_np_y(y_train))})",
    ax=ax,
)

plt.tight_layout()
plt.show()
# Out:
# number of classes: 31

# %% [markdown]
# ## Mapping Features $\rightarrow$ [0, $\pi$]

# %%
# raw -> scale -> optional pca -> [0, pi] using bounds from full train
X_train_angles_all = to_angles(
    X_train, scaler, x_min, x_max, pca=pca if USE_PCA else None, angle_max=np.pi
)

# seeded stratified holdout from train for early stopping (cal/test untouched)
VAL_FRAC = 0.1
_y_all = y_train
idx = np.arange(len(X_train_angles_all))
idx_fit, idx_val = train_test_split(
    idx,
    test_size=VAL_FRAC,
    stratify=_y_all,
    random_state=SEED,
)
X_train_angles, y_train = X_train_angles_all[idx_fit], _y_all[idx_fit]
X_val_angles, y_val = X_train_angles_all[idx_val], _y_all[idx_val]
print(
    f"angles fit: {X_train_angles.shape} | val: {X_val_angles.shape} | "
    f"VAL_FRAC={VAL_FRAC} | USE_PCA={USE_PCA} | SUBSET={SUBSET}"
)

fig, ax1 = plt.subplots(1, 1, figsize=(7, 4))
ax1.hist(X_train_angles.flatten(), bins=50, color="teal", alpha=0.8)
ax1.set_xlabel("angle (radians)")
ax1.set_title("Angle-encoded train (fit) feature distribution")
plt.tight_layout()
plt.show()
# Out:
# angles fit: (18140, 6) | val: (2016, 6) | VAL_FRAC=0.1 | USE_PCA=True | SUBSET=True

# %% [markdown]
# ## Quantum Circuit: Angle Encoding, Data Reuploading, and Adding Noise
#
# $$
# x\xrightarrow[\text{encode}]{\phi(x)}\ket{\psi(x)}\xrightarrow[\text{variational}]{U(\theta)}\ket{\Phi(x)}\xrightarrow{\Lambda_p}\rho(x)
# $$
# - $x$: classical data
# - $\phi(x)$: `qp.AngleEmbedding()`
# - $\ket{\psi(x)}$: quantum state after encoding
# - $U(\theta)$: `qp.StronglyEntanglingLayers()`
# - $\ket{\Phi(x)}$: quantum state after variational transform
# - $\rho(x)=\Lambda_p(\ket{\Phi(x)}\bra{\Phi(x)})$: standard depolarization channel to model NISQ noise

# %%
num_qubits = int(k95)  # pca comps if USE_PCA; else scaled feature dim
num_layers = 2  # reupload same classical data
noise_rate = DEFAULT_NOISE_RATE
print(f"num_qubits={num_qubits} (USE_PCA={USE_PCA})")
# Out:
# num_qubits=6 (USE_PCA=True)

# %%
# initialize devices
device = get_torch_device()
dev = create_quantum_device(
    num_qubits
)  # or dev = qp.device("default.mixed", wires=num_qubits)

# define circuit
forward_circuit = build_forward_circuit(
    dev, num_qubits, num_layers, noise_rate=noise_rate
)

# %% [markdown]
# ## Gradient Variance Probe

# %%
barren_plateau_var = BARREN_PLATEAU_VAR_THRESHOLD
n_trials = 5

safe_empty_cache()

# probe on CPU (recommended)
x_probe = X_train_angles[:1]

try:
    grad_var, grad_samples = gradient_variance_probe(
        forward_circuit,
        x_probe,
        num_qubits,
        num_layers,
        n_trials=n_trials,
        device=torch.device("cpu"),
    )

    print(f"pre-train grad var = {grad_var:.2e} (thr={barren_plateau_var:.0e})")
    if grad_var < barren_plateau_var:
        print("warning: possible barren plateau architecture")

    plt.figure(figsize=(6, 4))
    plt.hist(grad_samples, bins=15, color="darkcyan", alpha=0.8)
    plt.title(f"Gradient-variance probe (var={grad_var:.2e})")
    plt.tight_layout()
    plt.show()

except RuntimeError as e:
    if is_oom_error(e):
        print("\t[OOM] barren-plateau probe skipped (non-critical diagnostic).")
        safe_empty_cache()
    else:
        raise
# Out:
# pre-train grad var = 6.60e-08 (thr=1e-06)
# warning: possible barren plateau architecture

# %% [markdown]
# ## Training
#
# $$
# L = L_{CE}
# $$
#
# CE-only baseline: same quantum circuit + classical head as MAQT, no prototype losses.
#
# Minimizing $L_{CE}$ adjusts $\theta$ for better class predictions.

# %%
epochs = 50
batch_size = 64
lr = 0.01
early_stopping = True
patience = 5
min_delta = 0.001

out_dir = Path("artifacts") / dataset
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_dir = out_dir / f"{NOTEBOOK_NAME}_seed{SEED}"
latest_ckpt = ckpt_dir / "plain-latest.pt"
RESUME = False
resume_from = latest_ckpt if (RESUME and latest_ckpt.exists()) else None

print(f"checkpoint_dir: {ckpt_dir}")
print(f"resume_from: {resume_from}")
# Out:
# checkpoint_dir: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42
# resume_from: None

# %%
torch.manual_seed(SEED)

result = run_batched_safely(
    train_plain_vqc,
    X_train_angles,
    y_train,
    n_classes=num_classes,
    n_qubits=num_qubits,
    n_layers=num_layers,
    forward_circuit=forward_circuit,
    device=device,
    epochs=epochs,
    lr=lr,
    use_lr_schedule=True,  # auto LR
    batch_size=batch_size,
    min_batch=2,
    label="train_plain_vqc",
    use_weighted_sampler=True,
    seed=SEED,
    early_stopping=early_stopping,
    patience=patience,
    min_delta=min_delta,
    X_val=X_val_angles,
    y_val=y_val,
    checkpoint_dir=ckpt_dir,
    save_every_epoch=True,
    resume_from=resume_from,
    reset_early_stopping_on_resume=True,
    heartbeat_every_steps=200,  # pass None to less verbose
    notebook_name=NOTEBOOK_NAME,
    log_dir=ckpt_dir,
)

if result is None:
    raise RuntimeError("train_plain_vqc failed even at min_batch (OOM)")

theta, head, history = result
theta_star = theta
classifier_head = head
safe_empty_cache()
print(
    "\n"
    f"epochs_ran={history.get('epochs_ran')} | "
    f"best_epoch={history.get('best_epoch')} | "
    f"stopped_early={history.get('stopped_early')} | "
    f"stop_reason={history.get('stop_reason')}"
)
# Out:
# 	epoch 1 step 200 (71%) loss=2.7241 elapsed=86s eta=36s
# epoch  1/50 | time 122.7s | loss 2.8827 | L_CE 2.8827 | grad_var 4.65e-04 | val_loss 2.5034 | lr 1.00e-02 | peak_mem=160MB | best=2.5034@ep1 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch001.pt
# 	epoch 2 step 200 (71%) loss=2.4050 elapsed=88s eta=37s
# epoch  2/50 | time 125.2s | loss 2.4463 | L_CE 2.4463 | grad_var 9.37e-04 | val_loss 2.1997 | lr 9.99e-03 | peak_mem=160MB | best=2.1997@ep2 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch002.pt
# 	epoch 3 step 200 (71%) loss=2.0355 elapsed=88s eta=37s
# epoch  3/50 | time 124.9s | loss 2.2568 | L_CE 2.2568 | grad_var 1.29e-03 | val_loss 2.0139 | lr 9.96e-03 | peak_mem=160MB | best=2.0139@ep3 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch003.pt
# 	epoch 4 step 200 (71%) loss=2.0424 elapsed=88s eta=37s
# epoch  4/50 | time 125.1s | loss 2.1497 | L_CE 2.1497 | grad_var 1.95e-03 | val_loss 1.8902 | lr 9.91e-03 | peak_mem=160MB | best=1.8902@ep4 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch004.pt
# 	epoch 5 step 200 (71%) loss=2.1553 elapsed=88s eta=37s
# epoch  5/50 | time 125.2s | loss 2.0433 | L_CE 2.0433 | grad_var 2.40e-03 | val_loss 1.7919 | lr 9.84e-03 | peak_mem=160MB | best=1.7919@ep5 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch005.pt
# 	epoch 6 step 200 (71%) loss=1.9577 elapsed=88s eta=37s
# epoch  6/50 | time 125.4s | loss 1.9939 | L_CE 1.9939 | grad_var 2.76e-03 | val_loss 1.7075 | lr 9.76e-03 | peak_mem=160MB | best=1.7075@ep6 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch006.pt
# 	epoch 7 step 200 (71%) loss=1.8987 elapsed=89s eta=37s
# epoch  7/50 | time 125.7s | loss 1.9355 | L_CE 1.9355 | grad_var 2.98e-03 | val_loss 1.6619 | lr 9.65e-03 | peak_mem=160MB | best=1.6619@ep7 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch007.pt
# 	epoch 8 step 200 (71%) loss=1.7197 elapsed=89s eta=37s
# epoch  8/50 | time 126.5s | loss 1.9159 | L_CE 1.9159 | grad_var 4.13e-03 | val_loss 1.6129 | lr 9.53e-03 | peak_mem=160MB | best=1.6129@ep8 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch008.pt
# 	epoch 9 step 200 (71%) loss=2.1053 elapsed=90s eta=37s
# epoch  9/50 | time 127.1s | loss 1.8746 | L_CE 1.8746 | grad_var 3.55e-03 | val_loss 1.5909 | lr 9.39e-03 | peak_mem=160MB | best=1.5909@ep9 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch009.pt
# 	epoch 10 step 200 (71%) loss=1.8854 elapsed=89s eta=37s
# epoch 10/50 | time 126.7s | loss 1.8413 | L_CE 1.8413 | grad_var 3.94e-03 | val_loss 1.5473 | lr 9.23e-03 | peak_mem=160MB | best=1.5473@ep10 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch010.pt
# 	epoch 11 step 200 (71%) loss=1.7954 elapsed=89s eta=37s
# epoch 11/50 | time 126.2s | loss 1.8088 | L_CE 1.8088 | grad_var 4.19e-03 | val_loss 1.5222 | lr 9.05e-03 | peak_mem=160MB | best=1.5222@ep11 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch011.pt
# 	epoch 12 step 200 (71%) loss=1.7211 elapsed=89s eta=37s
# epoch 12/50 | time 126.0s | loss 1.8153 | L_CE 1.8153 | grad_var 4.37e-03 | val_loss 1.5132 | lr 8.86e-03 | peak_mem=160MB | best=1.5132@ep12 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch012.pt
# 	epoch 13 step 200 (71%) loss=1.7389 elapsed=89s eta=37s
# epoch 13/50 | time 125.6s | loss 1.7823 | L_CE 1.7823 | grad_var 4.54e-03 | val_loss 1.4975 | lr 8.66e-03 | peak_mem=160MB | best=1.4975@ep13 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch013.pt
# 	epoch 14 step 200 (71%) loss=1.9362 elapsed=89s eta=37s
# epoch 14/50 | time 126.1s | loss 1.7724 | L_CE 1.7724 | grad_var 4.48e-03 | val_loss 1.4869 | lr 8.44e-03 | peak_mem=160MB | best=1.4869@ep14 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch014.pt
# 	epoch 15 step 200 (71%) loss=1.9441 elapsed=89s eta=37s
# epoch 15/50 | time 126.4s | loss 1.7631 | L_CE 1.7631 | grad_var 5.06e-03 | val_loss 1.4479 | lr 8.21e-03 | peak_mem=160MB | best=1.4479@ep15 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch015.pt
# 	epoch 16 step 200 (71%) loss=1.5593 elapsed=89s eta=37s
# epoch 16/50 | time 126.5s | loss 1.7489 | L_CE 1.7489 | grad_var 4.94e-03 | val_loss 1.4487 | lr 7.96e-03 | peak_mem=160MB | best=1.4479@ep15 | bad=1/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch016.pt
# 	epoch 17 step 200 (71%) loss=2.0034 elapsed=89s eta=37s
# epoch 17/50 | time 126.0s | loss 1.7567 | L_CE 1.7567 | grad_var 5.62e-03 | val_loss 1.4422 | lr 7.70e-03 | peak_mem=160MB | best=1.4422@ep17 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch017.pt
# 	epoch 18 step 200 (71%) loss=1.7698 elapsed=90s eta=37s
# epoch 18/50 | time 126.9s | loss 1.7400 | L_CE 1.7400 | grad_var 5.80e-03 | val_loss 1.4250 | lr 7.43e-03 | peak_mem=160MB | best=1.4250@ep18 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch018.pt
# 	epoch 19 step 200 (71%) loss=1.6495 elapsed=89s eta=37s
# epoch 19/50 | time 126.5s | loss 1.7201 | L_CE 1.7201 | grad_var 5.13e-03 | val_loss 1.4128 | lr 7.16e-03 | peak_mem=160MB | best=1.4128@ep19 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch019.pt
# 	epoch 20 step 200 (71%) loss=1.5702 elapsed=89s eta=37s
# epoch 20/50 | time 125.9s | loss 1.7133 | L_CE 1.7133 | grad_var 5.47e-03 | val_loss 1.4204 | lr 6.87e-03 | peak_mem=160MB | best=1.4128@ep19 | bad=1/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch020.pt
# 	epoch 21 step 200 (71%) loss=1.7510 elapsed=89s eta=37s
# epoch 21/50 | time 125.9s | loss 1.7179 | L_CE 1.7179 | grad_var 6.00e-03 | val_loss 1.4095 | lr 6.58e-03 | peak_mem=160MB | best=1.4095@ep21 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch021.pt
# 	epoch 22 step 200 (71%) loss=1.5765 elapsed=89s eta=37s
# epoch 22/50 | time 126.3s | loss 1.7046 | L_CE 1.7046 | grad_var 5.63e-03 | val_loss 1.3971 | lr 6.28e-03 | peak_mem=160MB | best=1.3971@ep22 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch022.pt
# 	epoch 23 step 200 (71%) loss=1.6880 elapsed=89s eta=37s
# epoch 23/50 | time 126.2s | loss 1.7008 | L_CE 1.7008 | grad_var 6.06e-03 | val_loss 1.3958 | lr 5.98e-03 | peak_mem=160MB | best=1.3958@ep23 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch023.pt
# 	epoch 24 step 200 (71%) loss=1.8148 elapsed=89s eta=37s
# epoch 24/50 | time 125.9s | loss 1.6959 | L_CE 1.6959 | grad_var 5.44e-03 | val_loss 1.3863 | lr 5.67e-03 | peak_mem=160MB | best=1.3863@ep24 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch024.pt
# 	epoch 25 step 200 (71%) loss=1.3825 elapsed=89s eta=37s
# epoch 25/50 | time 126.5s | loss 1.6969 | L_CE 1.6969 | grad_var 5.78e-03 | val_loss 1.3816 | lr 5.36e-03 | peak_mem=160MB | best=1.3816@ep25 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch025.pt
# 	epoch 26 step 200 (71%) loss=1.6673 elapsed=89s eta=37s
# epoch 26/50 | time 126.8s | loss 1.6969 | L_CE 1.6969 | grad_var 5.73e-03 | val_loss 1.3693 | lr 5.05e-03 | peak_mem=160MB | best=1.3693@ep26 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch026.pt
# 	epoch 27 step 200 (71%) loss=2.0013 elapsed=89s eta=37s
# epoch 27/50 | time 127.0s | loss 1.6891 | L_CE 1.6891 | grad_var 6.05e-03 | val_loss 1.3795 | lr 4.74e-03 | peak_mem=160MB | best=1.3693@ep26 | bad=1/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch027.pt
# 	epoch 28 step 200 (71%) loss=1.5870 elapsed=90s eta=38s
# epoch 28/50 | time 127.0s | loss 1.6757 | L_CE 1.6757 | grad_var 6.36e-03 | val_loss 1.3723 | lr 4.43e-03 | peak_mem=160MB | best=1.3693@ep26 | bad=2/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch028.pt
# 	epoch 29 step 200 (71%) loss=1.8033 elapsed=89s eta=37s
# epoch 29/50 | time 125.9s | loss 1.6828 | L_CE 1.6828 | grad_var 6.28e-03 | val_loss 1.3615 | lr 4.12e-03 | peak_mem=160MB | best=1.3615@ep29 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch029.pt
# 	epoch 30 step 200 (71%) loss=1.5766 elapsed=88s eta=37s
# epoch 30/50 | time 125.5s | loss 1.6702 | L_CE 1.6702 | grad_var 6.06e-03 | val_loss 1.3683 | lr 3.82e-03 | peak_mem=160MB | best=1.3615@ep29 | bad=1/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch030.pt
# 	epoch 31 step 200 (71%) loss=1.6382 elapsed=88s eta=37s
# epoch 31/50 | time 125.4s | loss 1.6628 | L_CE 1.6628 | grad_var 6.28e-03 | val_loss 1.3625 | lr 3.52e-03 | peak_mem=160MB | best=1.3615@ep29 | bad=2/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch031.pt
# 	epoch 32 step 200 (71%) loss=1.6683 elapsed=88s eta=37s
# epoch 32/50 | time 125.5s | loss 1.6714 | L_CE 1.6714 | grad_var 6.31e-03 | val_loss 1.3551 | lr 3.23e-03 | peak_mem=160MB | best=1.3551@ep32 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch032.pt
# 	epoch 33 step 200 (71%) loss=1.4856 elapsed=88s eta=37s
# epoch 33/50 | time 125.4s | loss 1.6779 | L_CE 1.6779 | grad_var 6.42e-03 | val_loss 1.3592 | lr 2.94e-03 | peak_mem=160MB | best=1.3551@ep32 | bad=1/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch033.pt
# 	epoch 34 step 200 (71%) loss=1.7583 elapsed=88s eta=37s
# epoch 34/50 | time 125.5s | loss 1.6711 | L_CE 1.6711 | grad_var 7.00e-03 | val_loss 1.3594 | lr 2.67e-03 | peak_mem=160MB | best=1.3551@ep32 | bad=2/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch034.pt
# 	epoch 35 step 200 (71%) loss=1.5964 elapsed=88s eta=37s
# epoch 35/50 | time 125.4s | loss 1.6807 | L_CE 1.6807 | grad_var 6.38e-03 | val_loss 1.3551 | lr 2.40e-03 | peak_mem=160MB | best=1.3551@ep32 | bad=3/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch035.pt
# 	epoch 36 step 200 (71%) loss=1.3083 elapsed=88s eta=37s
# epoch 36/50 | time 125.5s | loss 1.6866 | L_CE 1.6866 | grad_var 6.19e-03 | val_loss 1.3480 | lr 2.14e-03 | peak_mem=160MB | best=1.3480@ep36 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch036.pt
# 	epoch 37 step 200 (71%) loss=1.7236 elapsed=89s eta=37s
# epoch 37/50 | time 125.7s | loss 1.6578 | L_CE 1.6578 | grad_var 6.28e-03 | val_loss 1.3493 | lr 1.89e-03 | peak_mem=160MB | best=1.3480@ep36 | bad=1/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch037.pt
# 	epoch 38 step 200 (71%) loss=1.7723 elapsed=89s eta=37s
# epoch 38/50 | time 126.2s | loss 1.6851 | L_CE 1.6851 | grad_var 6.84e-03 | val_loss 1.3470 | lr 1.66e-03 | peak_mem=160MB | best=1.3480@ep36 | bad=2/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch038.pt
# 	epoch 39 step 200 (71%) loss=1.8333 elapsed=88s eta=37s
# epoch 39/50 | time 125.2s | loss 1.6549 | L_CE 1.6549 | grad_var 6.11e-03 | val_loss 1.3466 | lr 1.44e-03 | peak_mem=160MB | best=1.3466@ep39 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch039.pt
# 	epoch 40 step 200 (71%) loss=1.9308 elapsed=89s eta=37s
# epoch 40/50 | time 125.9s | loss 1.6773 | L_CE 1.6773 | grad_var 6.53e-03 | val_loss 1.3490 | lr 1.24e-03 | peak_mem=160MB | best=1.3466@ep39 | bad=1/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch040.pt
# 	epoch 41 step 200 (71%) loss=1.6338 elapsed=89s eta=37s
# epoch 41/50 | time 126.1s | loss 1.6611 | L_CE 1.6611 | grad_var 6.40e-03 | val_loss 1.3503 | lr 1.05e-03 | peak_mem=160MB | best=1.3466@ep39 | bad=2/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch041.pt
# 	epoch 42 step 200 (71%) loss=1.9119 elapsed=89s eta=37s
# epoch 42/50 | time 126.9s | loss 1.6650 | L_CE 1.6650 | grad_var 6.44e-03 | val_loss 1.3444 | lr 8.71e-04 | peak_mem=160MB | best=1.3444@ep42 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch042.pt
# 	epoch 43 step 200 (71%) loss=1.8027 elapsed=90s eta=37s
# epoch 43/50 | time 127.0s | loss 1.6637 | L_CE 1.6637 | grad_var 6.48e-03 | val_loss 1.3467 | lr 7.12e-04 | peak_mem=160MB | best=1.3444@ep42 | bad=1/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch043.pt
# 	epoch 44 step 200 (71%) loss=1.6663 elapsed=89s eta=37s
# epoch 44/50 | time 126.7s | loss 1.6668 | L_CE 1.6668 | grad_var 6.41e-03 | val_loss 1.3429 | lr 5.71e-04 | peak_mem=160MB | best=1.3429@ep44 | bad=0/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch044.pt
# 	epoch 45 step 200 (71%) loss=1.7212 elapsed=89s eta=37s
# epoch 45/50 | time 126.7s | loss 1.6621 | L_CE 1.6621 | grad_var 6.62e-03 | val_loss 1.3463 | lr 4.48e-04 | peak_mem=160MB | best=1.3429@ep44 | bad=1/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch045.pt
# 	epoch 46 step 200 (71%) loss=1.6926 elapsed=89s eta=37s
# epoch 46/50 | time 125.8s | loss 1.6460 | L_CE 1.6460 | grad_var 6.33e-03 | val_loss 1.3471 | lr 3.42e-04 | peak_mem=160MB | best=1.3429@ep44 | bad=2/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch046.pt
# 	epoch 47 step 200 (71%) loss=1.7373 elapsed=89s eta=37s
# epoch 47/50 | time 125.5s | loss 1.6655 | L_CE 1.6655 | grad_var 6.47e-03 | val_loss 1.3458 | lr 2.56e-04 | peak_mem=160MB | best=1.3429@ep44 | bad=3/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch047.pt
# 	epoch 48 step 200 (71%) loss=1.8296 elapsed=88s eta=37s
# epoch 48/50 | time 125.0s | loss 1.6539 | L_CE 1.6539 | grad_var 6.80e-03 | val_loss 1.3458 | lr 1.88e-04 | peak_mem=160MB | best=1.3429@ep44 | bad=4/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch048.pt
# 	epoch 49 step 200 (71%) loss=1.6793 elapsed=89s eta=37s
# epoch 49/50 | time 126.1s | loss 1.6783 | L_CE 1.6783 | grad_var 6.36e-03 | val_loss 1.3451 | lr 1.39e-04 | peak_mem=160MB | best=1.3429@ep44 | bad=5/5
#   saved checkpoint: artifacts/CICIoT2023/final-ciciot2023-vqc-train_seed42/plain-epoch049.pt
# early stopping at epoch 49: no val_loss improvement for 5 epochs (best=1.3429 @ epoch 44)
# restored best plain-VQC weights from epoch 44 (val_loss=1.3429)
#
# epochs_ran=49 | best_epoch=44 | stopped_early=True | stop_reason=early_stopping

# %% [markdown]
# ## Prototypes
#
# Class-mean prototypes are computed post-hoc after CE training for later Algo-3 / geometry compare.

# %%
# post-hoc class-mean prototypes under frozen CE theta
proto_bank = PrototypeBank(classes=range(num_classes))
prototypes = proto_bank.compute(
    theta_star,
    X_train_angles,
    y_train,
    forward_circuit,
    device=device,
    batch_size=batch_size,
)

# %%
proto_df = pd.DataFrame(prototype_summary(prototypes, class_names))
proto_df
# Out:
#                       class  dim     trace
# 0          Backdoor_Malware   64  1.000001
# 1             BenignTraffic   64  1.000001
# 2          BrowserHijacking   64  1.000001
# 3          CommandInjection   64  1.000001
# 4    DDoS-ACK_Fragmentation   64  1.000001
# 5           DDoS-HTTP_Flood   64  1.000001
# 6           DDoS-ICMP_Flood   64  1.000001
# 7   DDoS-ICMP_Fragmentation   64  1.000001
# 8         DDoS-PSHACK_Flood   64  1.000001
# 9          DDoS-RSTFINFlood   64  1.000001
# 10           DDoS-SYN_Flood   64  1.000001
# 11           DDoS-SlowLoris   64  1.000001
# 12  DDoS-SynonymousIP_Flood   64  1.000001
# 13           DDoS-TCP_Flood   64  1.000001
# 14           DDoS-UDP_Flood   64  1.000001
# 15   DDoS-UDP_Fragmentation   64  1.000001
# 16             DNS_Spoofing   64  1.000001
# 17     DictionaryBruteForce   64  1.000001
# 18           DoS-HTTP_Flood   64  1.000001
# 19            DoS-SYN_Flood   64  1.000001
# 20            DoS-TCP_Flood   64  1.000001
# 21            DoS-UDP_Flood   64  1.000001
# 22         MITM-ArpSpoofing   64  1.000001
# 23      Recon-HostDiscovery   64  1.000001
# 24             Recon-OSScan   64  1.000001
# 25          Recon-PingSweep   64  1.000001
# 26           Recon-PortScan   64  1.000001
# 27             SqlInjection   64  1.000001
# 28         Uploading_Attack   64  1.000001
# 29        VulnerabilityScan   64  1.000001
# 30                      XSS   64  1.000001

# %%
# save prototypes (all-in-one checkpoint)
out_dir = Path("final_notebooks") / "final_artifacts"
out_dir.mkdir(parents=True, exist_ok=True)

ckpt_path = out_dir / f"{NOTEBOOK_NAME}-checkpoint.pt"
torch.save(
    {
        "theta": theta_star.detach().cpu(),
        "head_state_dict": head.state_dict(),
        "prototypes": {k: v.detach().cpu() for k, v in prototypes.items()},
        "train_mode": "CE-only",
        # rebuild / inference meta
        "class_names": list(class_names),
        "num_classes": num_classes,
        "num_qubits": num_qubits,
        "num_layers": num_layers,
        "noise_rate": noise_rate,
        # FROZEN feature + angle pipeline (must match train)
        "feature_cols": list(FEATURE_COLS),
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "target_col": target_col,
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "scaler": scaler,  # StandardScaler fitted on full train
        "pca": pca,  # PCA fitted on scaled full train (or None)
        "k95": int(k95),
        "angle_x_min": np.asarray(x_min),  # on pca space if USE_PCA else scaled space
        "angle_x_max": np.asarray(x_max),
        "angle_min": 0.0,
        "angle_max": float(np.pi),
    },
    ckpt_path,
)
print("published:", ckpt_path.resolve())
# Out:
# published: /home/lawun330/Desktop/quantum-sentinel/final_notebooks/final_artifacts/final-ciciot2023-vqc-train-checkpoint.pt

# %% [markdown]
# ## Visualization

# %%
# plots
epochs_x = range(1, len(history["loss"]) + 1)

fig, axes = plt.subplots(1, 3, figsize=(14, 4))

# total loss (= CE for this baseline)
axes[0].plot(epochs_x, history["loss"], marker="o")
axes[0].set_title("Total loss ($L_{CE}$)")
axes[0].set_xlabel("Epoch")

# CE curve
axes[1].plot(epochs_x, history["loss"], marker=None, label=r"$L$")
axes[1].plot(epochs_x, history["L_CE"], "--", label=r"$L_{CE}$")
axes[1].set_title(r"$L = L_{CE}$ (CE-only)")
axes[1].legend(fontsize=8)

# grad var
axes[2].plot(epochs_x, history["grad_var"], marker="o", color="tab:orange")
axes[2].axhline(
    1e-6, color="red", linestyle="--", label="plateau thr"
)  # or BARREN_PLATEAU_VAR_THRESHOLD
axes[2].set_title("Gradient variance")
axes[2].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Logging

# %%
# write log (final)
log_path = write_history_log(
    history,
    NOTEBOOK_NAME,
    extra={
        ## data
        "teamC_handoff": frozen_feat_path,
        "data_path": data_path,
        "dataset": dataset,
        "feature_cols": FEATURE_COLS,
        "target_col": target_col,
        "n_train": len(X_train),
        "class_names": list(class_names),
        "use_pca": bool(USE_PCA),
        "subset": bool(SUBSET),
        "per_class_cap": int(PER_CLASS_CAP) if SUBSET else None,
        "sampler": "greedy_dpp" if SUBSET else None,
        "num_qubits": num_qubits,
        "k95": int(k95),
        # algo: CE-only train
        "train_mode": "CE-only",
        "epochs": epochs,
        "batch_size": batch_size,
        "lr": lr,
        "use_lr_schedule": True,
        ## quantum model
        "noise_rate": noise_rate,
        "num_layers": num_layers,
        "num_classes": num_classes,
        ## training
        "train_total_sec": float(sum(history["epoch_sec"]))
        if history.get("epoch_sec")
        else None,
        "loss_last": float(history["loss"][-1]) if history["loss"] else None,
        "barren_plateau_var": barren_plateau_var,
        "barren_plateau_any": bool(
            any(g < barren_plateau_var for g in history["grad_var"])
        )
        if history.get("grad_var")
        else None,
        "seed": SEED,
        "early_stopping": early_stopping,
        "patience": patience,
        "best_epoch": history.get("best_epoch"),
        "best_score": history.get("best_score"),
        "stopped_early": history.get("stopped_early"),
        "epochs_ran": history.get("epochs_ran"),
        "stop_reason": history.get("stop_reason"),
        "interrupted": history.get("interrupted"),
        "checkpoint_dir": str(ckpt_dir),
    },
    log_dir="logs",
)
print(f"wrote {log_path.resolve()}")
# Out:
# wrote /home/lawun330/Desktop/quantum-sentinel/logs/final-ciciot2023-vqc-train.log
